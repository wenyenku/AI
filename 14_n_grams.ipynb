# %% [markdown]
# <a href="https://colab.research.google.com/github/shhuangmust/AI/blob/110-2/14.n_grams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # N-Grams
# - 了解單一字詞表示方式，接下來則是語言模型的表示。語言模型是由"字詞/字句"所構成，所以要透過組合單一字詞成為其他有意義的"字詞/字句"
# - 組合的過程稱之為n-grams，單一字詞為1-gram，兩個字詞組成有意義的"字詞/字句"稱之為2-grams，依此類推
# - 本範例利用情緒分析範例，示範如何把評論詞切成n-grams的前處理過程
# - 前處理過程包含：1. 去除標點符號(punctuation) 2. 去除停用詞(stopwords，無意義之詞，例如"的"、"了"...之類)
# - 接下來產生單字詞unigram，雙字詞bigram，三字詞trigram

# %% [markdown]
# **SENTIMENT ANALYSIS FOR FINANCIAL NEWS FROM THE PERSPECTIVE OF A RETIAL INVESTOR**
#
# **->3 categories:**
#
#
# -positive
#
# -negative
#
# -neutral
#
# DATASET:
#
# https://www.kaggle.com/ankurzing/sentiment-analysis-for-financial-news

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

plt.style.use(style='seaborn')
# %matplotlib inline

# %%
df=pd.read_csv('all-data.csv',encoding = "ISO-8859-1", header=None, names = ['Sentiment', 'News Headline'])
df.head()
# Out:
#   Sentiment                                      News Headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sentiment      4846 non-null   object
#  1   News Headline  4846 non-null   object
# dtypes: object(2)
# memory usage: 75.8+ KB

# %%
df.isna().sum()
# Out:
# Sentiment        0
# News Headline    0
# dtype: int64

# %%
df['Sentiment'].value_counts()
# Out:
# neutral     2879
# positive    1363
# negative     604
# Name: Sentiment, dtype: int64

# %% [markdown]
# **Feature extraction**

# %%
y=df['Sentiment'].values
y.shape
# Out:
# (4846,)

# %%
x=df['News Headline'].values
x.shape
# Out:
# (4846,)

# %% [markdown]
# **Train-test split**

# %%
from sklearn.model_selection import train_test_split

# %%
(x_train,x_test,y_train,y_test)=train_test_split(x,y,test_size=0.4)

# %%
x_train.shape
# Out:
# (2907,)

# %%
y_train.shape
# Out:
# (2907,)

# %%
x_test.shape
# Out:
# (1939,)

# %%
y_test.shape
# Out:
# (1939,)

# %%
x_train
# Out:
# array(['The lay-offs will start gradually and will last from one to six weeks .',
#        'ADPnews - Feb 5 , 2010 - Finnish real estate investor Sponda Oyj HEL : SDA1V said today that it slipped to a net loss of EUR 81.5 million USD 11.8 m in 2009 from a profit of EUR 29.3 million in 2008 .',
#        'No financial details were revealed .', ...,
#        "18 January 2010 - Finnish IT consultancy Trainers ' House Oyj HEL : TRH1V said last Friday it resolved to issue a EUR5m hybrid bond to domestic investors in a bid to strengthen its capital structure .",
#        'M-real Corporation Stock Exchange Announcement 29 September 2006 at 4.15 p.m. Kyro Corporation and M-real Corporation , a Metsaliitto Group subsidiary , have agreed on an arrangement which gives M-real option to purchase the Kyroskoski natural gas powerplant from Kyro .',
#        'Its total annual revenue comes up to about 160 mln zloty ( $ 56.9 mln-42 .3 mln euro ) .'],
#       dtype=object)

# %%
df1=pd.DataFrame(x_train)
df1=df1.rename(columns={0:'news'})

df2=pd.DataFrame(y_train)
df2=df2.rename(columns={0:'sentiment'})
df_train=pd.concat([df1,df2],axis=1)

df_train.head()
# Out:
#                                                 news sentiment
# 0  The lay-offs will start gradually and will las...   neutral
# 1  ADPnews - Feb 5 , 2010 - Finnish real estate i...  negative
# 2               No financial details were revealed .   neutral
# 3  The contract covers turnkey deliveries to all ...   neutral
# 4  ALEXANDRIA , Va. , May 23 -- Matti Harkonen an...   neutral

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   news       2907 non-null   object
#  1   sentiment  2907 non-null   object
# dtypes: object(2)
# memory usage: 45.5+ KB

# %%
df3=pd.DataFrame(x_test)
df3=df3.rename(columns={0:'news'})

df4=pd.DataFrame(y_test)
df4=df2.rename(columns={0:'sentiment'})
df_test=pd.concat([df3,df4],axis=1)

df_test.head()
# Out:
#                                                 news sentiment
# 0  The company is in charge of all natural gas st...   neutral
# 1  Operating profit for the 12-month period decre...  negative
# 2  Cramo Group 's financial targets for 2010-2013...   neutral
# 3  Sales came in at 241 mln eur , compared with 2...   neutral
# 4  Filmiteollisuus Fine Ab will be transferred to...   neutral

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   news       1939 non-null   object
#  1   sentiment  2907 non-null   object
# dtypes: object(2)
# memory usage: 45.5+ KB

# %% [markdown]
# **Pre-processing**

# %%
#removing punctuations
#library that contains punctuation
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
  if(type(text)==float):
    return text
  ans=""  
  for i in text:     
    if i not in string.punctuation:
      ans+=i    
  return ans

#storing the puntuation free text in a new column called clean_msg
df_train['news']= df_train['news'].apply(lambda x:remove_punctuation(x))
df_test['news']= df_test['news'].apply(lambda x:remove_punctuation(x))

# %%
df_train.head()
#punctuations are removed from news column in train dataset
# Out:
#                                                 news sentiment
# 0  The layoffs will start gradually and will last...   neutral
# 1  ADPnews  Feb 5  2010  Finnish real estate inve...  negative
# 2                No financial details were revealed    neutral
# 3  The contract covers turnkey deliveries to all ...   neutral
# 4  ALEXANDRIA  Va  May 23  Matti Harkonen and Pen...   neutral

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#method to generate n-grams:
#params:
#text-the text for which we have to generate n-grams
#ngram-number of grams to be generated from the text(1,2,3,4 etc., default value=1)


def generate_N_grams(text,ngram=1):
  words=[word for word in text.split(" ") if word not in set(stopwords.words('english'))]  
  print("Sentence after removing stopwords:",words)
  temp=zip(*[words[i:] for i in range(0,ngram)])
  ans=[' '.join(ngram) for ngram in temp]
  return ans

# %%
#sample!
generate_N_grams("The sun rises in the east",3)
# Out:
# Sentence after removing stopwords: ['The', 'sun', 'rises', 'east']
# ['The sun rises', 'sun rises east']

# %% [markdown]
# **Create unigrams**

# %%
from collections import defaultdict

# %%
positiveValues=defaultdict(int)
negativeValues=defaultdict(int)
neutralValues=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text):
    positiveValues[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text):
    negativeValues[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text):
    neutralValues[word]+=1
# Out:
# Sentence after removing stopwords: ['The', 'concept', 'enables', 'commercially', 'affordable', 'way', 'manufacture', 'highquality', 'TCO', 'coated', 'glass', 'solar', 'industry', '']
# Sentence after removing stopwords: ['Talentum', 'expects', 'net', 'sales', 'core', 'business', 'increase', '2008', '', 'compared', '2007', '']
# Sentence after removing stopwords: ['By', 'cutting', 'number', 'plants', '', 'group', 'trim', 'fixed', 'costs', '']
# Sentence after removing stopwords: ['More', 'staff', 'recruited', 'Japan', 'complement', 'network', 'close', '50', 'service', 'locations', '20', 'countries', 'worldwide', '']
# Sentence after removing stopwords: ['Finnish', 'Swedish', 'construction', 'markets', 'still', 'experiencing', 'estimated', '4', '', 'annual', 'growth', '2008', '']
# Sentence after removing stopwords: ['In', 'addition', 'fireplace', 'exports', '', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['It', 'combines', 'perfect', 'price', 'performance', 'sophisticated', 'management', 'facilities', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '194', 'mn', 'EUR', '245', 'mn', '']
# Sentence after removing stopwords: ['Cash', 'flow', 'business', 'operations', 'totalled', 'EUR', '04', 'mn', 'compared', 'negative', 'EUR', '155', 'mn', 'first', 'half', '2008', '']
# Sentence after removing stopwords: ['', 'The', 'change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', '', '', 'said', 'Julia', 'Prohaska', '', 'director', 'marketing', 'communications', 'Fiskars', '']
# Sentence after removing stopwords: ['A', 'new', 'Kveyt', 'light', 'variety', 'Suomalainen', 'Pekoni', 'marketed', 'Atria', 'brand', 'name', 'available', 'consumers', 'Finland', '']
# Sentence after removing stopwords: ['Finnish', 'OKO', 'bank', 'signed', 'cooperation', 'agreement', 'Raiffeisen', 'concerning', 'Finnish', 'companies', '', 'investments', 'Russia', '']
# Sentence after removing stopwords: ['The', 'production', 'capacity', 'tripled', 'without', 'major', 'additional', 'investments', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Aspo', 'Plc', 'STOCK', 'EXCHANGE', 'RELEASE', 'February', '11', '', '2011', 'at8', '45', 'ESL', 'Shipping', 'Ltd', '', 'part', 'Aspo', 'Group', '', 'signed', 'new', '', 'longterm', 'contract', 'Rautaruukki', 'Corporation', 'marine', 'transport', 'raw', 'materials', 'Baltic', 'Sea', '']
# Sentence after removing stopwords: ['SKF', '6', 'April', '2010', '', 'Alandsbanken', 'given', '', 'buy', '', 'recommendation', 'Swedish', 'industrial', 'company', 'SKF', 'AB', '', 'STO', '', 'SKF', 'B', '', 'share', 'price', 'target', 'SEK150', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'anticipated', 'operating', 'profit', 'improve', 'period', '']
# Sentence after removing stopwords: ['Fiskars', 'strong', 'portfolio', 'international', 'brands', '', 'include', 'Fiskars', '', 'Iittala', '', 'Gerber', '', 'Silva', 'Buster', '']
# Sentence after removing stopwords: ['Ramirent', 'leading', 'company', 'machinery', 'equipment', 'rentals', 'construction', 'industry', '']
# Sentence after removing stopwords: ['Previously', 'company', 'estimated', 'operating', 'profit', 'reach', 'level', '2005', '']
# Sentence after removing stopwords: ['The', 'financial', 'impact', 'estimated', '15', 'MEUR', 'annual', 'improvement', 'division', 'result', '', 'starting', 'fiscal', 'year', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'technology', 'group', 'Aspocomp', 'Group', 'Oyj', '', 'OMX', 'Helsinki', '', 'ACG1V', '', 'issued', 'third', 'quarter', 'report', 'Thursday', '', '13', 'November', '', '', 'posting', 'operating', 'profit', 'EUR0', '4', '', 'compared', 'loss', 'EUR0', '5', 'third', 'quarter', '2007', '']
# Sentence after removing stopwords: ['The', 'agreement', 'provide', 'The', 'Switch', 'double', 'converter', 'capacity', '', 'whilst', 'opening', 'manufacturing', 'locations', 'China', '']
# Sentence after removing stopwords: ['Finnish', 'KCI', 'Konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'Indian', 'steel', 'producer', 'Bhushan', 'Steel', '', 'Strips', 'delivered', '2007', '']
# Sentence after removing stopwords: ['According', 'Bosse', '', 'present', 'cooperation', 'beneficial', 'parties', '', 'however', '']
# Sentence after removing stopwords: ['Proving', 'good', 'cellphone', 'design', 'truly', 'work', 'art', '', 'website', 'Nokia', '6131', 'provides', 'colorful', 'canvas', 'expression', 'mobileinspired', 'sentiments', '']
# Sentence after removing stopwords: ['In', 'China', '', 'Finnish', 'Kone', 'provides', 'elevators', '', 'escalators', '', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'highspeed', 'railway', 'section', 'Beijing', 'Shanghai', '15', 'years', '', 'time', '']
# Sentence after removing stopwords: ['One', 'colleagues', 'summed', 'E7', 'quite', 'aptly', 'remarked', '', '', 'Fantastic', 'hardware', '']
# Sentence after removing stopwords: ['Tiimari', '', 'Finnish', 'retailer', '', 'reported', 'geenrated', 'quarterly', 'revenues', 'totalling', 'EUR', '13', 'mn', '4th', 'quarter', '2009', '', 'EUR', '03', 'mn', 'loss', '2008', '']
# Sentence after removing stopwords: ['The', 'stock', 'rose', 'third', 'day', 'Tuesday', 'bringing', 'threeday', 'rise', 'GBX10', '50', '18', '', '']
# Sentence after removing stopwords: ['Adanac', 'Molybdenum', 'Canada', 'ordered', 'grinding', 'technology', 'molybdenum', 'project', 'British', 'Columbia', '', 'Canada', '', 'Shalkiya', 'Zinc', 'Kazakhstan', 'awarded', 'contract', 'grinding', 'technology', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['At', 'end', 'March', '2007', '', 'group', 'order', 'book', 'EUR', '396', 'mn', '', '42', '', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['The', 'EPS', 'improved', 'EUR0', '38', 'EUR0', '27', '']
# Sentence after removing stopwords: ['Mreal', 'sales', 'expected', 'increased', '4', '', 'yearonyear', 'EUR609m', 'second', 'quarter', '2010', '']
# Sentence after removing stopwords: ['Growth', 'strongest', 'FSecure', 'operator', 'ISPs', '', 'mobile', 'operators', 'cable', 'operators', 'business', '']
# Sentence after removing stopwords: ['Seppala', 'revenue', 'increased', '02', '', 'EUR10', '1', 'In', 'Finland', '', 'revenue', 'went', '24', '', 'EUR6', '8', '', 'sales', 'abroad', 'rose', '62', '', 'EUR3', '3', 'Sales', 'increased', 'Baltic', 'countries', 'well', 'Russia', 'Ukraine', '']
# Sentence after removing stopwords: ['The', 'rebuilds', 'designed', 'improve', 'machines', '', 'performance', 'product', 'quality', '']
# Sentence after removing stopwords: ['The', 'disposal', 'Autotank', 'also', 'strengthen', 'Aspo', 'capital', 'structure', '', '', 'commented', 'Gustav', 'Nyberg', '', 'CEO', 'Aspo', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'R', 'shares', 'rose', '120', 'pct', '1184', 'eur', '', 'UPMKymmene', 'also', 'dragged', 'higher', '', 'rising', '168', 'pct', '1756', 'eur', 'MReal', 'B', 'added', '238', 'pct', '430', 'eur', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['Nevertheless', '', 'market', 'share', 'rose', '4914', 'percent', '4851', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['EuroChem', 'CFO', 'Andrey', 'Ilyin', 'said', '', '', 'This', 'facility', 'marks', 'another', 'important', 'step', 'EuroChem', 'securing', 'longterm', 'financing', 'necessary', 'potash', 'strategic', 'projects', '', '']
# Sentence after removing stopwords: ['Precedex', 'approved', 'IV', 'sedation', 'initially', 'intubated', 'mechanically', 'ventilated', 'patients', 'intensive', 'care', '']
# Sentence after removing stopwords: ['It', 'provides', 'customers', 'industryleading', 'elevators', '', 'escalators', 'innovative', 'solutions', 'maintenance', 'modernization', '']
# Sentence after removing stopwords: ['The', 'Finnish', 'supplier', 'BSSOSS', 'VAS', 'telecom', 'operators', '', 'Tecnotree', '', 'received', 'expansion', 'orders', 'worth', 'total', 'US', '73', 'mn', 'convergent', 'charging', 'next', 'generation', 'messaging', 'solutions', 'Latin', 'America', '', 'company', 'announced', 'without', 'specifying', 'operators', 'placed', 'orders', '']
# Sentence after removing stopwords: ['credit', '20', 'November', '2009', '', 'Finnish', 'glass', 'technology', 'company', 'Glaston', 'Oyj', 'Abp', '', 'HEL', '', 'GLA1V', '', 'said', 'today', 'concluded', 'EUR74m', 'revolving', 'credit', 'facility', 'agreement', 'core', 'banks', '']
# Sentence after removing stopwords: ['Aspocomp', 'repaid', 'interest', 'bearing', 'liability', 'Standard', 'Chartered', 'Bank', 'use', 'rest', 'consideration', 'partially', 'repay', 'interest', 'bearing', 'liabilities', 'Finland', 'improve', 'liquidity', '']
# Sentence after removing stopwords: ['Operating', 'income', 'rose', 'EUR', '6964', 'mn', 'EUR', '6003', 'mn', '2009', '']
# Sentence after removing stopwords: ['Due', 'rapid', 'expansion', '', 'market', 'share', 'Tallink', 'terms', 'passenger', 'carriage', 'Tallinna', 'Sadam', 'Port', 'Tallinn', 'totaled', '55', 'percent', 'November', '457', 'percent', 'November', '2005', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'accounts', '50', '', 'poultry', 'sales', 'Finland', '', 'profitability', 'good', 'level', '']
# Sentence after removing stopwords: ['TELE2', 'Affarsvarlden', 'gave', '', 'buy', '', 'recommendation', 'mobile', 'operator', 'Tele2', 'AB', 'share', 'price', 'target', '142', 'crowns', '', '', '2354', '', '1519', 'euro', '', '']
# Sentence after removing stopwords: ['Operating', 'loss', 'EUR', '179mn', '', 'compared', 'loss', 'EUR', '188mn', 'second', 'quarter', '2009', '']
# Sentence after removing stopwords: ['The', 'sale', '', 'result', 'gain', 'EUR', '60', 'million', 'second', 'quarter', '2010', 'OriolaKD', '', 'supports', 'Finnish', 'company', 'strategy', 'focus', 'pharmaceutical', 'wholesale', 'retail', 'operations', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'totalled', 'EUR', '808', 'mn', '', 'compared', 'loss', 'EUR', '131', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['We', 'warmly', 'welcome', 'Satama', '', '', 'states', 'Jussi', 'Lansio', '', 'chairman', 'Board', '']
# Sentence after removing stopwords: ['This', 'new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties', '']
# Sentence after removing stopwords: ['Finnish', 'business', 'software', 'group', 'AffectoGenimap', 'Oyj', 'said', 'signed', 'agreement', 'acquire', 'shares', 'Swedish', 'sector', 'company', 'Intellibis', 'Ab', '12', 'mln', 'euro', '', '', '158', 'mln', '', 'debtfree', 'basis', '']
# Sentence after removing stopwords: ['Talvivaara', 'also', 'maintains', 'assumption', 'turning', 'cash', 'flow', 'positive', 'year', 'end', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['Dubai', 'Nokia', 'announced', 'launch', '', 'Comes', 'Music', '', '', 'groundbreaking', 'service', 'introduces', 'new', 'way', 'people', 'enjoy', 'music', '']
# Sentence after removing stopwords: ['Previously', '', 'EB', 'delivered', 'custom', 'solution', 'LG', 'Electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators', '']
# Sentence after removing stopwords: ['As', 'part', 'transaction', '', 'Mreal', 'Sappi', 'also', 'signed', 'longterm', 'agreement', 'supply', 'pulp', 'BCTMP', 'smaller', 'services', 'supplies', '']
# Sentence after removing stopwords: ['The', 'company', 'also', 'expects', 'sell', 'products', 'Russian', 'region', '']
# Sentence after removing stopwords: ['Nokia', 'continue', 'invest', 'future', 'development', 'Qt', 'benefit', 'users', '', 'Commercial', 'LGPL', '']
# Sentence after removing stopwords: ['21', 'December', '2010', '', 'Finnish', 'industrial', 'machinery', 'company', 'Wartsila', 'Oyj', 'Abp', 'HEL', '', 'WRT1V', 'said', 'yesterday', 'order', 'design', 'liquefied', 'natural', 'gas', 'LNG', 'powered', 'platform', 'supply', 'vessel', 'PSV', 'Norwegian', 'oil', 'service', 'provider', 'Eidesvik', 'Offshore', 'ASA', 'OSL', '', 'EIOF', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'Finland', '', 'Sept', '18', '', '2009', '', 'GLOBE', 'NEWSWIRE', '', '', 'Ixonos', 'Plc', 'expands', 'company', 'smartphone', 'RD', 'services', 'establishes', 'new', 'nextgeneration', 'smartphone', 'design', 'unit', 'connection', 'Ixonos', '', 'site', 'Jyvaeskylae', '']
# Sentence after removing stopwords: ['HELSINKI', 'AFX', '', 'KCI', 'Konecranes', 'said', 'raised', 'stake', 'MMH', 'Holdings', 'Inc', '', 'owner', 'USbased', 'Morris', 'Materials', 'Handling', '', '909', 'pct', '745', 'pct', '']
# Sentence after removing stopwords: ['Finnish', 'electronics', 'manufacturer', 'PKC', 'Group', 'Oyj', '', 'OMX', 'Helsinki', '', 'PKC1V', '', 'said', 'Wednesday', '', '31', 'December', '', 'completed', 'acquisition', 'MAN', 'Nutzfahrzeuge', 'AG', 'cable', 'harness', 'business', 'MAN', 'Star', 'Trucks', '', 'Buses', 'Spolka', 'zoo', 'Poland', '']
# Sentence after removing stopwords: ['Ramirent', 'Danish', 'subsidiary', 'Ramirent', 'AS', 'today', 'signed', 'agreement', 'acquire', 'business', 'assets', 'machinery', 'rental', 'company', 'Jydsk', 'Materiel', 'Udlejning', 'located', 'West', 'Jutland', '']
# Sentence after removing stopwords: ['This', 'assignment', 'strengthens', 'Poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry', '']
# Sentence after removing stopwords: ['Net', 'sales', 'revenue', 'per', 'passenger', 'expected', 'increase', '']
# Sentence after removing stopwords: ['The', 'Dutch', 'broker', 'noted', 'Nokian', 'Tyres', 'reported', 'good', 'first', 'quarter', '2006', '', 'line', 'consensus', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'margin', 'increased', '112', '', '117', '', '']
# Sentence after removing stopwords: ['In', 'JanuarySeptember', '2007', '', 'Finnlines', '', 'net', 'sales', 'rose', 'EUR', '5054', 'mn', 'EUR', '4735', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'While', 'concerns', 'remain', 'longer', 'term', '', 'size', 'scale', 'may', 'enable', 'Nokia', 'hold', 'newfound', 'margin', 'improvements', 'near', 'term', '', '', 'analyst', 'wrote', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', '', 'HEL', '', 'CTH1V', '', 'said', 'today', 'net', 'loss', 'narrowed', 'EUR', '500000', '', 'USD', '680000', '', 'last', 'quarter', '2010', 'EUR', '53', 'million', 'period', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Finnish', 'consumer', 'packaging', 'manufacturer', 'Huhtamaki', 'Oyj', 'said', 'swung', 'net', 'profit', '841', 'mln', 'euro', '', '1056', 'mln', 'first', 'nine', 'months', '2006', 'net', 'loss', '26', 'mln', 'euro', '', '33', 'mln', 'period', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'high', 'technology', 'provider', 'Vaahto', 'Group', 'reports', 'net', 'sales', 'EUR', '418', 'mn', 'accounting', 'period', 'September', '2007', '', 'February', '2008', '', 'increase', '112', '', 'year', 'earlier', '']
# Sentence after removing stopwords: ['By', 'implementing', 'software', 'Finnish', 'Army', 'aims', 'unify', 'improve', 'operations', 'application', 'areas', '', 'QPR', 'Software', 'stated', '']
# Sentence after removing stopwords: ['At', 'press', 'conference', '', 'Lattelecom', 'board', 'chairman', 'Nils', 'Melngailis', 'explained', 'Blackstone', 'chosen', 'experience', 'IT', 'sector', 'well', 'financial', 'strength', '']
# Sentence after removing stopwords: ['Finnish', 'pharmaceuticals', 'company', 'Orion', 'reports', 'profit', 'taxes', 'EUR', '700', 'mn', 'third', 'quarter', '2010', '', 'EUR', '549', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '06', 'mn', 'EUR', '04', 'mn', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '1034', 'mn', 'EUR', '232', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['The', 'OMX', 'Helsinki', '25', 'index', '092', 'pct', '251867', 'Helsinki', 'CAP', 'portfolio', 'index', '091', 'pct', 'higher', '471119', '']
# Sentence after removing stopwords: ['', 'ADPnews', '', '', 'Nov', '9', '', '2009', '', 'Four', 'companies', 'agreed', 'buy', 'combined', 'SEK', '59', 'billion', '', 'USD', '854mEUR', '5718', '', 'drug', 'stores', 'offered', 'sale', 'part', 'restructuring', 'Swedish', 'statedowned', 'pharmacy', 'monopoly', 'Apoteket', 'AB', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Lietuva', '', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'Kesko', 'Group', '', 'boosted', 'sales', '429', 'percent', '134', 'million', 'euros', '', 'VAT', 'inclusive', '']
# Sentence after removing stopwords: ['According', 'company', 'updated', 'strategy', 'years', '20092012', '', 'Basware', 'targets', 'longterm', 'net', 'sales', 'growth', 'range', '20', '', '40', '', 'operating', 'profit', 'margin', '10', '', '20', '', 'net', 'sales', '']
# Sentence after removing stopwords: ['Iggesunds', 'Bruk', 'Sweden', 'one', 'advanced', '', 'fully', 'integrated', 'pulp', 'paperboard', 'mills', 'world', '']
# Sentence after removing stopwords: ['UPMKymmene', 'working', 'closely', 'shipping', 'agents', 'reduce', 'fuel', 'consumption', 'greenhouse', 'gas', 'emissions', '']
# Sentence after removing stopwords: ['Metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'China', 'Lee', '', 'Man', 'Paper', 'Co', '']
# Sentence after removing stopwords: ['In', 'Q1', '2010', '', 'Bank', 'land', 'net', 'interest', 'income', 'increased', 'EUR', '91', 'mn', 'EUR', '97', 'mn', '']
# Sentence after removing stopwords: ['Separately', '', 'YIT', 'Corporation', 'Austrian', 'firm', 'E', 'AG', 'last', 'week', 'signed', 'agreement', 'sale', 'E', 'building', 'system', 'service', 'business', 'Germany', '', 'Austria', '', 'Poland', '', 'Czech', 'Republic', '', 'Hungary', 'Romania', 'EUR', '55', 'mln', '']
# Sentence after removing stopwords: ['Orders', 'received', 'grew', '55', '', 'yearonyear', 'EUR732m', '']
# Sentence after removing stopwords: ['Forestries', 'also', 'higher', '', 'driven', 'yesterday', 'bullish', 'analyst', 'comment', 'Stora', 'Enso', 'Dagens', 'Industri', '', 'dealers', 'said', '']
# Sentence after removing stopwords: ['The', 'group', 'expand', 'chain', 'include', '45', 'stores', '']
# Sentence after removing stopwords: ['Last', 'year', 'company', 'raised', 'turnover', 'approximately', '7', 'million', 'litas', 'EUR', '2', 'mln', '', '61', 'million', 'litas', '2004', '']
# Sentence after removing stopwords: ['Sales', 'expected', 'increase', 'end', 'year', '2006', '', 'however', '']
# Sentence after removing stopwords: ['Comparable', 'net', 'sales', 'expected', 'increase', '10', '', '2008', '', 'line', 'group', 'target', '']
# Sentence after removing stopwords: ['Kalmar', 'awarded', 'new', '5year', 'contract', 'supply', 'Rough', 'Terrain', 'Container', 'Handler', 'RTCH', '']
# Sentence after removing stopwords: ['The', 'company', 'also', 'featured', 'Ethibel', 'Pioneer', 'Investment', 'Register', 'included', 'Innovest', 'Global', '100', 'list', 'world', 'sustainable', 'corporations', '']
# Sentence after removing stopwords: ['In', 'AsiaPacific', 'region', '', 'Visa', 'Wave', 'available', 'Malaysia', '', 'Taiwan', 'South', 'Korea', 'expanded', 'Japan', 'Southeast', 'Asia', 'year', '', 'Jung', 'added', '']
# Sentence after removing stopwords: ['', 'Following', 'last', 'year', 'good', 'profit', 'development', '', 'entered', 'current', 'year', 'good', 'position', '']
# Sentence after removing stopwords: ['The', 'companies', 'agreed', 'longterm', 'cooperation', 'mechanise', 'harvesting', 'Stora', 'Enso', 'eucalyptus', 'plantations', 'Southern', 'China', '']
# Sentence after removing stopwords: ['Outotec', 'said', 'new', 'orders', 'worth', '4929', 'mln', 'eur', 'quarter', '', 'compared', '2404', 'mln', 'eur', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Sales', 'Department', 'Store', 'Division', 'Hobby', 'Hall', 'increased', '7', '', '', 'sales', 'clothing', 'store', 'subsidiary', 'Seppala', 'decreased', '4', '', '']
# Sentence after removing stopwords: ['Global', 'Banking', 'News', '', '28', 'September', '2010', 'Tieto', 'Corporation', 'Pohjola', 'Bank', '', 'PINK', '', 'POJLF', '', 'cooperate', 'SWIFT', 'services', '']
# Sentence after removing stopwords: ['Poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'Latin', 'America', '']
# Sentence after removing stopwords: ['Tekla', 'implement', 'renewal', 'software', 'versions', 'introduced', 'spring', '2011', '']
# Sentence after removing stopwords: ['Sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'EUR', '393', 'mn', '', 'EUR', '327', 'mn', '']
# Sentence after removing stopwords: ['', 'Operating', 'profit', 'rose', '269', '', 'EUR', '1058', '', '834', '', 'million', '']
# Sentence after removing stopwords: ['Then', '', 'said', 'contract', 'estimated', 'contribute', 'EUR150m', 'net', 'sales', '2010', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '1019', 'mn', 'EUR', '1007', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Mobile', 'phone', 'sales', 'rose', '25', '', '587', 'billion', 'euros', '', 'enterprise', 'solution', 'sales', 'dropped', '39', '', '186', 'million', 'euros', '']
# Sentence after removing stopwords: ['The', 'pilot', 'project', 'proved', 'RIFD', 'technology', 'ideal', 'purposes', '', '', 'comments', 'Olli', 'Saarinen', '', 'Material', 'Handling', 'Supervisor', 'Yara', '']
# Sentence after removing stopwords: ['The', 'robust', 'growth', 'result', 'inclusion', 'clothing', 'chain', 'Lindex', 'Group', 'December', '2007', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '5mn', 'EUR', '28', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['TELECOMWORLDWIRE7', 'April', '2006TJ', 'Group', 'Plc', 'sells', 'stake', 'Morning', 'Digital', 'Design', 'Oy', 'Finnish', 'IT', 'company', 'TJ', 'Group', 'Plc', 'said', 'Friday', '7', 'April', 'signed', 'agreement', 'selling', 'shares', 'Morning', 'Digital', 'Design', 'Oy', 'Edita', 'Oyj', '']
# Sentence after removing stopwords: ['CEO', 'company', 'Tarmo', 'Noop', 'said', 'growth', 'sale', 'premium', 'beers', 'biggest', '']
# Sentence after removing stopwords: ['Finnish', 'Bank', 'land', 'reports', 'operating', 'profit', 'rose', 'EUR', '213', 'mn', 'second', 'quarter', '2009', 'EUR', '61', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['The', 'respondents', 'praised', 'Finnair', 'reliability', '', 'Finnishness', '', 'understanding', 'target', 'group', '']
# Sentence after removing stopwords: ['South', 'African', 'Sappi', 'become', 'largest', 'foreign', 'forest', 'industry', 'company', 'operating', 'Finland', 'result', 'acquisition', 'Finnish', 'Mreal', 'Corporation', 'Graphic', 'Papers', 'Business', 'unit', '']
# Sentence after removing stopwords: ['Progress', 'Group', '', 'QPR', 'representative', 'Saudi', 'Arabia', 'North', 'Africa', '', 'signed', 'framework', 'agreement', 'long', 'term', 'strategic', 'relationship', 'ISE', '']
# Sentence after removing stopwords: ['NASDAQlisted', 'Yahoo', 'Inc', 'introduced', 'new', 'service', 'enables', 'Malaysians', 'take', 'favorite', 'Internet', 'content', 'services', 'mobile', 'phones', '']
# Sentence after removing stopwords: ['On', 'hand', '', 'Montevideo', 'said', 'two', 'mills', 'working', 'area', 'generate', 'jobs', '']
# Sentence after removing stopwords: ['In', 'accordance', 'strategy', '', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'South', 'Africa', 'October', '']
# Sentence after removing stopwords: ['We', 'position', 'pursue', 'novel', 'clinical', 'candidates', 'going', 'forward', '', '']
# Sentence after removing stopwords: ['Shareholders', 'Rakvere', 'Lihakombinaat', 'decided', 'favor', 'buyout', 'minority', 'shares', 'midJuly', '']
# Sentence after removing stopwords: ['Fiskars', '', '360yearold', 'global', 'business', 'best', 'known', 'orangehandled', 'scissors', '', 'expects', 'derive', 'synergies', 'EUR5', 'million', 'year', 'consolidating', 'certain', 'parts', 'housewares', 'division', 'two', 'compete', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'increased', '45', '', 'EUR', '314', 'mn', 'EUR', '300', 'mn', '2004', '']
# Sentence after removing stopwords: ['Microsoft', 'also', 'churned', 'courtship', '', 'agreeing', 'use', 'Navteq', 'mapping', 'service', '', 'offered', 'company', 'Nokia', 'bought', '', '81', 'billion', 'years', 'ago', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '04', 'mn', '', 'operating', 'loss', 'EUR', '08', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['The', 'apartment', 'block', 'welllocated', '', 'easy', 'reach', 'city', 'center', 'close', 'school', 'kindergarten', '']
# Sentence after removing stopwords: ['The', 'policy', 'also', 'aimed', 'making', 'companies', 'profitable', 'competitive', '']
# Sentence after removing stopwords: ['EBIT', 'excluding', 'nonrecurring', 'items', '', 'totalled', 'EUR', '678', 'mn', '', 'EUR', '381', 'mn', '']
# Sentence after removing stopwords: ['By', 'acquiring', 'RCP', '', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company', '']
# Sentence after removing stopwords: ['Lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'Kaluga', 'regional', 'administration', 'last', 'November', '']
# Sentence after removing stopwords: ['Finnish', 'telecoms', 'software', 'developer', 'Tecnomen', 'Oyj', 'said', 'December', '5', '', '2006', '', '33', 'mln', '', '25', 'mln', 'euro', '', 'order', 'supply', 'expansion', 'charging', 'messaging', 'systems', 'mobile', 'fixed', 'networks', 'Brasil', 'Telecom', '']
# Sentence after removing stopwords: ['', 'Very', 'recommendable', '', 'Nokian', 'Z', 'G2', 'according', '', 'ADAC', 'judgement', '', 'latest', 'summer', 'tyre', 'test', 'German', 'automobile', 'association', 'ADAC', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', '27', '', 'EUR', '5798', 'mn', 'EUR', '4572', 'mn', '2006', '']
# Sentence after removing stopwords: ['Finnish', 'IT', 'consultancy', 'Satama', 'Interactive', 'Oyj', 'posted', 'net', 'profit', '14', 'mln', 'euro', '', '20', 'mln', 'first', 'nine', 'months', '2007', '', 'compared', 'net', 'loss', '462000', 'euro', '', '664000', 'period', '2006', '']
# Sentence after removing stopwords: ['Rapala', 'said', 'estimates', 'make', 'savings', '12', 'mln', 'eur', 'year', 'centralising', 'French', 'operations', 'one', 'site', '']
# Sentence after removing stopwords: ['This', 'second', 'successful', 'effort', 'financial', 'investor', 'year', '']
# Sentence after removing stopwords: ['Net', 'sales', 'went', '1', '', 'yearonyear', 'EUR', '29', 'million', '', 'affected', 'business', 'acquisitions', '', 'realized', 'previous', 'financial', 'period', '', 'effect', 'EUR', '51', 'million', 'review', 'period', '']
# Sentence after removing stopwords: ['Its', 'market', 'share', 'widened', '4851', 'percent', '4831', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['And', 'broker', 'repeated', '', 'buy', '', 'rating', '', 'based', 'expectations', 'current', 'restructuring', 'lead', 'clear', 'improvement', 'performance', 'Europe', '2007', '']
# Sentence after removing stopwords: ['In', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'loss', 'narrowed', 'EUR415', '000', 'EUR7', '4', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Dubbed', 'Nokia', 'Money', 'Solutions', '', 'company', 'officials', 'say', 'initiative', 'would', 'seek', 'bridge', 'gap', 'banked', 'unbanked', 'developing', 'countries', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'owns', '43', 'percent', 'Bergvik', 'earns', 'therefore', 'SEK', '15', 'bn', 'value', 'appreciation', '']
# Sentence after removing stopwords: ['Latvenergo', 'ordered', 'significant', 'expansion', 'Tekla', 'Xpower', 'network', 'information', 'system', '']
# Sentence after removing stopwords: ['With', 'acquisition', 'Panostaja', 'Oyj', 'expands', 'business', 'area', 'specialising', 'digital', 'printing', '']
# Sentence after removing stopwords: ['Estonian', 'telecoms', 'company', 'Elisa', 'customer', 'numbers', 'cross', '400000', 'TALLINN', '', 'Oct', '22', '', 'BNS', '', 'The', 'Estonian', 'telecommunications', 'company', 'Elisa', 'approximately', '50000', 'new', 'clients', 'nine', 'months', 'year', '', 'bringing', 'number', '401800', 'end', 'September', '', 'company', 'said', '']
# Sentence after removing stopwords: ['DMASIA16', 'August', '2006Benefon', 'extends', 'manufacturing', 'capability', 'ASMobile', '', '2006', 'Digitalmediaasiacom', '', 'DMA', 'Ltd', '']
# Sentence after removing stopwords: ['OUTOTEC', 'OYJ', 'PRESS', 'RELEASE', 'DECEMBER', '4', '', '2009', '1030', 'AM', 'Outotec', 'establishes', 'new', 'subsidiary', 'Kolkata', 'Outotec', 'established', 'subsidiary', 'India', 'order', 'better', 'serve', 'Indian', 'customers', 'increase', 'business', 'growing', 'Indian', 'market', '']
# Sentence after removing stopwords: ['The', 'total', 'delivery', 'volume', 'paper', 'businesses', '2010', '1155000', 'tonnes', '', '1132000', 'tonnes', '2009', '']
# Sentence after removing stopwords: ['Loss', 'taxes', 'amounted', 'EUR', '12', 'mn', 'compared', 'loss', '26', 'mn', '']
# Sentence after removing stopwords: ['The', 'GeoSolutions', 'technology', 'leverage', 'Benefon', 'GPS', 'solutions', 'providing', 'Location', 'Based', 'Search', 'Technology', '', 'Communities', 'Platform', '', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model', '']
# Sentence after removing stopwords: ['Growth', 'expected', 'continue', '2008', '']
# Sentence after removing stopwords: ['Total', 'operating', 'revenue', 'grew', '276', '', 'yearonyear', 'EUR61m', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Feb', '11', '', '2009', '', 'Finnish', 'management', 'software', 'solutions', 'provider', 'Ixonos', 'Oyj', '', 'HEL', '', 'XNS1V', '', 'said', 'today', 'net', 'profit', 'rose', 'EUR', '35', 'million', '', 'USD', '45', '', '2008', 'EUR', '31', 'million', '2007', '']
# Sentence after removing stopwords: ['Stockmann', 'Swedish', 'sector', 'company', 'AB', 'Lindex', 'entered', 'agreement', 'September', '30', '', '2007', '', 'whereby', 'Stockmann', '', 'whollyowned', 'subsidiary', '', 'make', 'public', 'tender', 'offer', 'Lindex', 'issued', 'shares', '']
# Sentence after removing stopwords: ['However', '', 'bottomline', 'result', 'improved', 'thanks', 'positive', 'financial', 'items', '']
# Sentence after removing stopwords: ['The', 'contract', 'signed', 'August', 'Papua', 'New', 'Guineabased', 'Lihir', 'Gold', 'Ltd', 'ASX', '', 'LGL', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['The', 'company', 'operating', 'income', '', 'EBIT', '', 'totalled', 'EUR', '00', 'mn', '', 'EUR', '03', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Profitability', '', 'EBIT', '', '', '139', '', '', 'compared', '131', '', 'previousyear', 'period', '']
# Sentence after removing stopwords: ['', 'We', 'pleased', 'efforts', 'negotiating', 'teams', 'look', 'forward', 'productive', 'four', 'years', 'ahead', '', '']
# Sentence after removing stopwords: ['Componenta', 'increased', 'stake', 'Turkish', 'steel', 'company', 'Doktas', 'Dokumculuk', 'Ticaret', 'Sanayi', 'AS', '926', 'pct', 'stake', 'March', '2007', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['LONDON', 'AFX', '', 'Shares', 'Rautaruukki', 'Corp', 'upgraded', '', 'hold', '', '', 'sell', '', 'ABN', 'Amro', '', 'price', 'target', 'raised', '2575', 'eur', '145', '', 'said', 'dealers', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Dec', '11', '', '2008', '', 'Finnish', 'construction', 'engineering', 'company', 'Outotec', 'Oyj', '', 'OMX', '', 'OTE1V', '', 'said', 'today', 'EUR', '28', 'million', '', 'USD', '368', '', 'order', 'expand', 'phosphate', 'concentrator', 'Siilinjarvi', 'Norwegian', 'minera']
# Sentence after removing stopwords: ['services', 'supplier', 'Efore', 'Plc', 'streamline', 'operations', 'Finland', 'US', 'Finnish', 'electronic', 'systems', 'services', 'supplier', 'Efore', 'Plc', '', 'OMX', 'Helsinki', '', 'EFO1V', '', 'said', 'Tuesday', '', '3', 'February', '', 'initiated', 'statutory', 'negotiations', 'regarding', 'streamlining', 'operations', 'Finland', '']
# Sentence after removing stopwords: ['However', '', 'total', 'orders', 'received', 'still', 'last', 'year', 'levels', '']
# Sentence after removing stopwords: ['SysOpen', 'Digia', 'signed', 'agreement', 'main', 'shareholders', 'Sentera', 'holding', 'total', '7739', '', 'share', 'capital', 'votes', 'Sentera', '']
# Sentence after removing stopwords: ['According', 'CEO', 'Nordea', 'Bank', 'Estonia', 'Vahur', 'Kraft', '', 'Nordea', 'Finland', 'Stockmann', 'cooperating', 'ten', 'years', '']
# Sentence after removing stopwords: ['The', 'Bristol', 'Port', 'Company', 'sealed', 'one', 'million', 'pound', 'contract', 'Cooper', 'Specialised', 'Handling', 'supply', 'four', '45tonne', '', 'customised', 'reach', 'stackers', 'Konecranes', '']
# Sentence after removing stopwords: ['In', 'autumn', '', 'plans', 'expand', 'service', 'St', 'Petersburg', 'Moscow', 'launch', 'service', 'Yekaterinburg', '', 'Russia', '', 'flying', 'three', 'times', 'week', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafers', 'manufacturer', 'Okmetic', 'Oyj', 'said', 'June', '29', '', '2007', 'signed', 'agreement', 'Nordea', 'Bank', 'Finland', 'Plc', '', 'local', 'subsidiary', 'Swedish', 'commercial', 'bank', 'Nordea', 'Bank', 'AB', '', 'refinance', 'Okmetic', 'syndicated', 'bank', 'facility', 'amounts', '20', 'mln', 'euro', '', '', '269', 'mln', '', '']
# Sentence after removing stopwords: ['We', 'capitalize', 'experience', 'number', 'similar', 'bridge', 'projects', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['Managing', 'Director', 'Kari', 'Inkinen', 'says', 'Sponda', 'leasing', 'operations', 'developed', 'highly', 'favourably', '']
# Sentence after removing stopwords: ['GeoSentric', 'Oyj', 'GeoSolutions', 'Business', 'Unit', 'GyPSii', '', 'mobile', 'digital', 'lifestyle', 'application', 'geomobility', 'social', 'networking', 'platform', '', 'signed', 'agreement', 'Nanjing', 'MyNet', 'make', 'GyPSii', 'mobile', 'social', 'networking', 'platform', 'available', 'customers', 'China', 'Mobile', '']
# Sentence after removing stopwords: ['It', 'also', 'turned', 'earnings', 'per', 'share', '', 'EPS', '', 'EUR', '044', 'versus', 'loss', 'per', 'share', 'EUR', '226', '']
# Sentence after removing stopwords: ['Tallink', 'claims', 'watertight', 'doors', 'Vana', 'Tallinn', 'Regina', 'Baltica', '', 'including', 'electrical', 'systems', '', 'fully', 'working', 'order', '']
# Sentence after removing stopwords: ['The', '5050', 'joint', 'venture', '', 'called', 'Nokia', 'Siemens', 'Networks', '', 'comprised', 'Nokia', 'network', 'business', 'group', 'Siemens', '', 'carrierrelated', 'operations', '', 'creating', 'estimated', 'synergies', '15', 'billion', 'euros', '', '', '19', 'billion', '', '2010', '', 'Nokia', 'said', '']
# Sentence after removing stopwords: ['In', 'banking', '', 'Sampo', 'A', 'unchanged', '1424', 'eur', 'Nordea', 'rose', '042', 'pct', '951', 'eur', '']
# Sentence after removing stopwords: ['Finnish', 'Raisio', '', 'Diagnostics', '', 'launching', 'new', 'DNAbased', 'quick', 'tests', 'ensure', 'safety', 'food', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '830', 'mn', '', 'EUR', '235', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Pearl', 'Plaza', 'LLC', '', 'joint', 'venture', 'SRV', 'Shanghai', 'Industrial', 'Investment', 'Holdings', 'Co', 'Ltd', '', 'concluded', 'investment', 'decision', 'construction', 'first', 'phase', 'shopping', 'center', 'Saint', 'Petersburg', '', 'Russia', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['Alma', 'Media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously', '']
# Sentence after removing stopwords: ['Exports', 'accounted', '654', '', 'net', 'sales', '', 'representing', 'time', 'record', 'company', '']
# Sentence after removing stopwords: ['Construction', 'volumes', 'meanwhile', 'grow', 'rate', '1015', 'percent', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'mobile', 'operator', 'DNA', 'function', 'subcontractor', 'Maingate', 'responsible', 'telecommunications', 'connections', '']
# Sentence after removing stopwords: ['The', 'Group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets', '']
# Sentence after removing stopwords: ['Outotec', 'net', 'profit', 'second', 'quarter', '2007', 'jumped', '168', 'mln', 'euro', '', '', '231', 'mln', '', '46', 'mln', 'euro', '', '', '63', 'mln', '', 'year', 'ago', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'guided', 'EBIT', 'sales', 'growth', '20', 'pct', '10', 'pct', 'respectively', 'year', '']
# Sentence after removing stopwords: ['According', 'Nordic', 'financial', 'group', 'Nordea', 'analyst', 'Sami', 'Sarkamies', '', 'makes', 'Nokia', 'portfolio', 'competitive', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Significance', '', 'Teleste', 'emphasised', 'large', 'size', 'growing', 'economy', '', 'well', 'rapid', 'development', 'TV', 'services', 'distribution', 'industry', '', 'Poland', 'viewed', 'attractive', 'market', '']
# Sentence after removing stopwords: ['The', 'energyefficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'stateoftheart', 'technology', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Retail', 'wholesale', 'group', 'Kesko', 'reported', 'net', 'sales', '6594', 'mln', 'eur', 'February', '', 'increase', '108', 'pct', 'yearonyear', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', 'higher', '048', '037', 'year', 'ahead', 'market', 'consensus', '040', 'eur', '']
# Sentence after removing stopwords: ['Sanoma', 'Magazines', 'Finland', 'net', 'sales', 'grew', 'EUR', '1401', 'mn', 'EUR', '1318', 'mn', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'part', 'Ramirent', 'strategy', 'strengthen', 'position', 'selected', 'locations', '']
# Sentence after removing stopwords: ['It', 'estimates', 'operating', 'profit', 'improve', 'third', 'quarter', '']
# Sentence after removing stopwords: ['Ragutis', '', 'controlled', 'Finnish', 'brewery', 'Olvi', '', 'achieved', '57', 'percent', 'rise', 'beer', 'sales', '226', 'million', 'liters', 'held', '1075', 'percent', 'market', 'share', '']
# Sentence after removing stopwords: ['TomTom', 'given', 'assurances', 'continue', 'sell', 'maps', 'competitors', 'wins', 'EU', 'approval', '']
# Sentence after removing stopwords: ['For', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'profit', 'rose', 'EUR41m', 'EUR30m', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Exports', 'grew', '165', 'percent', '191', 'million', 'liters', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Diluted', 'loss', 'per', 'share', 'stood', 'EUR', '015', 'versus', 'EUR', '026', '']
# Sentence after removing stopwords: ['Nokia', '012', 'pct', '1670', 'eur', 'kicking', 'morning', 'negative', 'territory', '']
# Sentence after removing stopwords: ['The', 'borrower', 'happy', 'roadshow', 'paid', 'hit', 'ratio', 'high', '']
# Sentence after removing stopwords: ['Adjusted', 'changes', 'Group', 'structure', '', 'Division', 'net', 'sales', 'increased', '17', '', '']
# Sentence after removing stopwords: ['Cision', 'says', 'sale', 'return', 'UK', 'operation', 'profitability', '']
# Sentence after removing stopwords: ['Finnish', 'Okmetic', 'manufactures', 'processes', 'silicon', 'wafers', 'semiconductor', 'sensor', 'industries', 'Norwegian', 'solar', 'wafer', 'company', 'NorSun', 'signed', 'contract', 'Okmetic', 'supply', 'NorSun', 'mono', 'silicon', 'crystals', 'use', 'solar', 'cell', 'manufacturing', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafer', 'technology', 'company', 'Okmetic', 'Oyj', 'OMX', 'Helsinki', '', 'OKM1V', 'reported', 'Thursday', '30', 'October', 'operating', 'profit', 'EUR7', '4', 'JanuarySeptember', '2008', '', 'EUR6', '1', 'corresponding', 'period', '2007', '']
# Sentence after removing stopwords: ['Also', '', 'bringing', '', 'right', 'kind', 'people', '', 'upgrade', 'human', 'resources', '']
# Sentence after removing stopwords: ['About', 'Elcoteq', 'Elcoteq', 'SE', 'leading', 'electronics', 'manufacturing', 'services', '', 'EMS', '', 'company', 'communications', 'technology', 'field', '']
# Sentence after removing stopwords: ['Mr', 'Priit', 'Kasak', '', 'Balti', 'Metsamasina', 'owner', '', 'said', 'Rakverebased', 'company', 'wishes', 'increase', 'Valmet', 'market', 'share', '27', '', 'third', 'couple', 'years', '']
# Sentence after removing stopwords: ['Finland', 'Nokian', 'Tyres', 'Kazakhstan', 'Ordabasy', 'Corporation', 'signed', 'agreement', 'build', 'plant', 'Astana', 'produce', 'car', 'tires', '', 'Ordabasy', 'chairman', 'Dinmukhamet', 'Idrisov', 'said', 'press', 'conference', '']
# Sentence after removing stopwords: ['The', 'company', 'expects', 'net', 'sales', 'first', 'half', '2008', 'reach', 'previous', 'year', 'level', '']
# Sentence after removing stopwords: ['Ruukki', 'announced', 'signed', 'agreement', 'Aker', 'Solutions', 'Norway', 'supply', '24', 'suction', 'anchors', 'September', '2010', 'Kalajoki', 'unit', 'Finland', '']
# Sentence after removing stopwords: ['AUSTIN', '', 'Texas', '', 'Sept', '6', '', 'Texas', 'Department', 'Of', 'Transportation', 'awards', 'contract', 'Teleste', 'Video', 'Compression', 'Distribution', 'Equipment', '']
# Sentence after removing stopwords: ['The', 'price', 'raw', 'material', 'aluminium', 'went', 'end', '2005', '', 'company', 'considers', 'outlook', '2006', 'favourable', '']
# Sentence after removing stopwords: ['Finnish', 'automation', 'solutions', 'developer', 'Cencorp', 'Corporation', '', 'OMX', 'Helsinki', '', 'CNC1V', '', 'said', 'Friday', '', '27', 'June', '', 'completed', 'employee', 'negotiations', 'regarding', 'reorganisation', 'operations', '']
# Sentence after removing stopwords: ['The', 'company', 'committed', 'expanding', 'Apollo', 'portfolio', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'Nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout', '']
# Sentence after removing stopwords: ['The', 'company', 'moved', 'operating', 'profit', 'EUR10', '9', 'versus', 'operating', 'loss', 'EUR15', '3', 'It', 'also', 'turned', 'EPS', 'EUR0', '08', 'versus', 'loss', 'per', 'share', 'EUR0', '04', '']
# Sentence after removing stopwords: ['The', 'increase', 'capital', 'stock', 'registered', 'Finnish', 'Trade', 'Register', '20', 'November', '2006', '']
# Sentence after removing stopwords: ['Basware', 'Corporation', 'stock', 'exchange', 'release', 'August', '31', '', '2010', '1625', 'Basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'Basware', 'deliver', 'Invoice', 'Automation', 'solution', 'Connectivity', 'Services', 'international', 'industrial', 'group', '']
# Sentence after removing stopwords: ['20', 'October', '2010', '', 'Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', 'HEL', '', 'CTH1V', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'EUR7m', 'first', 'nine', 'months', '2010', 'EUR23', '3', 'period', '2009', '']
# Sentence after removing stopwords: ['In', 'January', '', 'traffic', '', 'measured', 'revenue', 'passenger', 'kilometres', 'RPK', '', 'went', '32', '', 'capacity', '', 'measured', 'available', 'seat', 'kilometres', 'ASK', '', 'rose', '122', '', '']
# Sentence after removing stopwords: ['Lule', 'municipality', 'awarded', 'YIT', '2year', 'contract', '', 'property', 'management', 'one', 'third', 'municipality', 'properties', '', 'total', 'area', '140000', 'sq', 'metres', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'jumped', 'EUR', '219', 'million', 'EUR', '31', 'million', '']
# Sentence after removing stopwords: ['Tekla', 'Structures', 'BIM', 'Building', 'Information', 'Modeling', 'software', 'developed', 'according', 'longterm', 'plan', 'improved', 'user', 'experience', '', 'process', '', 'functionality', '']
# Sentence after removing stopwords: ['Industry', 'Investment', 'interested', 'Glaston', 'solar', 'energy', 'projects', '']
# Sentence after removing stopwords: ['Sales', 'improved', 'SEK', '1553', 'mn', '', 'compared', 'SEK', '1408', 'mn', '']
# Sentence after removing stopwords: ['It', 'leading', 'private', 'road', 'ambulance', 'service', 'company', 'Finland', '']
# Sentence after removing stopwords: ['The', 'decision', 'sell', 'share', 'Lenenergo', 'reached', 'line', 'Fortum', 'strategic', 'plans', 'invest', 'mainly', 'generating', 'assets', 'Russia', '', 'Lenenergo', 'grid', 'company', '', 'press', 'release', 'said', '']
# Sentence after removing stopwords: ['It', 'projected', 'revenue', '', '22', 'billion', '', '23', 'billion', '', 'slightly', 'higher', 'analyst', 'estimates', '', '219', 'billion', '']
# Sentence after removing stopwords: ['These', 'measures', 'expected', 'produce', 'annual', 'cost', 'savings', 'EUR', '15', 'million', 'starting', '2007', '']
# Sentence after removing stopwords: ['', 'I', 'happy', 'outcome', '', '', 'Sneed', 'said', 'hearing', '']
# ...
# Sentence after removing stopwords: ['Net', 'sales', '2006', 'totaled', 'EUR', '302', 'million', 'operating', 'margin', '16', '', '']
# Sentence after removing stopwords: ['The', 'Bank', 'land', 'acquired', 'private', 'banking', 'business', '', 'asset', 'management', '', 'share', 'brokerage', 'business', 'Kaupthing', 'Sweden', 'early', '2009', '']
# Sentence after removing stopwords: ['Quality', 'chargers', 'CHARGZ', 'brand', 'sold', 'selected', 'retail', 'stores', 'sales', 'locations', 'worldwide', '']
# Sentence after removing stopwords: ['industry', 'Asia', '\x88', 'Pakistan', '', 'Malaysia', '', 'Taiwan', 'Philippines', 'Today', '', 'Global', 'Research', '', 'Data', 'Services', 'going', 'publish', 'several', 'market', 'analyses', 'cement', 'markets', 'Asia', '']
# Sentence after removing stopwords: ['Glaston', 'wellknown', 'brands', 'Bavelloni', '', 'preprocessing', 'machines', 'tools', '', 'Tamglass', 'Uniglass', 'safety', 'glass', 'machines', 'Albat', '', 'Wirsam', 'software', 'solutions', '']
# Sentence after removing stopwords: ['A', 'Le', 'Coq', 'market', 'share', '413', 'percent', 'rival', 'beverage', 'group', 'Saku', '321', 'percent', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'June', '7', '', 'Michael', 'G', 'Williams', 'Newbury', 'Park', '', 'Calif', '', 'developed', 'network', 'device', '']
# Sentence after removing stopwords: ['', 'They', 'already', 'allocated', 'money', 'inventory', '']
# Sentence after removing stopwords: ['The', 'value', 'threeyear', 'contract', 'estimated', 'EUR40m', '']
# Sentence after removing stopwords: ['Each', 'option', 'right', 'entitles', 'holder', 'subscribe', 'one', 'new', 'share', 'subscription', 'price', 'EUR0', '045', 'subscription', 'period', 'ends', '31', 'December', '2013', '']
# Sentence after removing stopwords: ['Kaukopartio', 'Oy', 'acquired', 'specialized', 'knowledge', 'Far', 'Eastern', 'operations', '', 'industrial', 'sourcing', 'services', 'core', 'competence', '']
# Sentence after removing stopwords: ['The', 'value', 'orders', 'EUR', '25mn', '']
# Sentence after removing stopwords: ['The', 'owners', 'participated', 'business', 'operations', 'company', 'continue', 'Poyry', 'employment', 'transaction', '']
# Sentence after removing stopwords: ['Nokian', 'Tyres', '', 'tyres', 'considered', 'genuine', 'winter', 'tyres', 'Russia', '']
# Sentence after removing stopwords: ['Mr', 'McDonald', 'started', 'evening', 'set', '', 'featuring', 'hits', 'solo', 'career', 'Doobie', 'Brothers', 'years', 'selection', 'RB', 'cover', 'songs', 'met', 'mixed', 'results', '']
# Sentence after removing stopwords: ['Nokia', 'said', 'outcome', '', 'fair', 'responsible', 'social', 'plan', '', '']
# Sentence after removing stopwords: ['AffectoGenimap', 'builds', 'highly', 'customised', 'IT', 'solutions', 'customers', 'Finland', 'Baltic', 'countries', '']
# Sentence after removing stopwords: ['Votorantim', 'Celulose', 'e', 'Papel', '', 'VCP', '', 'part', 'Votorantim', 'Group', '', 'major', 'Brazilian', 'conglomerate', '']
# Sentence after removing stopwords: ['She', 'succeed', 'Krister', 'Kylas', '', 'decided', 'leave', 'TeliaSonera', '']
# Sentence after removing stopwords: ['The', 'dividend', 'paid', 'April', '15', '', '2008', 'shareholders', 'record', 'date', 'April', '8', '', '2008', 'entered', 'list', 'shareholders', 'kept', 'Finnish', 'Central', 'Securities', 'Depository', 'Ltd', '']
# Sentence after removing stopwords: ['Unbelievably', '', 'company', 'makes', '', 'Fiskars', 'Corporation', '', 'formed', '1649', 'Dutch', 'merchant', 'named', 'Peter', 'Thorwoste', 'given', 'charter', 'establish', 'blast', 'furnace', 'forging', 'operation', 'small', 'Finnish', 'village', 'Fiskars', '']
# Sentence after removing stopwords: ['The', 'number', 'class', 'A', 'shares', 'remains', 'unchanged', '9526089', 'shares', '']
# Sentence after removing stopwords: ['HELSINKI', 'AFX', '', 'Cargotec', 'said', 'bought', '95', 'pct', 'stake', 'Indital', 'Construction', 'Machinery', 'Ltd', '', 'Bangalorebased', 'company', 'makes', 'fork', 'lift', 'trucks', 'mobile', 'cranes', '', 'undisclosed', 'sum', '']
# Sentence after removing stopwords: ['Finnish', 'fibers', 'plastics', 'producer', 'Suominen', 'Corporation', 'OMX', 'Helsinki', '', 'SUY1V', 'reported', 'Wednesday', '22', 'October', 'operating', 'loss', 'EUR0', '8', 'net', 'sales', 'EUR55', '2', 'third', 'quarter', '2008', '']
# Sentence after removing stopwords: ['Swedish', 'telco', 'TeliaSonera', 'teaming', 'Friends', '', 'Swedish', 'organization', 'bullying', '', 'fight', 'bullying', 'children', 'teenagers', 'via', 'electronic', 'channels', '']
# Sentence after removing stopwords: ['Sanoma', 'also', 'Executive', 'Committee', '', 'accordance', 'Company', 'Articles', 'Association', '', 'prepares', 'proposals', 'matters', 'decided', 'noted', 'Board', 'Directors', '']
# Sentence after removing stopwords: ['3G', 'data', 'subscribers', 'also', 'helping', 'maintain', 'growth', 'levels', '', 'since', 'dataonly', 'subscriptions', 'push', 'multiple', 'SIM', 'ownership', '']
# Sentence after removing stopwords: ['', 'Printed', 'fabrics', 'related', 'design', 'expertise', 'always', 'core', 'Marimekko', 'business', 'brand', '']
# Sentence after removing stopwords: ['Feed', 'companies', 'Suomen', 'Rehu', 'Raisio', 'import', 'GMO', 'feed', '']
# Sentence after removing stopwords: ['The', 'engine', 'electrical', 'output', '18321', 'kW', '', 'making', 'largest', 'gas', 'powered', 'generating', 'set', 'world', '']
# Sentence after removing stopwords: ['This', 'lays', 'foundation', 'sustainable', 'business', 'development', 'long', 'term', '']
# Sentence after removing stopwords: ['The', 'Committee', 'proposes', 'following', 'remuneration', '', 'monthly', 'remuneration', 'EUR', '5000', 'Chairman', '', 'EUR', '3500', 'Deputy', 'Chairman', '', 'EUR', '2500', 'Board', 'members', '']
# Sentence after removing stopwords: ['Risto', 'Jalo', '', 'chief', 'executive', 'Dormus', 'Print', 'also', 'owner', 'remainder', 'company', '', 'keep', 'position', 'acquisition', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'Oct', '15', '', 'Aaron', 'Moss', 'Hampshire', '', 'Great', 'Britain', '', 'developed', 'ornamental', 'design', 'handset', '', 'US', 'Patent', '', 'Trademark', 'Office', 'announced', '']
# Sentence after removing stopwords: ['Yvonne', 'Jones', 'owner', 'Chameleon', 'Interiors', '']
# Sentence after removing stopwords: ['Citigroup', '', 'Inc', 'NYSE', '', 'C', '', 'Deutsche', 'Bank', 'NYSE', '', 'DB', 'Pohjola', 'Bank', 'lead', 'managers', 'sale', '']
# Sentence after removing stopwords: ['At', 'beginning', 'subscription', 'period', 'May', '2', '', '2006', 'share', 'subscription', 'price', 'B', 'option', 'right', 'EUR', '1022', 'per', 'share', '']
# Sentence after removing stopwords: ['In', '2005', 'bank', 'posted', 'net', 'profit', 'Lt', '82', 'mn', '']
# Sentence after removing stopwords: ['The', 'company', 'earlier', 'said', 'considering', 'different', 'strategic', 'options', 'struggling', 'lowcost', 'mobile', 'operator', '', 'including', 'divestment', 'holding', '']
# Sentence after removing stopwords: ['The', 'two', 'sellers', 'Finnish', 'National', 'Fund', 'RD', '', 'Sitra', '', 'Oras', 'Invest', 'Oy', '', 'also', 'sold', 'half', 'shareholdings', '', 'leaving', '38', 'pct', '32', 'pct', 'company', 'respectively', '']
# Sentence after removing stopwords: ['According', 'Gallup', 'Food', 'Farm', 'Facts', '', 'beef', 'consumption', 'totaled', '99mn', 'kilos', 'Finland', '2007', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'Alma', 'Media', 'focus', 'quality', 'developing', 'chain', 'operations', '']
# Sentence after removing stopwords: ['mr', 'Bakman', 'sees', 'also', 'expansion', 'options', 'TallinnHelisnki', 'link', '', 'claiming', 'however', '', 'operating', 'link', 'single', 'ship', 'enough', '']
# Sentence after removing stopwords: ['Since', 'registration', 'shares', 'subscribed', 'directed', 'share', 'issue', '', 'new', 'number', 'Panostaja', 'shares', 'voting', 'rights', '41733110', '']
# Sentence after removing stopwords: ['The', 'inaugural', 'speech', 'given', 'Hannu', 'Kyrolainen', '', 'Finland', 'Ambassador', 'Czech', 'Republic', '']
# Sentence after removing stopwords: ['Following', 'issue', '', 'new', 'shares', 'constitute', '10', 'percent', 'firm', 'capital', '']
# Sentence after removing stopwords: ['The', 'decision', 'made', 'whether', 'group', 'agrees', 'import', 'Estonian', 'meat', 'meat', 'products', 'Finland', '', 'paper', 'added', '']
# Sentence after removing stopwords: ['Measures', 'launched', 'immediately', 'due', 'finalized', 'first', 'quarter', '2010', '']
# Sentence after removing stopwords: ['', 'Our', 'approach', 'much', 'use', 'raw', 'materials', 'produced', 'line', 'principles', 'sustainable', 'development', '']
# Sentence after removing stopwords: ['With', 'second', 'phase', 'new', 'Innova', 'building', '', 'Tecnopolis', 'presence', 'Jyvaskyla', 'increase', 'total', 'approximately', '62000', 'floor', 'square', 'meters', '']
# Sentence after removing stopwords: ['Country', '', '', 'Germany', 'Sector', '', 'ConstructionReal', 'Estate', '', 'MachineryEngineering', 'Target', '', 'Caverion', 'GmbH', 'Buyer', '', 'YIT', 'Oyj', 'Deal', 'size', 'USD', '', '903', 'Type', '', 'Corporate', 'acquisition', 'Status', '', 'Agreed']
# Sentence after removing stopwords: ['Pharmaceutical', 'market', 'Netherlands', 'Global', 'Research', '', 'Data', 'Services', 'published', 'recently', 'market', 'analysis', 'pharmaceutical', 'markets', 'Netherlands', '']
# Sentence after removing stopwords: ['It', 'even', 'little', 'bit', 'higher', 'Yara', 'multiples', '', '', 'analyst', 'Helsinki', 'said', '']
# Sentence after removing stopwords: ['Finnish', 'plumbing', 'heating', 'systems', 'supplier', 'Uponor', 'announced', 'companywide', 'cost', 'reduction', 'program', 'August', '2008', '']
# Sentence after removing stopwords: ['Finnish', 'diversified', 'holding', 'company', 'Aspo', 'Oyj', 'said', 'September', '8', '', '2008', 'sell', 'Finnish', 'tape', 'business', 'Kaukomarkkinat', 'unit', 'local', 'Oy', 'Telpak', 'Ab', '']
# Sentence after removing stopwords: ['The', 'Polish', 'business', 'employs', '1000', 'people', '', 'net', 'sales', 'EUR', '70mn', '2007', '']
# Sentence after removing stopwords: ['The', 'reductions', 'implemented', 'immediately', '', 'beginning', 'October', '2009', '']
# Sentence after removing stopwords: ['The', 'company', '120', 'employees', 'annual', 'sales', 'approximately', 'EUR16m', '']
# Sentence after removing stopwords: ['Finnish', 'glass', 'technology', 'group', 'Glaston', 'Corporation', '', 'OMX', 'Helsinki', '', 'GLA1V', '', 'reported', 'Thursday', '', '14', 'August', '', 'operating', 'profit', 'EUR6', '5', 'net', 'sales', 'EUR201', '5', 'period', 'JanuarySeptember', '2008', '']
# Sentence after removing stopwords: ['', 'Nordea', 'definitely', 'big', 'Sampo', 'acquire', '', '', 'said', 'analyst', '', 'But', 'Sampo', 'would', 'appear', 'agenda', 'Nordea', 'ahead', 'privatisation', '']
# Sentence after removing stopwords: ['Bertrand', 'Sciard', 'vice', 'chairman', 'board', 'directors', 'Aldata', 'Solution', 'since', 'April', '2007', '']
# Sentence after removing stopwords: ['The', 'webcast', 'may', 'followed', 'online', 'company', 'website', 'wwwruukkicominvestors', '']
# Sentence after removing stopwords: ['In', 'Sweden', '', 'Gallerix', 'accumulated', 'SEK', 'denominated', 'sales', '1', '', 'EUR', 'denominated', 'sales', '11', '', '']
# Sentence after removing stopwords: ['Cramo', '', 'headquartered', 'Vantaa', '', 'Finland', '', 'rents', 'construction', 'machinery', 'equipment', '', 'well', 'rents', 'sells', 'modular', 'space', '']
# Sentence after removing stopwords: ['The', 'first', 'phase', 'logistics', 'complex', 'envisages', 'completion', '70000', 'sq', 'logistics', 'premises', 'gatehouse', 'building', 'November', '2008', '']
# Sentence after removing stopwords: ['The', 'proposal', 'shareholders', 'elect', 'Mr', 'Hannu', 'Krogerus', 'Board', 'based', 'long', 'unrivalled', 'experience', 'knowledge', 'matters', 'related', 'Elcoteq', '']
# Sentence after removing stopwords: ['', 'We', 'license', 'agreement', 'Nokia', 'Corp', 'part', 'expires', 'April', '9', '', '2007', '']
# Sentence after removing stopwords: ['The', 'platform', 'would', 'continue', 'development', 'framework', 'Symbian', 'MeeGo', '']
# Sentence after removing stopwords: ['The', 'new', 'Kroksberg', 'railway', 'tunnel', 'built', 'new', 'section', 'track', 'Harnosand', 'Veda', '', 'forming', 'part', 'line', 'follows', 'coast', 'Gulf', 'Bothnia', '']
# Sentence after removing stopwords: ['The', 'energy', 'sector', 'accounted', 'approximately', '33', '', 'steel', 'industry', '57', '', 'transportation', 'volume', '']
# Sentence after removing stopwords: ['Currently', 'Alfred', 'A', 'Palmberg', 'putting', 'finishing', 'touches', 'one', 'Finland', 'biggest', 'ever', 'replumbing', 'bathroom', 'refurbishment', 'projects', 'also', 'district', 'Vuosaari', '']
# Sentence after removing stopwords: ['The', 'prices', 'stainless', 'steel', 'also', 'rose', 'Europe', '']
# Sentence after removing stopwords: ['In', 'release', 'Oct', '28', '', 'Peab', 'said', 'two', 'businesses', 'continue', 'conducted', 'brands', 'Cliffton', 'Stockholm', 'Entreprenad', '', 'part', 'Peab', 'Group', '']
# Sentence after removing stopwords: ['We', 'serve', 'broad', 'range', 'customers', '', 'including', 'construction', 'process', 'industries', '', 'shipyards', '', 'public', 'sector', 'households', '']
# Sentence after removing stopwords: ['', 'Tweeple', 'check', 'following', '', 'cautious', 'clicking', 'URLs', 'tinyurls', '', '']
# Sentence after removing stopwords: ['Cargotec', 'sales', 'totalled', 'EUR', '34', 'billion', '2008', 'employs', 'approximately', '10500', 'people', '']
# Sentence after removing stopwords: ['The', 'expanded', 'plant', 'scheduled', 'operational', 'middle', 'October', '2009', '']
# Sentence after removing stopwords: ['The', 'machines', 'cease', 'production', 'end', 'February', '2007', '']
# Sentence after removing stopwords: ['All', 'rights', 'reserved', '']
# Sentence after removing stopwords: ['The', 'company', 'studying', 'feasibility', 'focusing', 'processed', 'meat', 'production', 'Vantaa', 'facilities', 'processing', 'fresh', 'meat', 'Forssa', 'facilities', '']
# Sentence after removing stopwords: ['The', 'opportunity', 'available', 'employees', '', 'however', '']
# Sentence after removing stopwords: ['The', 'broadbased', 'WIG', 'index', 'ended', 'Thursday', 'session', '01', 'pct', '6500334', 'pts', '', 'bluechip', 'WIG20', '113', '368715', 'pts', '']
# Sentence after removing stopwords: ['The', 'bank', 'leasing', 'arm', 'Nordea', 'Liising', 'ended', 'year', 'profit', '44', 'million', 'euros', '']
# Sentence after removing stopwords: ['To', 'number', 'one', 'means', 'creating', 'added', 'value', 'stakeholders', 'everything', '']
# Sentence after removing stopwords: ['The', 'companies', 'divest', 'UPM', 'Fray', 'Bentos', 'pulp', 'mill', 'Forestal', 'Oriental', '', 'company', 'specialising', 'eucalyptus', 'cultivation', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'produces', 'many', 'turkey', 'products', '', 'cold', 'cuts', '']
# Sentence after removing stopwords: ['Mr', 'Kari', 'Stadigh', 'carry', 'Chairman', 'Board', 'Mr', 'Matti', 'Arteva', 'ViceChairman', '']
# Sentence after removing stopwords: ['The', 'Russian', 'government', 'contribute', '20', '', 'necessary', 'funds', '', 'said', '']
# Sentence after removing stopwords: ['Nordstjernan', 'used', 'option', 'buy', 'another', '224', '', 'stake', 'Salcomp', 'shares', 'votes', '']
# Sentence after removing stopwords: ['Mreal', 'Corporation', 'Stock', 'Exchange', 'Announcement', '29', 'September', '2006', '415', 'pm', 'Kyro', 'Corporation', 'Mreal', 'Corporation', '', 'Metsaliitto', 'Group', 'subsidiary', '', 'agreed', 'arrangement', 'gives', 'Mreal', 'option', 'purchase', 'Kyroskoski', 'natural', 'gas', 'powerplant', 'Kyro', '']
# Sentence after removing stopwords: ['Its', 'total', 'annual', 'revenue', 'comes', '160', 'mln', 'zloty', '', '', '569', 'mln42', '3', 'mln', 'euro', '', '']

# %%
positiveValues
#output is a dictionary-list of words in news column and the count of each of these words in train dataset where sentiment=positive
# Out:
# defaultdict(int,
#             {'The': 165,
#              'concept': 2,
#              'enables': 5,
#              'commercially': 3,
#              'affordable': 1,
#              'way': 4,
#              'manufacture': 1,
#              'highquality': 2,
#              'TCO': 1,
#              'coated': 1,
#              'glass': 3,
#              'solar': 4,
#              'industry': 14,
#              '': 2374,
#              'Talentum': 3,
#              'expects': 15,
#              'net': 111,
#              'sales': 105,
#              'core': 5,
#              'business': 37,
#              'increase': 44,
#              '2008': 53,
#              'compared': 40,
#              '2007': 47,
#              'By': 3,
#              'cutting': 2,
#              'number': 7,
#              'plants': 4,
#              'group': 38,
#              'trim': 1,
#              'fixed': 2,
#              'costs': 9,
#              'More': 2,
#              'staff': 2,
#              'recruited': 1,
#              'Japan': 4,
#              'complement': 1,
#              'network': 9,
#              'close': 4,
#              '50': 7,
#              'service': 26,
#              'locations': 5,
#              '20': 18,
#              'countries': 12,
#              'worldwide': 1,
#              'Finnish': 124,
#              'Swedish': 9,
#              'construction': 17,
#              'markets': 11,
#              'still': 5,
#              'experiencing': 1,
#              'estimated': 13,
#              '4': 18,
#              'annual': 11,
#              'growth': 24,
#              'In': 39,
#              'addition': 7,
#              'fireplace': 1,
#              'exports': 1,
#              'demand': 9,
#              'lining': 1,
#              'stone': 1,
#              'exceeded': 2,
#              'level': 7,
#              'earlier': 21,
#              'part': 12,
#              'year': 88,
#              'continue': 10,
#              'clearly': 1,
#              'brisker': 1,
#              'remainder': 1,
#              'Clothing': 1,
#              'retail': 4,
#              'chain': 5,
#              'SeppÆlÆ': 1,
#              'increased': 46,
#              '8': 12,
#              'EUR': 244,
#              '1552': 1,
#              'mn': 154,
#              'operating': 48,
#              'profit': 117,
#              'rose': 58,
#              '311': 1,
#              '171': 1,
#              '2004': 14,
#              'It': 15,
#              'combines': 1,
#              'perfect': 1,
#              'price': 9,
#              'performance': 8,
#              'sophisticated': 1,
#              'management': 12,
#              'facilities': 1,
#              'company': 144,
#              'said': 154,
#              'Operating': 35,
#              '194': 1,
#              '245': 2,
#              'Cash': 4,
#              'flow': 7,
#              'operations': 29,
#              'totalled': 13,
#              '04': 5,
#              'negative': 4,
#              '155': 2,
#              'first': 36,
#              'half': 6,
#              'change': 2,
#              'optimize': 1,
#              'operational': 4,
#              'efficiencies': 1,
#              'growing': 6,
#              'Julia': 1,
#              'Prohaska': 1,
#              'director': 11,
#              'marketing': 4,
#              'communications': 4,
#              'Fiskars': 9,
#              'A': 9,
#              'new': 51,
#              'Kveyt': 1,
#              'light': 2,
#              'variety': 1,
#              'Suomalainen': 1,
#              'Pekoni': 1,
#              'marketed': 1,
#              'Atria': 9,
#              'brand': 4,
#              'name': 1,
#              'available': 5,
#              'consumers': 3,
#              'Finland': 52,
#              'OKO': 2,
#              'bank': 6,
#              'signed': 36,
#              'cooperation': 12,
#              'agreement': 37,
#              'Raiffeisen': 1,
#              'concerning': 3,
#              'companies': 24,
#              'investments': 7,
#              'Russia': 20,
#              'production': 13,
#              'capacity': 12,
#              'tripled': 2,
#              'without': 2,
#              'major': 5,
#              'additional': 4,
#              'Aspo': 6,
#              'Plc': 10,
#              'STOCK': 1,
#              'EXCHANGE': 1,
#              'RELEASE': 2,
#              'February': 10,
#              '11': 6,
#              '2011': 16,
#              'at8': 1,
#              '45': 8,
#              'ESL': 2,
#              'Shipping': 3,
#              'Ltd': 9,
#              'Group': 28,
#              'longterm': 14,
#              'contract': 34,
#              'Rautaruukki': 7,
#              'Corporation': 23,
#              'marine': 2,
#              'transport': 4,
#              'raw': 5,
#              'materials': 4,
#              'Baltic': 9,
#              'Sea': 2,
#              'SKF': 3,
#              '6': 11,
#              'April': 7,
#              '2010': 69,
#              'Alandsbanken': 1,
#              'given': 4,
#              'buy': 8,
#              'recommendation': 4,
#              'industrial': 5,
#              'AB': 5,
#              'STO': 3,
#              'B': 2,
#              'share': 34,
#              'target': 9,
#              'SEK150': 1,
#              'Previously': 4,
#              'anticipated': 1,
#              'improve': 12,
#              'period': 81,
#              'strong': 11,
#              'portfolio': 6,
#              'international': 9,
#              'brands': 4,
#              'include': 4,
#              'Iittala': 1,
#              'Gerber': 1,
#              'Silva': 1,
#              'Buster': 1,
#              'Ramirent': 8,
#              'leading': 15,
#              'machinery': 10,
#              'equipment': 16,
#              'rentals': 1,
#              'reach': 7,
#              '2005': 24,
#              'financial': 16,
#              'impact': 2,
#              '15': 15,
#              'MEUR': 1,
#              'improvement': 5,
#              'division': 5,
#              'result': 19,
#              'starting': 2,
#              'fiscal': 6,
#              'technology': 26,
#              'Aspocomp': 3,
#              'Oyj': 62,
#              'OMX': 19,
#              'Helsinki': 18,
#              'ACG1V': 2,
#              'issued': 2,
#              'third': 18,
#              'quarter': 64,
#              'report': 3,
#              'Thursday': 7,
#              '13': 10,
#              'November': 11,
#              'posting': 1,
#              'EUR0': 22,
#              'loss': 43,
#              '5': 13,
#              'provide': 6,
#              'Switch': 1,
#              'double': 4,
#              'converter': 1,
#              'whilst': 1,
#              'opening': 2,
#              'manufacturing': 9,
#              'China': 15,
#              'KCI': 2,
#              'Konecranes': 7,
#              'awarded': 20,
#              'order': 25,
#              'four': 7,
#              'hot': 1,
#              'metal': 7,
#              'ladle': 1,
#              'cranes': 1,
#              'Indian': 6,
#              'steel': 13,
#              'producer': 3,
#              'Bhushan': 1,
#              'Steel': 1,
#              'Strips': 1,
#              'delivered': 3,
#              'According': 13,
#              'Bosse': 1,
#              'present': 2,
#              'beneficial': 1,
#              'parties': 5,
#              'however': 5,
#              'Proving': 1,
#              'good': 9,
#              'cellphone': 1,
#              'design': 6,
#              'truly': 2,
#              'work': 2,
#              'art': 1,
#              'website': 1,
#              'Nokia': 32,
#              '6131': 1,
#              'provides': 6,
#              'colorful': 1,
#              'canvas': 1,
#              'expression': 1,
#              'mobileinspired': 1,
#              'sentiments': 1,
#              'Kone': 4,
#              'elevators': 5,
#              'escalators': 3,
#              'solutions': 25,
#              'modernisation': 1,
#              'maintenance': 5,
#              'build': 3,
#              '342': 1,
#              'installed': 3,
#              'highspeed': 1,
#              'railway': 2,
#              'section': 1,
#              'Beijing': 3,
#              'Shanghai': 3,
#              'years': 11,
#              'time': 11,
#              'One': 2,
#              'colleagues': 1,
#              'summed': 1,
#              'E7': 1,
#              'quite': 3,
#              'aptly': 1,
#              'remarked': 1,
#              'Fantastic': 1,
#              'hardware': 1,
#              'Tiimari': 2,
#              'retailer': 4,
#              'reported': 7,
#              'geenrated': 1,
#              'quarterly': 2,
#              'revenues': 4,
#              'totalling': 2,
#              '4th': 1,
#              '2009': 78,
#              '03': 6,
#              'stock': 9,
#              'day': 6,
#              'Tuesday': 6,
#              'bringing': 4,
#              'threeday': 1,
#              'rise': 7,
#              'GBX10': 1,
#              '18': 6,
#              'Adanac': 1,
#              'Molybdenum': 1,
#              'Canada': 2,
#              'ordered': 3,
#              'grinding': 2,
#              'molybdenum': 1,
#              'project': 9,
#              'British': 1,
#              'Columbia': 1,
#              'Shalkiya': 4,
#              'Zinc': 2,
#              'Kazakhstan': 6,
#              'zinclead': 2,
#              'At': 7,
#              'end': 15,
#              'March': 4,
#              'book': 3,
#              '396': 1,
#              '42': 2,
#              'corresponding': 35,
#              '2006': 37,
#              'terms': 4,
#              'profitability': 7,
#              'earnings': 9,
#              'best': 6,
#              'history': 2,
#              'Chief': 4,
#              'Executive': 3,
#              'VeliMatti': 1,
#              'Mattila': 1,
#              'EPS': 10,
#              'improved': 14,
#              '38': 2,
#              '27': 8,
#              'Mreal': 7,
#              'expected': 23,
#              'yearonyear': 20,
#              'EUR609m': 1,
#              'second': 22,
#              'Growth': 2,
#              'strongest': 1,
#              'FSecure': 4,
#              'operator': 6,
#              'ISPs': 1,
#              'mobile': 27,
#              'operators': 7,
#              'cable': 4,
#              'Seppala': 2,
#              'revenue': 10,
#              '02': 1,
#              'EUR10': 4,
#              '1': 17,
#              'went': 7,
#              '24': 3,
#              'EUR6': 4,
#              'abroad': 1,
#              '62': 2,
#              'EUR3': 6,
#              '3': 18,
#              'Sales': 12,
#              'well': 18,
#              'Ukraine': 2,
#              'rebuilds': 1,
#              'designed': 3,
#              'machines': 2,
#              'product': 6,
#              'quality': 4,
#              'disposal': 2,
#              'Autotank': 1,
#              'also': 38,
#              'strengthen': 8,
#              'capital': 8,
#              'structure': 7,
#              'commented': 1,
#              'Gustav': 1,
#              'Nyberg': 1,
#              'CEO': 15,
#              'Stora': 7,
#              'Enso': 7,
#              'R': 1,
#              'shares': 7,
#              '120': 1,
#              'pct': 21,
#              '1184': 1,
#              'eur': 34,
#              'UPMKymmene': 6,
#              'dragged': 1,
#              'higher': 10,
#              'rising': 1,
#              '168': 2,
#              '1756': 1,
#              'MReal': 1,
#              'added': 3,
#              '238': 1,
#              '430': 1,
#              'September': 12,
#              'agreed': 7,
#              'Danish': 3,
#              'Rose': 1,
#              'Poultry': 1,
#              'AS': 3,
#              'EUR23': 2,
#              '9': 12,
#              'combination': 2,
#              'cash': 5,
#              'Nevertheless': 2,
#              'market': 35,
#              '4914': 1,
#              'percent': 33,
#              '4851': 2,
#              'EuroChem': 4,
#              'CFO': 1,
#              'Andrey': 1,
#              'Ilyin': 1,
#              'This': 13,
#              'facility': 10,
#              'marks': 1,
#              'another': 5,
#              'important': 3,
#              'step': 3,
#              'securing': 1,
#              'financing': 6,
#              'necessary': 1,
#              'potash': 1,
#              'strategic': 9,
#              'projects': 10,
#              'Precedex': 1,
#              'approved': 5,
#              'IV': 1,
#              'sedation': 1,
#              'initially': 1,
#              'intubated': 1,
#              'mechanically': 1,
#              'ventilated': 1,
#              'patients': 3,
#              'intensive': 1,
#              'care': 2,
#              'customers': 19,
#              'industryleading': 1,
#              'innovative': 5,
#              'modernization': 2,
#              'supplier': 7,
#              'BSSOSS': 1,
#              'VAS': 1,
#              'telecom': 3,
#              'Tecnotree': 1,
#              'received': 8,
#              'expansion': 10,
#              'orders': 10,
#              'worth': 7,
#              'total': 11,
#              'US': 11,
#              '73': 2,
#              'convergent': 1,
#              'charging': 2,
#              'next': 5,
#              'generation': 4,
#              'messaging': 3,
#              'Latin': 4,
#              'America': 10,
#              'announced': 12,
#              'specifying': 1,
#              'placed': 1,
#              'credit': 4,
#              'Glaston': 5,
#              'Abp': 3,
#              'HEL': 31,
#              'GLA1V': 1,
#              'today': 32,
#              'concluded': 5,
#              'EUR74m': 1,
#              'revolving': 2,
#              'banks': 3,
#              'repaid': 1,
#              'interest': 8,
#              'bearing': 3,
#              'liability': 1,
#              'Standard': 2,
#              'Chartered': 2,
#              'Bank': 19,
#              'use': 14,
#              'rest': 1,
#              'consideration': 1,
#              'partially': 2,
#              'repay': 1,
#              'liabilities': 1,
#              'liquidity': 1,
#              'income': 10,
#              '6964': 1,
#              '6003': 1,
#              'Due': 1,
#              'rapid': 2,
#              'Tallink': 2,
#              'passenger': 5,
#              'carriage': 1,
#              'Tallinna': 1,
#              'Sadam': 1,
#              'Port': 3,
#              'Tallinn': 4,
#              'totaled': 11,
#              '55': 3,
#              '457': 1,
#              'HK': 3,
#              'Ruokatalo': 3,
#              'accounts': 1,
#              'poultry': 1,
#              'TELE2': 1,
#              'Affarsvarlden': 2,
#              'gave': 2,
#              'Tele2': 1,
#              '142': 1,
#              'crowns': 1,
#              '2354': 1,
#              '1519': 1,
#              'euro': 41,
#              '179mn': 1,
#              '188mn': 1,
#              'sale': 11,
#              'gain': 5,
#              '60': 1,
#              'million': 104,
#              'OriolaKD': 2,
#              'supports': 3,
#              'strategy': 16,
#              'focus': 8,
#              'pharmaceutical': 2,
#              'wholesale': 2,
#              'Pretax': 7,
#              '808': 1,
#              '131': 3,
#              'We': 18,
#              'warmly': 2,
#              'welcome': 6,
#              'Satama': 4,
#              'states': 1,
#              'Jussi': 3,
#              'Lansio': 1,
#              'chairman': 3,
#              'Board': 3,
#              'partnership': 4,
#              'represents': 2,
#              'significant': 12,
#              'milestone': 1,
#              'software': 14,
#              'AffectoGenimap': 1,
#              'acquire': 5,
#              'sector': 8,
#              'Intellibis': 1,
#              'Ab': 1,
#              '12': 10,
#              'mln': 91,
#              '158': 1,
#              'debtfree': 1,
#              'basis': 2,
#              'Talvivaara': 3,
#              'maintains': 1,
#              'assumption': 1,
#              'turning': 1,
#              'positive': 13,
#              'Commission': 2,
#              'applauded': 1,
#              'applying': 1,
#              'factbased': 1,
#              'datadriven': 1,
#              'approach': 3,
#              'providing': 7,
#              'clarity': 1,
#              'future': 5,
#              'petitions': 1,
#              'Dubai': 1,
#              'launch': 5,
#              'Comes': 1,
#              'Music': 1,
#              'groundbreaking': 1,
#              'introduces': 1,
#              'people': 4,
#              'enjoy': 1,
#              'music': 1,
#              'EB': 3,
#              'custom': 2,
#              'solution': 8,
#              'LG': 1,
#              'Electronics': 2,
#              'making': 5,
#              'terminal': 2,
#              'vendors': 1,
#              'wireless': 2,
#              'As': 6,
#              'transaction': 7,
#              'Sappi': 2,
#              'supply': 24,
#              'pulp': 4,
#              'BCTMP': 1,
#              'smaller': 2,
#              'services': 42,
#              'supplies': 2,
#              'sell': 5,
#              'products': 20,
#              'Russian': 5,
#              'region': 7,
#              'invest': 5,
#              'development': 9,
#              'Qt': 2,
#              'benefit': 1,
#              'users': 2,
#              'Commercial': 1,
#              'LGPL': 1,
#              '21': 2,
#              'December': 11,
#              'Wartsila': 2,
#              'WRT1V': 1,
#              'yesterday': 7,
#              'liquefied': 1,
#              'natural': 2,
#              'gas': 4,
#              'LNG': 1,
#              'powered': 1,
#              'platform': 4,
#              'vessel': 3,
#              'PSV': 1,
#              'Norwegian': 7,
#              'oil': 5,
#              'provider': 18,
#              'Eidesvik': 1,
#              'Offshore': 1,
#              'ASA': 3,
#              'OSL': 2,
#              'EIOF': 1,
#              'HELSINKI': 6,
#              'Sept': 2,
#              'GLOBE': 1,
#              'NEWSWIRE': 1,
#              'Ixonos': 5,
#              'expands': 4,
#              'smartphone': 3,
#              'RD': 4,
#              'establishes': 2,
#              'nextgeneration': 1,
#              'unit': 7,
#              'connection': 1,
#              'site': 2,
#              'Jyvaeskylae': 2,
#              'AFX': 4,
#              'raised': 4,
#              'stake': 6,
#              'MMH': 1,
#              'Holdings': 2,
#              'Inc': 6,
#              'owner': 2,
#              'USbased': 1,
#              'Morris': 1,
#              'Materials': 1,
#              'Handling': 3,
#              '909': 1,
#              '745': 1,
#              'electronics': 6,
#              'manufacturer': 9,
#              'PKC': 3,
#              'PKC1V': 1,
#              'Wednesday': 5,
#              '31': 9,
#              'completed': 5,
#              'acquisition': 14,
#              'MAN': 2,
#              'Nutzfahrzeuge': 1,
#              'AG': 3,
#              'harness': 1,
#              'Star': 1,
#              'Trucks': 1,
#              'Buses': 1,
#              'Spolka': 1,
#              'zoo': 1,
#              'Poland': 5,
#              'subsidiary': 9,
#              'assets': 3,
#              'rental': 5,
#              'Jydsk': 1,
#              'Materiel': 1,
#              'Udlejning': 1,
#              'located': 3,
#              'West': 1,
#              'Jutland': 1,
#              'assignment': 2,
#              'strengthens': 2,
#              'Poyry': 5,
#              'position': 12,
#              'engineering': 11,
#              'chemical': 1,
#              'process': 6,
#              'Net': 12,
#              'per': 30,
#              'Dutch': 1,
#              'broker': 4,
#              'noted': 3,
#              'Nokian': 6,
#              'Tyres': 4,
#              'line': 12,
#              'consensus': 4,
#              'margin': 6,
#              '112': 2,
#              '117': 1,
#              'JanuarySeptember': 7,
#              'Finnlines': 2,
#              '5054': 1,
#              '4735': 1,
#              'While': 1,
#              'concerns': 1,
#              'remain': 4,
#              'longer': 1,
#              'term': 3,
#              'size': 2,
#              'scale': 1,
#              'may': 2,
#              'enable': 4,
#              'hold': 2,
#              'newfound': 1,
#              'improvements': 1,
#              'near': 3,
#              'analyst': 5,
#              'wrote': 1,
#              'negotiations': 3,
#              'carried': 4,
#              'constructive': 1,
#              'manner': 1,
#              'tried': 1,
#              'find': 1,
#              'situation': 2,
#              'Componenta': 6,
#              'CTH1V': 2,
#              'narrowed': 6,
#              '500000': 1,
#              'USD': 18,
#              '680000': 1,
#              'last': 21,
#              '53': 4,
#              'consumer': 1,
#              'packaging': 3,
#              'Huhtamaki': 1,
#              'swung': 5,
#              '841': 1,
#              '1056': 1,
#              'nine': 16,
#              'months': 17,
#              '26': 3,
#              '33': 4,
#              'high': 5,
#              'Vaahto': 3,
#              'reports': 8,
#              '418': 1,
#              'accounting': 3,
#              'implementing': 2,
#              'Army': 1,
#              'aims': 5,
#              'unify': 1,
#              'application': 5,
#              'areas': 9,
#              'QPR': 3,
#              'Software': 1,
#              'stated': 3,
#              'press': 4,
#              'conference': 2,
#              'Lattelecom': 1,
#              'board': 7,
#              'Nils': 1,
#              'Melngailis': 1,
#              'explained': 1,
#              'Blackstone': 2,
#              'chosen': 4,
#              'experience': 6,
#              'IT': 9,
#              'strength': 3,
#              'pharmaceuticals': 2,
#              'Orion': 2,
#              'taxes': 5,
#              '700': 1,
#              '549': 1,
#              '06': 1,
#              '1034': 1,
#              '232': 2,
#              '25': 8,
#              'index': 6,
#              '092': 1,
#              '251867': 1,
#              'CAP': 1,
#              '091': 1,
#              '471119': 1,
#              'ADPnews': 2,
#              'Nov': 4,
#              'Four': 1,
#              'combined': 3,
#              'SEK': 5,
#              '59': 3,
#              'billion': 16,
#              '854mEUR': 1,
#              '5718': 1,
#              'drug': 1,
#              'stores': 3,
#              'offered': 3,
#              'restructuring': 8,
#              'statedowned': 1,
#              'pharmacy': 1,
#              'monopoly': 1,
#              'Apoteket': 1,
#              'Kesko': 6,
#              'Agro': 2,
#              'Lietuva': 1,
#              'agricultural': 2,
#              'grain': 2,
#              'trader': 1,
#              'member': 1,
#              'boosted': 3,
#              '429': 1,
#              '134': 2,
#              'euros': 12,
#              'VAT': 2,
#              'inclusive': 2,
#              'updated': 1,
#              '20092012': 1,
#              'Basware': 10,
#              'targets': 2,
#              'range': 3,
#              '40': 9,
#              '10': 14,
#              'Iggesunds': 1,
#              'Bruk': 1,
#              'Sweden': 6,
#              'one': 10,
#              'advanced': 1,
#              'fully': 3,
#              'integrated': 4,
#              'paperboard': 1,
#              'mills': 4,
#              'world': 13,
#              'working': 10,
#              'closely': 1,
#              'shipping': 1,
#              'agents': 1,
#              'reduce': 2,
#              'fuel': 5,
#              'consumption': 3,
#              'greenhouse': 1,
#              'emissions': 1,
#              'Metso': 6,
#              'around': 8,
#              'kraftliner': 1,
#              'machine': 4,
#              'Lee': 2,
#              'Man': 1,
#              'Paper': 5,
#              'Co': 2,
#              'Q1': 2,
#              'land': 4,
#              '91': 1,
#              '97': 2,
#              'Separately': 1,
#              'YIT': 11,
#              'Austrian': 2,
#              'firm': 5,
#              'E': 2,
#              'week': 4,
#              'building': 8,
#              'system': 9,
#              'Germany': 2,
#              'Austria': 2,
#              'Czech': 3,
#              'Republic': 3,
#              'Hungary': 2,
#              'Romania': 2,
#              'Orders': 1,
#              'grew': 19,
#              'EUR732m': 1,
#              'Forestries': 1,
#              'driven': 2,
#              'bullish': 2,
#              'comment': 1,
#              'Dagens': 1,
#              'Industri': 1,
#              'dealers': 2,
#              'expand': 15,
#              'Last': 5,
#              'turnover': 4,
#              'approximately': 4,
#              '7': 19,
#              'litas': 2,
#              '2': 15,
#              '61': 3,
#              'Comparable': 1,
#              'Kalmar': 2,
#              '5year': 1,
#              'Rough': 1,
#              'Terrain': 1,
#              'Container': 1,
#              'Handler': 1,
#              'RTCH': 1,
#              'featured': 2,
#              'Ethibel': 1,
#              'Pioneer': 1,
#              'Investment': 3,
#              'Register': 2,
#              'included': 2,
#              'Innovest': 1,
#              'Global': 5,
#              '100': 6,
#              'list': 2,
#              'sustainable': 1,
#              'corporations': 1,
#              'AsiaPacific': 1,
#              'Visa': 1,
#              'Wave': 1,
#              'Malaysia': 1,
#              'Taiwan': 1,
#              'South': 7,
#              'Korea': 1,
#              'expanded': 2,
#              'Southeast': 1,
#              'Asia': 7,
#              'Jung': 1,
#              'Following': 1,
#              'entered': 3,
#              'current': 11,
#              'mechanise': 1,
#              'harvesting': 1,
#              'eucalyptus': 1,
#              'plantations': 1,
#              'Southern': 1,
#              'Outotec': 9,
#              '4929': 1,
#              '2404': 1,
#              'Department': 5,
#              'Store': 2,
#              'Division': 4,
#              'Hobby': 1,
#              'Hall': 1,
#              'clothing': 4,
#              'store': 4,
#              'decreased': 1,
#              'Banking': 1,
#              'News': 12,
#              '28': 8,
#              'Tieto': 1,
#              'Pohjola': 5,
#              'PINK': 1,
#              'POJLF': 1,
#              'cooperate': 1,
#              'SWIFT': 1,
#              'track': 3,
#              'record': 8,
#              'transportation': 1,
#              'Tekla': 4,
#              'implement': 2,
#              'renewal': 1,
#              'versions': 1,
#              'introduced': 4,
#              'spring': 1,
#              'Sports': 4,
#              'progressed': 1,
#              'owing': 1,
#              'prolonged': 1,
#              'winter': 1,
#              'season': 1,
#              '393': 1,
#              '327': 2,
#              '269': 2,
#              '1058': 1,
#              '834': 1,
#              'Then': 1,
#              'contribute': 4,
#              'EUR150m': 1,
#              '1019': 1,
#              '1007': 1,
#              'Mobile': 5,
#              'phone': 8,
#              '587': 1,
#              'enterprise': 2,
#              'dropped': 1,
#              '39': 2,
#              '186': 2,
#              ...})

# %%
positiveValues.items()
#o/p is a dictionary with the word in news column as key and its count within the train dataset as its corresponding value
# Out:
# dict_items([('The', 165), ('concept', 2), ('enables', 5), ('commercially', 3), ('affordable', 1), ('way', 4), ('manufacture', 1), ('highquality', 2), ('TCO', 1), ('coated', 1), ('glass', 3), ('solar', 4), ('industry', 14), ('', 2374), ('Talentum', 3), ('expects', 15), ('net', 111), ('sales', 105), ('core', 5), ('business', 37), ('increase', 44), ('2008', 53), ('compared', 40), ('2007', 47), ('By', 3), ('cutting', 2), ('number', 7), ('plants', 4), ('group', 38), ('trim', 1), ('fixed', 2), ('costs', 9), ('More', 2), ('staff', 2), ('recruited', 1), ('Japan', 4), ('complement', 1), ('network', 9), ('close', 4), ('50', 7), ('service', 26), ('locations', 5), ('20', 18), ('countries', 12), ('worldwide', 1), ('Finnish', 124), ('Swedish', 9), ('construction', 17), ('markets', 11), ('still', 5), ('experiencing', 1), ('estimated', 13), ('4', 18), ('annual', 11), ('growth', 24), ('In', 39), ('addition', 7), ('fireplace', 1), ('exports', 1), ('demand', 9), ('lining', 1), ('stone', 1), ('exceeded', 2), ('level', 7), ('earlier', 21), ('part', 12), ('year', 88), ('continue', 10), ('clearly', 1), ('brisker', 1), ('remainder', 1), ('Clothing', 1), ('retail', 4), ('chain', 5), ('SeppÆlÆ', 1), ('increased', 46), ('8', 12), ('EUR', 244), ('1552', 1), ('mn', 154), ('operating', 48), ('profit', 117), ('rose', 58), ('311', 1), ('171', 1), ('2004', 14), ('It', 15), ('combines', 1), ('perfect', 1), ('price', 9), ('performance', 8), ('sophisticated', 1), ('management', 12), ('facilities', 1), ('company', 144), ('said', 154), ('Operating', 35), ('194', 1), ('245', 2), ('Cash', 4), ('flow', 7), ('operations', 29), ('totalled', 13), ('04', 5), ('negative', 4), ('155', 2), ('first', 36), ('half', 6), ('change', 2), ('optimize', 1), ('operational', 4), ('efficiencies', 1), ('growing', 6), ('Julia', 1), ('Prohaska', 1), ('director', 11), ('marketing', 4), ('communications', 4), ('Fiskars', 9), ('A', 9), ('new', 51), ('Kveyt', 1), ('light', 2), ('variety', 1), ('Suomalainen', 1), ('Pekoni', 1), ('marketed', 1), ('Atria', 9), ('brand', 4), ('name', 1), ('available', 5), ('consumers', 3), ('Finland', 52), ('OKO', 2), ('bank', 6), ('signed', 36), ('cooperation', 12), ('agreement', 37), ('Raiffeisen', 1), ('concerning', 3), ('companies', 24), ('investments', 7), ('Russia', 20), ('production', 13), ('capacity', 12), ('tripled', 2), ('without', 2), ('major', 5), ('additional', 4), ('Aspo', 6), ('Plc', 10), ('STOCK', 1), ('EXCHANGE', 1), ('RELEASE', 2), ('February', 10), ('11', 6), ('2011', 16), ('at8', 1), ('45', 8), ('ESL', 2), ('Shipping', 3), ('Ltd', 9), ('Group', 28), ('longterm', 14), ('contract', 34), ('Rautaruukki', 7), ('Corporation', 23), ('marine', 2), ('transport', 4), ('raw', 5), ('materials', 4), ('Baltic', 9), ('Sea', 2), ('SKF', 3), ('6', 11), ('April', 7), ('2010', 69), ('Alandsbanken', 1), ('given', 4), ('buy', 8), ('recommendation', 4), ('industrial', 5), ('AB', 5), ('STO', 3), ('B', 2), ('share', 34), ('target', 9), ('SEK150', 1), ('Previously', 4), ('anticipated', 1), ('improve', 12), ('period', 81), ('strong', 11), ('portfolio', 6), ('international', 9), ('brands', 4), ('include', 4), ('Iittala', 1), ('Gerber', 1), ('Silva', 1), ('Buster', 1), ('Ramirent', 8), ('leading', 15), ('machinery', 10), ('equipment', 16), ('rentals', 1), ('reach', 7), ('2005', 24), ('financial', 16), ('impact', 2), ('15', 15), ('MEUR', 1), ('improvement', 5), ('division', 5), ('result', 19), ('starting', 2), ('fiscal', 6), ('technology', 26), ('Aspocomp', 3), ('Oyj', 62), ('OMX', 19), ('Helsinki', 18), ('ACG1V', 2), ('issued', 2), ('third', 18), ('quarter', 64), ('report', 3), ('Thursday', 7), ('13', 10), ('November', 11), ('posting', 1), ('EUR0', 22), ('loss', 43), ('5', 13), ('provide', 6), ('Switch', 1), ('double', 4), ('converter', 1), ('whilst', 1), ('opening', 2), ('manufacturing', 9), ('China', 15), ('KCI', 2), ('Konecranes', 7), ('awarded', 20), ('order', 25), ('four', 7), ('hot', 1), ('metal', 7), ('ladle', 1), ('cranes', 1), ('Indian', 6), ('steel', 13), ('pro ...

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive=pd.DataFrame(sorted(positiveValues.items(),key=lambda x:x[1],reverse=True))
df_negative=pd.DataFrame(sorted(negativeValues.items(),key=lambda x:x[1],reverse=True))
df_neutral=pd.DataFrame(sorted(neutralValues.items(),key=lambda x:x[1],reverse=True))

# %%
pd1=df_positive[0][:10]
pd2=df_positive[1][:10]

ned1=df_negative[0][:10]
ned2=df_negative[1][:10]

nud1=df_neutral[0][:10]
nud2=df_neutral[1][:10]


plt.figure(1,figsize=(16,4))

plt.bar(pd1,pd2, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-UNIGRAM ANALYSIS")

plt.savefig("positive-unigram.png")
plt.show()

# %%
df_positive.head(10)
# Out:
#          0     1
# 0           2374
# 1      EUR   244
# 2      The   165
# 3       mn   154
# 4     said   154
# 5  company   144
# 6  Finnish   124
# 7   profit   117
# 8      net   111
# 9    sales   105

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1,ned2, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-UNIGRAM ANALYSIS")

plt.savefig("negative-unigram.png")
plt.show()

# %%
df_negative.head(10)
# Out:
#          0    1
# 0           918
# 1      EUR  206
# 2       mn  150
# 3   profit   90
# 4      The   66
# 5  company   59
# 6    sales   58
# 7  Finnish   57
# 8     2008   53
# 9   period   52

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1,nud2, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-UNIGRAM ANALYSIS")

plt.savefig("neutral-unigram.png")
plt.show()

# %%
df_neutral.head(10)
# Out:
#           0     1
# 0            4449
# 1       The   559
# 2   company   294
# 3      said   142
# 4   Finland   132
# 5   Finnish   132
# 6       EUR   118
# 7   million   118
# 8       new   100
# 9  business   100

# %% [markdown]
# **Creating bigrams**

# %%
positiveValues2=defaultdict(int)
negativeValues2=defaultdict(int)
neutralValues2=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text,2):
    positiveValues2[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text,2):
    negativeValues2[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text,2):
    neutralValues2[word]+=1
# Out:
# Sentence after removing stopwords: ['The', 'concept', 'enables', 'commercially', 'affordable', 'way', 'manufacture', 'highquality', 'TCO', 'coated', 'glass', 'solar', 'industry', '']
# Sentence after removing stopwords: ['Talentum', 'expects', 'net', 'sales', 'core', 'business', 'increase', '2008', '', 'compared', '2007', '']
# Sentence after removing stopwords: ['By', 'cutting', 'number', 'plants', '', 'group', 'trim', 'fixed', 'costs', '']
# Sentence after removing stopwords: ['More', 'staff', 'recruited', 'Japan', 'complement', 'network', 'close', '50', 'service', 'locations', '20', 'countries', 'worldwide', '']
# Sentence after removing stopwords: ['Finnish', 'Swedish', 'construction', 'markets', 'still', 'experiencing', 'estimated', '4', '', 'annual', 'growth', '2008', '']
# Sentence after removing stopwords: ['In', 'addition', 'fireplace', 'exports', '', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['It', 'combines', 'perfect', 'price', 'performance', 'sophisticated', 'management', 'facilities', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '194', 'mn', 'EUR', '245', 'mn', '']
# Sentence after removing stopwords: ['Cash', 'flow', 'business', 'operations', 'totalled', 'EUR', '04', 'mn', 'compared', 'negative', 'EUR', '155', 'mn', 'first', 'half', '2008', '']
# Sentence after removing stopwords: ['', 'The', 'change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', '', '', 'said', 'Julia', 'Prohaska', '', 'director', 'marketing', 'communications', 'Fiskars', '']
# Sentence after removing stopwords: ['A', 'new', 'Kveyt', 'light', 'variety', 'Suomalainen', 'Pekoni', 'marketed', 'Atria', 'brand', 'name', 'available', 'consumers', 'Finland', '']
# Sentence after removing stopwords: ['Finnish', 'OKO', 'bank', 'signed', 'cooperation', 'agreement', 'Raiffeisen', 'concerning', 'Finnish', 'companies', '', 'investments', 'Russia', '']
# Sentence after removing stopwords: ['The', 'production', 'capacity', 'tripled', 'without', 'major', 'additional', 'investments', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Aspo', 'Plc', 'STOCK', 'EXCHANGE', 'RELEASE', 'February', '11', '', '2011', 'at8', '45', 'ESL', 'Shipping', 'Ltd', '', 'part', 'Aspo', 'Group', '', 'signed', 'new', '', 'longterm', 'contract', 'Rautaruukki', 'Corporation', 'marine', 'transport', 'raw', 'materials', 'Baltic', 'Sea', '']
# Sentence after removing stopwords: ['SKF', '6', 'April', '2010', '', 'Alandsbanken', 'given', '', 'buy', '', 'recommendation', 'Swedish', 'industrial', 'company', 'SKF', 'AB', '', 'STO', '', 'SKF', 'B', '', 'share', 'price', 'target', 'SEK150', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'anticipated', 'operating', 'profit', 'improve', 'period', '']
# Sentence after removing stopwords: ['Fiskars', 'strong', 'portfolio', 'international', 'brands', '', 'include', 'Fiskars', '', 'Iittala', '', 'Gerber', '', 'Silva', 'Buster', '']
# Sentence after removing stopwords: ['Ramirent', 'leading', 'company', 'machinery', 'equipment', 'rentals', 'construction', 'industry', '']
# Sentence after removing stopwords: ['Previously', 'company', 'estimated', 'operating', 'profit', 'reach', 'level', '2005', '']
# Sentence after removing stopwords: ['The', 'financial', 'impact', 'estimated', '15', 'MEUR', 'annual', 'improvement', 'division', 'result', '', 'starting', 'fiscal', 'year', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'technology', 'group', 'Aspocomp', 'Group', 'Oyj', '', 'OMX', 'Helsinki', '', 'ACG1V', '', 'issued', 'third', 'quarter', 'report', 'Thursday', '', '13', 'November', '', '', 'posting', 'operating', 'profit', 'EUR0', '4', '', 'compared', 'loss', 'EUR0', '5', 'third', 'quarter', '2007', '']
# Sentence after removing stopwords: ['The', 'agreement', 'provide', 'The', 'Switch', 'double', 'converter', 'capacity', '', 'whilst', 'opening', 'manufacturing', 'locations', 'China', '']
# Sentence after removing stopwords: ['Finnish', 'KCI', 'Konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'Indian', 'steel', 'producer', 'Bhushan', 'Steel', '', 'Strips', 'delivered', '2007', '']
# Sentence after removing stopwords: ['According', 'Bosse', '', 'present', 'cooperation', 'beneficial', 'parties', '', 'however', '']
# Sentence after removing stopwords: ['Proving', 'good', 'cellphone', 'design', 'truly', 'work', 'art', '', 'website', 'Nokia', '6131', 'provides', 'colorful', 'canvas', 'expression', 'mobileinspired', 'sentiments', '']
# Sentence after removing stopwords: ['In', 'China', '', 'Finnish', 'Kone', 'provides', 'elevators', '', 'escalators', '', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'highspeed', 'railway', 'section', 'Beijing', 'Shanghai', '15', 'years', '', 'time', '']
# Sentence after removing stopwords: ['One', 'colleagues', 'summed', 'E7', 'quite', 'aptly', 'remarked', '', '', 'Fantastic', 'hardware', '']
# Sentence after removing stopwords: ['Tiimari', '', 'Finnish', 'retailer', '', 'reported', 'geenrated', 'quarterly', 'revenues', 'totalling', 'EUR', '13', 'mn', '4th', 'quarter', '2009', '', 'EUR', '03', 'mn', 'loss', '2008', '']
# Sentence after removing stopwords: ['The', 'stock', 'rose', 'third', 'day', 'Tuesday', 'bringing', 'threeday', 'rise', 'GBX10', '50', '18', '', '']
# Sentence after removing stopwords: ['Adanac', 'Molybdenum', 'Canada', 'ordered', 'grinding', 'technology', 'molybdenum', 'project', 'British', 'Columbia', '', 'Canada', '', 'Shalkiya', 'Zinc', 'Kazakhstan', 'awarded', 'contract', 'grinding', 'technology', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['At', 'end', 'March', '2007', '', 'group', 'order', 'book', 'EUR', '396', 'mn', '', '42', '', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['The', 'EPS', 'improved', 'EUR0', '38', 'EUR0', '27', '']
# Sentence after removing stopwords: ['Mreal', 'sales', 'expected', 'increased', '4', '', 'yearonyear', 'EUR609m', 'second', 'quarter', '2010', '']
# Sentence after removing stopwords: ['Growth', 'strongest', 'FSecure', 'operator', 'ISPs', '', 'mobile', 'operators', 'cable', 'operators', 'business', '']
# Sentence after removing stopwords: ['Seppala', 'revenue', 'increased', '02', '', 'EUR10', '1', 'In', 'Finland', '', 'revenue', 'went', '24', '', 'EUR6', '8', '', 'sales', 'abroad', 'rose', '62', '', 'EUR3', '3', 'Sales', 'increased', 'Baltic', 'countries', 'well', 'Russia', 'Ukraine', '']
# Sentence after removing stopwords: ['The', 'rebuilds', 'designed', 'improve', 'machines', '', 'performance', 'product', 'quality', '']
# Sentence after removing stopwords: ['The', 'disposal', 'Autotank', 'also', 'strengthen', 'Aspo', 'capital', 'structure', '', '', 'commented', 'Gustav', 'Nyberg', '', 'CEO', 'Aspo', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'R', 'shares', 'rose', '120', 'pct', '1184', 'eur', '', 'UPMKymmene', 'also', 'dragged', 'higher', '', 'rising', '168', 'pct', '1756', 'eur', 'MReal', 'B', 'added', '238', 'pct', '430', 'eur', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['Nevertheless', '', 'market', 'share', 'rose', '4914', 'percent', '4851', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['EuroChem', 'CFO', 'Andrey', 'Ilyin', 'said', '', '', 'This', 'facility', 'marks', 'another', 'important', 'step', 'EuroChem', 'securing', 'longterm', 'financing', 'necessary', 'potash', 'strategic', 'projects', '', '']
# Sentence after removing stopwords: ['Precedex', 'approved', 'IV', 'sedation', 'initially', 'intubated', 'mechanically', 'ventilated', 'patients', 'intensive', 'care', '']
# Sentence after removing stopwords: ['It', 'provides', 'customers', 'industryleading', 'elevators', '', 'escalators', 'innovative', 'solutions', 'maintenance', 'modernization', '']
# Sentence after removing stopwords: ['The', 'Finnish', 'supplier', 'BSSOSS', 'VAS', 'telecom', 'operators', '', 'Tecnotree', '', 'received', 'expansion', 'orders', 'worth', 'total', 'US', '73', 'mn', 'convergent', 'charging', 'next', 'generation', 'messaging', 'solutions', 'Latin', 'America', '', 'company', 'announced', 'without', 'specifying', 'operators', 'placed', 'orders', '']
# Sentence after removing stopwords: ['credit', '20', 'November', '2009', '', 'Finnish', 'glass', 'technology', 'company', 'Glaston', 'Oyj', 'Abp', '', 'HEL', '', 'GLA1V', '', 'said', 'today', 'concluded', 'EUR74m', 'revolving', 'credit', 'facility', 'agreement', 'core', 'banks', '']
# Sentence after removing stopwords: ['Aspocomp', 'repaid', 'interest', 'bearing', 'liability', 'Standard', 'Chartered', 'Bank', 'use', 'rest', 'consideration', 'partially', 'repay', 'interest', 'bearing', 'liabilities', 'Finland', 'improve', 'liquidity', '']
# Sentence after removing stopwords: ['Operating', 'income', 'rose', 'EUR', '6964', 'mn', 'EUR', '6003', 'mn', '2009', '']
# Sentence after removing stopwords: ['Due', 'rapid', 'expansion', '', 'market', 'share', 'Tallink', 'terms', 'passenger', 'carriage', 'Tallinna', 'Sadam', 'Port', 'Tallinn', 'totaled', '55', 'percent', 'November', '457', 'percent', 'November', '2005', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'accounts', '50', '', 'poultry', 'sales', 'Finland', '', 'profitability', 'good', 'level', '']
# Sentence after removing stopwords: ['TELE2', 'Affarsvarlden', 'gave', '', 'buy', '', 'recommendation', 'mobile', 'operator', 'Tele2', 'AB', 'share', 'price', 'target', '142', 'crowns', '', '', '2354', '', '1519', 'euro', '', '']
# Sentence after removing stopwords: ['Operating', 'loss', 'EUR', '179mn', '', 'compared', 'loss', 'EUR', '188mn', 'second', 'quarter', '2009', '']
# Sentence after removing stopwords: ['The', 'sale', '', 'result', 'gain', 'EUR', '60', 'million', 'second', 'quarter', '2010', 'OriolaKD', '', 'supports', 'Finnish', 'company', 'strategy', 'focus', 'pharmaceutical', 'wholesale', 'retail', 'operations', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'totalled', 'EUR', '808', 'mn', '', 'compared', 'loss', 'EUR', '131', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['We', 'warmly', 'welcome', 'Satama', '', '', 'states', 'Jussi', 'Lansio', '', 'chairman', 'Board', '']
# Sentence after removing stopwords: ['This', 'new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties', '']
# Sentence after removing stopwords: ['Finnish', 'business', 'software', 'group', 'AffectoGenimap', 'Oyj', 'said', 'signed', 'agreement', 'acquire', 'shares', 'Swedish', 'sector', 'company', 'Intellibis', 'Ab', '12', 'mln', 'euro', '', '', '158', 'mln', '', 'debtfree', 'basis', '']
# Sentence after removing stopwords: ['Talvivaara', 'also', 'maintains', 'assumption', 'turning', 'cash', 'flow', 'positive', 'year', 'end', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['Dubai', 'Nokia', 'announced', 'launch', '', 'Comes', 'Music', '', '', 'groundbreaking', 'service', 'introduces', 'new', 'way', 'people', 'enjoy', 'music', '']
# Sentence after removing stopwords: ['Previously', '', 'EB', 'delivered', 'custom', 'solution', 'LG', 'Electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators', '']
# Sentence after removing stopwords: ['As', 'part', 'transaction', '', 'Mreal', 'Sappi', 'also', 'signed', 'longterm', 'agreement', 'supply', 'pulp', 'BCTMP', 'smaller', 'services', 'supplies', '']
# Sentence after removing stopwords: ['The', 'company', 'also', 'expects', 'sell', 'products', 'Russian', 'region', '']
# Sentence after removing stopwords: ['Nokia', 'continue', 'invest', 'future', 'development', 'Qt', 'benefit', 'users', '', 'Commercial', 'LGPL', '']
# Sentence after removing stopwords: ['21', 'December', '2010', '', 'Finnish', 'industrial', 'machinery', 'company', 'Wartsila', 'Oyj', 'Abp', 'HEL', '', 'WRT1V', 'said', 'yesterday', 'order', 'design', 'liquefied', 'natural', 'gas', 'LNG', 'powered', 'platform', 'supply', 'vessel', 'PSV', 'Norwegian', 'oil', 'service', 'provider', 'Eidesvik', 'Offshore', 'ASA', 'OSL', '', 'EIOF', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'Finland', '', 'Sept', '18', '', '2009', '', 'GLOBE', 'NEWSWIRE', '', '', 'Ixonos', 'Plc', 'expands', 'company', 'smartphone', 'RD', 'services', 'establishes', 'new', 'nextgeneration', 'smartphone', 'design', 'unit', 'connection', 'Ixonos', '', 'site', 'Jyvaeskylae', '']
# Sentence after removing stopwords: ['HELSINKI', 'AFX', '', 'KCI', 'Konecranes', 'said', 'raised', 'stake', 'MMH', 'Holdings', 'Inc', '', 'owner', 'USbased', 'Morris', 'Materials', 'Handling', '', '909', 'pct', '745', 'pct', '']
# Sentence after removing stopwords: ['Finnish', 'electronics', 'manufacturer', 'PKC', 'Group', 'Oyj', '', 'OMX', 'Helsinki', '', 'PKC1V', '', 'said', 'Wednesday', '', '31', 'December', '', 'completed', 'acquisition', 'MAN', 'Nutzfahrzeuge', 'AG', 'cable', 'harness', 'business', 'MAN', 'Star', 'Trucks', '', 'Buses', 'Spolka', 'zoo', 'Poland', '']
# Sentence after removing stopwords: ['Ramirent', 'Danish', 'subsidiary', 'Ramirent', 'AS', 'today', 'signed', 'agreement', 'acquire', 'business', 'assets', 'machinery', 'rental', 'company', 'Jydsk', 'Materiel', 'Udlejning', 'located', 'West', 'Jutland', '']
# Sentence after removing stopwords: ['This', 'assignment', 'strengthens', 'Poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry', '']
# Sentence after removing stopwords: ['Net', 'sales', 'revenue', 'per', 'passenger', 'expected', 'increase', '']
# Sentence after removing stopwords: ['The', 'Dutch', 'broker', 'noted', 'Nokian', 'Tyres', 'reported', 'good', 'first', 'quarter', '2006', '', 'line', 'consensus', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'margin', 'increased', '112', '', '117', '', '']
# Sentence after removing stopwords: ['In', 'JanuarySeptember', '2007', '', 'Finnlines', '', 'net', 'sales', 'rose', 'EUR', '5054', 'mn', 'EUR', '4735', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'While', 'concerns', 'remain', 'longer', 'term', '', 'size', 'scale', 'may', 'enable', 'Nokia', 'hold', 'newfound', 'margin', 'improvements', 'near', 'term', '', '', 'analyst', 'wrote', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', '', 'HEL', '', 'CTH1V', '', 'said', 'today', 'net', 'loss', 'narrowed', 'EUR', '500000', '', 'USD', '680000', '', 'last', 'quarter', '2010', 'EUR', '53', 'million', 'period', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Finnish', 'consumer', 'packaging', 'manufacturer', 'Huhtamaki', 'Oyj', 'said', 'swung', 'net', 'profit', '841', 'mln', 'euro', '', '1056', 'mln', 'first', 'nine', 'months', '2006', 'net', 'loss', '26', 'mln', 'euro', '', '33', 'mln', 'period', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'high', 'technology', 'provider', 'Vaahto', 'Group', 'reports', 'net', 'sales', 'EUR', '418', 'mn', 'accounting', 'period', 'September', '2007', '', 'February', '2008', '', 'increase', '112', '', 'year', 'earlier', '']
# Sentence after removing stopwords: ['By', 'implementing', 'software', 'Finnish', 'Army', 'aims', 'unify', 'improve', 'operations', 'application', 'areas', '', 'QPR', 'Software', 'stated', '']
# Sentence after removing stopwords: ['At', 'press', 'conference', '', 'Lattelecom', 'board', 'chairman', 'Nils', 'Melngailis', 'explained', 'Blackstone', 'chosen', 'experience', 'IT', 'sector', 'well', 'financial', 'strength', '']
# Sentence after removing stopwords: ['Finnish', 'pharmaceuticals', 'company', 'Orion', 'reports', 'profit', 'taxes', 'EUR', '700', 'mn', 'third', 'quarter', '2010', '', 'EUR', '549', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '06', 'mn', 'EUR', '04', 'mn', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '1034', 'mn', 'EUR', '232', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['The', 'OMX', 'Helsinki', '25', 'index', '092', 'pct', '251867', 'Helsinki', 'CAP', 'portfolio', 'index', '091', 'pct', 'higher', '471119', '']
# Sentence after removing stopwords: ['', 'ADPnews', '', '', 'Nov', '9', '', '2009', '', 'Four', 'companies', 'agreed', 'buy', 'combined', 'SEK', '59', 'billion', '', 'USD', '854mEUR', '5718', '', 'drug', 'stores', 'offered', 'sale', 'part', 'restructuring', 'Swedish', 'statedowned', 'pharmacy', 'monopoly', 'Apoteket', 'AB', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Lietuva', '', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'Kesko', 'Group', '', 'boosted', 'sales', '429', 'percent', '134', 'million', 'euros', '', 'VAT', 'inclusive', '']
# Sentence after removing stopwords: ['According', 'company', 'updated', 'strategy', 'years', '20092012', '', 'Basware', 'targets', 'longterm', 'net', 'sales', 'growth', 'range', '20', '', '40', '', 'operating', 'profit', 'margin', '10', '', '20', '', 'net', 'sales', '']
# Sentence after removing stopwords: ['Iggesunds', 'Bruk', 'Sweden', 'one', 'advanced', '', 'fully', 'integrated', 'pulp', 'paperboard', 'mills', 'world', '']
# Sentence after removing stopwords: ['UPMKymmene', 'working', 'closely', 'shipping', 'agents', 'reduce', 'fuel', 'consumption', 'greenhouse', 'gas', 'emissions', '']
# Sentence after removing stopwords: ['Metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'China', 'Lee', '', 'Man', 'Paper', 'Co', '']
# Sentence after removing stopwords: ['In', 'Q1', '2010', '', 'Bank', 'land', 'net', 'interest', 'income', 'increased', 'EUR', '91', 'mn', 'EUR', '97', 'mn', '']
# Sentence after removing stopwords: ['Separately', '', 'YIT', 'Corporation', 'Austrian', 'firm', 'E', 'AG', 'last', 'week', 'signed', 'agreement', 'sale', 'E', 'building', 'system', 'service', 'business', 'Germany', '', 'Austria', '', 'Poland', '', 'Czech', 'Republic', '', 'Hungary', 'Romania', 'EUR', '55', 'mln', '']
# Sentence after removing stopwords: ['Orders', 'received', 'grew', '55', '', 'yearonyear', 'EUR732m', '']
# Sentence after removing stopwords: ['Forestries', 'also', 'higher', '', 'driven', 'yesterday', 'bullish', 'analyst', 'comment', 'Stora', 'Enso', 'Dagens', 'Industri', '', 'dealers', 'said', '']
# Sentence after removing stopwords: ['The', 'group', 'expand', 'chain', 'include', '45', 'stores', '']
# Sentence after removing stopwords: ['Last', 'year', 'company', 'raised', 'turnover', 'approximately', '7', 'million', 'litas', 'EUR', '2', 'mln', '', '61', 'million', 'litas', '2004', '']
# Sentence after removing stopwords: ['Sales', 'expected', 'increase', 'end', 'year', '2006', '', 'however', '']
# Sentence after removing stopwords: ['Comparable', 'net', 'sales', 'expected', 'increase', '10', '', '2008', '', 'line', 'group', 'target', '']
# Sentence after removing stopwords: ['Kalmar', 'awarded', 'new', '5year', 'contract', 'supply', 'Rough', 'Terrain', 'Container', 'Handler', 'RTCH', '']
# Sentence after removing stopwords: ['The', 'company', 'also', 'featured', 'Ethibel', 'Pioneer', 'Investment', 'Register', 'included', 'Innovest', 'Global', '100', 'list', 'world', 'sustainable', 'corporations', '']
# Sentence after removing stopwords: ['In', 'AsiaPacific', 'region', '', 'Visa', 'Wave', 'available', 'Malaysia', '', 'Taiwan', 'South', 'Korea', 'expanded', 'Japan', 'Southeast', 'Asia', 'year', '', 'Jung', 'added', '']
# Sentence after removing stopwords: ['', 'Following', 'last', 'year', 'good', 'profit', 'development', '', 'entered', 'current', 'year', 'good', 'position', '']
# Sentence after removing stopwords: ['The', 'companies', 'agreed', 'longterm', 'cooperation', 'mechanise', 'harvesting', 'Stora', 'Enso', 'eucalyptus', 'plantations', 'Southern', 'China', '']
# Sentence after removing stopwords: ['Outotec', 'said', 'new', 'orders', 'worth', '4929', 'mln', 'eur', 'quarter', '', 'compared', '2404', 'mln', 'eur', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Sales', 'Department', 'Store', 'Division', 'Hobby', 'Hall', 'increased', '7', '', '', 'sales', 'clothing', 'store', 'subsidiary', 'Seppala', 'decreased', '4', '', '']
# Sentence after removing stopwords: ['Global', 'Banking', 'News', '', '28', 'September', '2010', 'Tieto', 'Corporation', 'Pohjola', 'Bank', '', 'PINK', '', 'POJLF', '', 'cooperate', 'SWIFT', 'services', '']
# Sentence after removing stopwords: ['Poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'Latin', 'America', '']
# Sentence after removing stopwords: ['Tekla', 'implement', 'renewal', 'software', 'versions', 'introduced', 'spring', '2011', '']
# Sentence after removing stopwords: ['Sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'EUR', '393', 'mn', '', 'EUR', '327', 'mn', '']
# Sentence after removing stopwords: ['', 'Operating', 'profit', 'rose', '269', '', 'EUR', '1058', '', '834', '', 'million', '']
# Sentence after removing stopwords: ['Then', '', 'said', 'contract', 'estimated', 'contribute', 'EUR150m', 'net', 'sales', '2010', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '1019', 'mn', 'EUR', '1007', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Mobile', 'phone', 'sales', 'rose', '25', '', '587', 'billion', 'euros', '', 'enterprise', 'solution', 'sales', 'dropped', '39', '', '186', 'million', 'euros', '']
# Sentence after removing stopwords: ['The', 'pilot', 'project', 'proved', 'RIFD', 'technology', 'ideal', 'purposes', '', '', 'comments', 'Olli', 'Saarinen', '', 'Material', 'Handling', 'Supervisor', 'Yara', '']
# Sentence after removing stopwords: ['The', 'robust', 'growth', 'result', 'inclusion', 'clothing', 'chain', 'Lindex', 'Group', 'December', '2007', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '5mn', 'EUR', '28', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['TELECOMWORLDWIRE7', 'April', '2006TJ', 'Group', 'Plc', 'sells', 'stake', 'Morning', 'Digital', 'Design', 'Oy', 'Finnish', 'IT', 'company', 'TJ', 'Group', 'Plc', 'said', 'Friday', '7', 'April', 'signed', 'agreement', 'selling', 'shares', 'Morning', 'Digital', 'Design', 'Oy', 'Edita', 'Oyj', '']
# Sentence after removing stopwords: ['CEO', 'company', 'Tarmo', 'Noop', 'said', 'growth', 'sale', 'premium', 'beers', 'biggest', '']
# Sentence after removing stopwords: ['Finnish', 'Bank', 'land', 'reports', 'operating', 'profit', 'rose', 'EUR', '213', 'mn', 'second', 'quarter', '2009', 'EUR', '61', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['The', 'respondents', 'praised', 'Finnair', 'reliability', '', 'Finnishness', '', 'understanding', 'target', 'group', '']
# Sentence after removing stopwords: ['South', 'African', 'Sappi', 'become', 'largest', 'foreign', 'forest', 'industry', 'company', 'operating', 'Finland', 'result', 'acquisition', 'Finnish', 'Mreal', 'Corporation', 'Graphic', 'Papers', 'Business', 'unit', '']
# Sentence after removing stopwords: ['Progress', 'Group', '', 'QPR', 'representative', 'Saudi', 'Arabia', 'North', 'Africa', '', 'signed', 'framework', 'agreement', 'long', 'term', 'strategic', 'relationship', 'ISE', '']
# Sentence after removing stopwords: ['NASDAQlisted', 'Yahoo', 'Inc', 'introduced', 'new', 'service', 'enables', 'Malaysians', 'take', 'favorite', 'Internet', 'content', 'services', 'mobile', 'phones', '']
# Sentence after removing stopwords: ['On', 'hand', '', 'Montevideo', 'said', 'two', 'mills', 'working', 'area', 'generate', 'jobs', '']
# Sentence after removing stopwords: ['In', 'accordance', 'strategy', '', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'South', 'Africa', 'October', '']
# Sentence after removing stopwords: ['We', 'position', 'pursue', 'novel', 'clinical', 'candidates', 'going', 'forward', '', '']
# Sentence after removing stopwords: ['Shareholders', 'Rakvere', 'Lihakombinaat', 'decided', 'favor', 'buyout', 'minority', 'shares', 'midJuly', '']
# Sentence after removing stopwords: ['Fiskars', '', '360yearold', 'global', 'business', 'best', 'known', 'orangehandled', 'scissors', '', 'expects', 'derive', 'synergies', 'EUR5', 'million', 'year', 'consolidating', 'certain', 'parts', 'housewares', 'division', 'two', 'compete', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'increased', '45', '', 'EUR', '314', 'mn', 'EUR', '300', 'mn', '2004', '']
# Sentence after removing stopwords: ['Microsoft', 'also', 'churned', 'courtship', '', 'agreeing', 'use', 'Navteq', 'mapping', 'service', '', 'offered', 'company', 'Nokia', 'bought', '', '81', 'billion', 'years', 'ago', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '04', 'mn', '', 'operating', 'loss', 'EUR', '08', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['The', 'apartment', 'block', 'welllocated', '', 'easy', 'reach', 'city', 'center', 'close', 'school', 'kindergarten', '']
# Sentence after removing stopwords: ['The', 'policy', 'also', 'aimed', 'making', 'companies', 'profitable', 'competitive', '']
# Sentence after removing stopwords: ['EBIT', 'excluding', 'nonrecurring', 'items', '', 'totalled', 'EUR', '678', 'mn', '', 'EUR', '381', 'mn', '']
# Sentence after removing stopwords: ['By', 'acquiring', 'RCP', '', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company', '']
# Sentence after removing stopwords: ['Lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'Kaluga', 'regional', 'administration', 'last', 'November', '']
# Sentence after removing stopwords: ['Finnish', 'telecoms', 'software', 'developer', 'Tecnomen', 'Oyj', 'said', 'December', '5', '', '2006', '', '33', 'mln', '', '25', 'mln', 'euro', '', 'order', 'supply', 'expansion', 'charging', 'messaging', 'systems', 'mobile', 'fixed', 'networks', 'Brasil', 'Telecom', '']
# Sentence after removing stopwords: ['', 'Very', 'recommendable', '', 'Nokian', 'Z', 'G2', 'according', '', 'ADAC', 'judgement', '', 'latest', 'summer', 'tyre', 'test', 'German', 'automobile', 'association', 'ADAC', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', '27', '', 'EUR', '5798', 'mn', 'EUR', '4572', 'mn', '2006', '']
# Sentence after removing stopwords: ['Finnish', 'IT', 'consultancy', 'Satama', 'Interactive', 'Oyj', 'posted', 'net', 'profit', '14', 'mln', 'euro', '', '20', 'mln', 'first', 'nine', 'months', '2007', '', 'compared', 'net', 'loss', '462000', 'euro', '', '664000', 'period', '2006', '']
# Sentence after removing stopwords: ['Rapala', 'said', 'estimates', 'make', 'savings', '12', 'mln', 'eur', 'year', 'centralising', 'French', 'operations', 'one', 'site', '']
# Sentence after removing stopwords: ['This', 'second', 'successful', 'effort', 'financial', 'investor', 'year', '']
# Sentence after removing stopwords: ['Net', 'sales', 'went', '1', '', 'yearonyear', 'EUR', '29', 'million', '', 'affected', 'business', 'acquisitions', '', 'realized', 'previous', 'financial', 'period', '', 'effect', 'EUR', '51', 'million', 'review', 'period', '']
# Sentence after removing stopwords: ['Its', 'market', 'share', 'widened', '4851', 'percent', '4831', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['And', 'broker', 'repeated', '', 'buy', '', 'rating', '', 'based', 'expectations', 'current', 'restructuring', 'lead', 'clear', 'improvement', 'performance', 'Europe', '2007', '']
# Sentence after removing stopwords: ['In', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'loss', 'narrowed', 'EUR415', '000', 'EUR7', '4', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Dubbed', 'Nokia', 'Money', 'Solutions', '', 'company', 'officials', 'say', 'initiative', 'would', 'seek', 'bridge', 'gap', 'banked', 'unbanked', 'developing', 'countries', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'owns', '43', 'percent', 'Bergvik', 'earns', 'therefore', 'SEK', '15', 'bn', 'value', 'appreciation', '']
# Sentence after removing stopwords: ['Latvenergo', 'ordered', 'significant', 'expansion', 'Tekla', 'Xpower', 'network', 'information', 'system', '']
# Sentence after removing stopwords: ['With', 'acquisition', 'Panostaja', 'Oyj', 'expands', 'business', 'area', 'specialising', 'digital', 'printing', '']
# Sentence after removing stopwords: ['Estonian', 'telecoms', 'company', 'Elisa', 'customer', 'numbers', 'cross', '400000', 'TALLINN', '', 'Oct', '22', '', 'BNS', '', 'The', 'Estonian', 'telecommunications', 'company', 'Elisa', 'approximately', '50000', 'new', 'clients', 'nine', 'months', 'year', '', 'bringing', 'number', '401800', 'end', 'September', '', 'company', 'said', '']
# Sentence after removing stopwords: ['DMASIA16', 'August', '2006Benefon', 'extends', 'manufacturing', 'capability', 'ASMobile', '', '2006', 'Digitalmediaasiacom', '', 'DMA', 'Ltd', '']
# Sentence after removing stopwords: ['OUTOTEC', 'OYJ', 'PRESS', 'RELEASE', 'DECEMBER', '4', '', '2009', '1030', 'AM', 'Outotec', 'establishes', 'new', 'subsidiary', 'Kolkata', 'Outotec', 'established', 'subsidiary', 'India', 'order', 'better', 'serve', 'Indian', 'customers', 'increase', 'business', 'growing', 'Indian', 'market', '']
# Sentence after removing stopwords: ['The', 'total', 'delivery', 'volume', 'paper', 'businesses', '2010', '1155000', 'tonnes', '', '1132000', 'tonnes', '2009', '']
# Sentence after removing stopwords: ['Loss', 'taxes', 'amounted', 'EUR', '12', 'mn', 'compared', 'loss', '26', 'mn', '']
# Sentence after removing stopwords: ['The', 'GeoSolutions', 'technology', 'leverage', 'Benefon', 'GPS', 'solutions', 'providing', 'Location', 'Based', 'Search', 'Technology', '', 'Communities', 'Platform', '', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model', '']
# Sentence after removing stopwords: ['Growth', 'expected', 'continue', '2008', '']
# Sentence after removing stopwords: ['Total', 'operating', 'revenue', 'grew', '276', '', 'yearonyear', 'EUR61m', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Feb', '11', '', '2009', '', 'Finnish', 'management', 'software', 'solutions', 'provider', 'Ixonos', 'Oyj', '', 'HEL', '', 'XNS1V', '', 'said', 'today', 'net', 'profit', 'rose', 'EUR', '35', 'million', '', 'USD', '45', '', '2008', 'EUR', '31', 'million', '2007', '']
# Sentence after removing stopwords: ['Stockmann', 'Swedish', 'sector', 'company', 'AB', 'Lindex', 'entered', 'agreement', 'September', '30', '', '2007', '', 'whereby', 'Stockmann', '', 'whollyowned', 'subsidiary', '', 'make', 'public', 'tender', 'offer', 'Lindex', 'issued', 'shares', '']
# Sentence after removing stopwords: ['However', '', 'bottomline', 'result', 'improved', 'thanks', 'positive', 'financial', 'items', '']
# Sentence after removing stopwords: ['The', 'contract', 'signed', 'August', 'Papua', 'New', 'Guineabased', 'Lihir', 'Gold', 'Ltd', 'ASX', '', 'LGL', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['The', 'company', 'operating', 'income', '', 'EBIT', '', 'totalled', 'EUR', '00', 'mn', '', 'EUR', '03', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Profitability', '', 'EBIT', '', '', '139', '', '', 'compared', '131', '', 'previousyear', 'period', '']
# Sentence after removing stopwords: ['', 'We', 'pleased', 'efforts', 'negotiating', 'teams', 'look', 'forward', 'productive', 'four', 'years', 'ahead', '', '']
# Sentence after removing stopwords: ['Componenta', 'increased', 'stake', 'Turkish', 'steel', 'company', 'Doktas', 'Dokumculuk', 'Ticaret', 'Sanayi', 'AS', '926', 'pct', 'stake', 'March', '2007', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['LONDON', 'AFX', '', 'Shares', 'Rautaruukki', 'Corp', 'upgraded', '', 'hold', '', '', 'sell', '', 'ABN', 'Amro', '', 'price', 'target', 'raised', '2575', 'eur', '145', '', 'said', 'dealers', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Dec', '11', '', '2008', '', 'Finnish', 'construction', 'engineering', 'company', 'Outotec', 'Oyj', '', 'OMX', '', 'OTE1V', '', 'said', 'today', 'EUR', '28', 'million', '', 'USD', '368', '', 'order', 'expand', 'phosphate', 'concentrator', 'Siilinjarvi', 'Norwegian', 'minera']
# Sentence after removing stopwords: ['services', 'supplier', 'Efore', 'Plc', 'streamline', 'operations', 'Finland', 'US', 'Finnish', 'electronic', 'systems', 'services', 'supplier', 'Efore', 'Plc', '', 'OMX', 'Helsinki', '', 'EFO1V', '', 'said', 'Tuesday', '', '3', 'February', '', 'initiated', 'statutory', 'negotiations', 'regarding', 'streamlining', 'operations', 'Finland', '']
# Sentence after removing stopwords: ['However', '', 'total', 'orders', 'received', 'still', 'last', 'year', 'levels', '']
# Sentence after removing stopwords: ['SysOpen', 'Digia', 'signed', 'agreement', 'main', 'shareholders', 'Sentera', 'holding', 'total', '7739', '', 'share', 'capital', 'votes', 'Sentera', '']
# Sentence after removing stopwords: ['According', 'CEO', 'Nordea', 'Bank', 'Estonia', 'Vahur', 'Kraft', '', 'Nordea', 'Finland', 'Stockmann', 'cooperating', 'ten', 'years', '']
# Sentence after removing stopwords: ['The', 'Bristol', 'Port', 'Company', 'sealed', 'one', 'million', 'pound', 'contract', 'Cooper', 'Specialised', 'Handling', 'supply', 'four', '45tonne', '', 'customised', 'reach', 'stackers', 'Konecranes', '']
# Sentence after removing stopwords: ['In', 'autumn', '', 'plans', 'expand', 'service', 'St', 'Petersburg', 'Moscow', 'launch', 'service', 'Yekaterinburg', '', 'Russia', '', 'flying', 'three', 'times', 'week', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafers', 'manufacturer', 'Okmetic', 'Oyj', 'said', 'June', '29', '', '2007', 'signed', 'agreement', 'Nordea', 'Bank', 'Finland', 'Plc', '', 'local', 'subsidiary', 'Swedish', 'commercial', 'bank', 'Nordea', 'Bank', 'AB', '', 'refinance', 'Okmetic', 'syndicated', 'bank', 'facility', 'amounts', '20', 'mln', 'euro', '', '', '269', 'mln', '', '']
# Sentence after removing stopwords: ['We', 'capitalize', 'experience', 'number', 'similar', 'bridge', 'projects', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['Managing', 'Director', 'Kari', 'Inkinen', 'says', 'Sponda', 'leasing', 'operations', 'developed', 'highly', 'favourably', '']
# Sentence after removing stopwords: ['GeoSentric', 'Oyj', 'GeoSolutions', 'Business', 'Unit', 'GyPSii', '', 'mobile', 'digital', 'lifestyle', 'application', 'geomobility', 'social', 'networking', 'platform', '', 'signed', 'agreement', 'Nanjing', 'MyNet', 'make', 'GyPSii', 'mobile', 'social', 'networking', 'platform', 'available', 'customers', 'China', 'Mobile', '']
# Sentence after removing stopwords: ['It', 'also', 'turned', 'earnings', 'per', 'share', '', 'EPS', '', 'EUR', '044', 'versus', 'loss', 'per', 'share', 'EUR', '226', '']
# Sentence after removing stopwords: ['Tallink', 'claims', 'watertight', 'doors', 'Vana', 'Tallinn', 'Regina', 'Baltica', '', 'including', 'electrical', 'systems', '', 'fully', 'working', 'order', '']
# Sentence after removing stopwords: ['The', '5050', 'joint', 'venture', '', 'called', 'Nokia', 'Siemens', 'Networks', '', 'comprised', 'Nokia', 'network', 'business', 'group', 'Siemens', '', 'carrierrelated', 'operations', '', 'creating', 'estimated', 'synergies', '15', 'billion', 'euros', '', '', '19', 'billion', '', '2010', '', 'Nokia', 'said', '']
# Sentence after removing stopwords: ['In', 'banking', '', 'Sampo', 'A', 'unchanged', '1424', 'eur', 'Nordea', 'rose', '042', 'pct', '951', 'eur', '']
# Sentence after removing stopwords: ['Finnish', 'Raisio', '', 'Diagnostics', '', 'launching', 'new', 'DNAbased', 'quick', 'tests', 'ensure', 'safety', 'food', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '830', 'mn', '', 'EUR', '235', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Pearl', 'Plaza', 'LLC', '', 'joint', 'venture', 'SRV', 'Shanghai', 'Industrial', 'Investment', 'Holdings', 'Co', 'Ltd', '', 'concluded', 'investment', 'decision', 'construction', 'first', 'phase', 'shopping', 'center', 'Saint', 'Petersburg', '', 'Russia', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['Alma', 'Media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously', '']
# Sentence after removing stopwords: ['Exports', 'accounted', '654', '', 'net', 'sales', '', 'representing', 'time', 'record', 'company', '']
# Sentence after removing stopwords: ['Construction', 'volumes', 'meanwhile', 'grow', 'rate', '1015', 'percent', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'mobile', 'operator', 'DNA', 'function', 'subcontractor', 'Maingate', 'responsible', 'telecommunications', 'connections', '']
# Sentence after removing stopwords: ['The', 'Group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets', '']
# Sentence after removing stopwords: ['Outotec', 'net', 'profit', 'second', 'quarter', '2007', 'jumped', '168', 'mln', 'euro', '', '', '231', 'mln', '', '46', 'mln', 'euro', '', '', '63', 'mln', '', 'year', 'ago', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'guided', 'EBIT', 'sales', 'growth', '20', 'pct', '10', 'pct', 'respectively', 'year', '']
# Sentence after removing stopwords: ['According', 'Nordic', 'financial', 'group', 'Nordea', 'analyst', 'Sami', 'Sarkamies', '', 'makes', 'Nokia', 'portfolio', 'competitive', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Significance', '', 'Teleste', 'emphasised', 'large', 'size', 'growing', 'economy', '', 'well', 'rapid', 'development', 'TV', 'services', 'distribution', 'industry', '', 'Poland', 'viewed', 'attractive', 'market', '']
# Sentence after removing stopwords: ['The', 'energyefficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'stateoftheart', 'technology', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Retail', 'wholesale', 'group', 'Kesko', 'reported', 'net', 'sales', '6594', 'mln', 'eur', 'February', '', 'increase', '108', 'pct', 'yearonyear', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', 'higher', '048', '037', 'year', 'ahead', 'market', 'consensus', '040', 'eur', '']
# Sentence after removing stopwords: ['Sanoma', 'Magazines', 'Finland', 'net', 'sales', 'grew', 'EUR', '1401', 'mn', 'EUR', '1318', 'mn', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'part', 'Ramirent', 'strategy', 'strengthen', 'position', 'selected', 'locations', '']
# Sentence after removing stopwords: ['It', 'estimates', 'operating', 'profit', 'improve', 'third', 'quarter', '']
# Sentence after removing stopwords: ['Ragutis', '', 'controlled', 'Finnish', 'brewery', 'Olvi', '', 'achieved', '57', 'percent', 'rise', 'beer', 'sales', '226', 'million', 'liters', 'held', '1075', 'percent', 'market', 'share', '']
# Sentence after removing stopwords: ['TomTom', 'given', 'assurances', 'continue', 'sell', 'maps', 'competitors', 'wins', 'EU', 'approval', '']
# Sentence after removing stopwords: ['For', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'profit', 'rose', 'EUR41m', 'EUR30m', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Exports', 'grew', '165', 'percent', '191', 'million', 'liters', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Diluted', 'loss', 'per', 'share', 'stood', 'EUR', '015', 'versus', 'EUR', '026', '']
# Sentence after removing stopwords: ['Nokia', '012', 'pct', '1670', 'eur', 'kicking', 'morning', 'negative', 'territory', '']
# Sentence after removing stopwords: ['The', 'borrower', 'happy', 'roadshow', 'paid', 'hit', 'ratio', 'high', '']
# Sentence after removing stopwords: ['Adjusted', 'changes', 'Group', 'structure', '', 'Division', 'net', 'sales', 'increased', '17', '', '']
# Sentence after removing stopwords: ['Cision', 'says', 'sale', 'return', 'UK', 'operation', 'profitability', '']
# Sentence after removing stopwords: ['Finnish', 'Okmetic', 'manufactures', 'processes', 'silicon', 'wafers', 'semiconductor', 'sensor', 'industries', 'Norwegian', 'solar', 'wafer', 'company', 'NorSun', 'signed', 'contract', 'Okmetic', 'supply', 'NorSun', 'mono', 'silicon', 'crystals', 'use', 'solar', 'cell', 'manufacturing', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafer', 'technology', 'company', 'Okmetic', 'Oyj', 'OMX', 'Helsinki', '', 'OKM1V', 'reported', 'Thursday', '30', 'October', 'operating', 'profit', 'EUR7', '4', 'JanuarySeptember', '2008', '', 'EUR6', '1', 'corresponding', 'period', '2007', '']
# Sentence after removing stopwords: ['Also', '', 'bringing', '', 'right', 'kind', 'people', '', 'upgrade', 'human', 'resources', '']
# Sentence after removing stopwords: ['About', 'Elcoteq', 'Elcoteq', 'SE', 'leading', 'electronics', 'manufacturing', 'services', '', 'EMS', '', 'company', 'communications', 'technology', 'field', '']
# Sentence after removing stopwords: ['Mr', 'Priit', 'Kasak', '', 'Balti', 'Metsamasina', 'owner', '', 'said', 'Rakverebased', 'company', 'wishes', 'increase', 'Valmet', 'market', 'share', '27', '', 'third', 'couple', 'years', '']
# Sentence after removing stopwords: ['Finland', 'Nokian', 'Tyres', 'Kazakhstan', 'Ordabasy', 'Corporation', 'signed', 'agreement', 'build', 'plant', 'Astana', 'produce', 'car', 'tires', '', 'Ordabasy', 'chairman', 'Dinmukhamet', 'Idrisov', 'said', 'press', 'conference', '']
# Sentence after removing stopwords: ['The', 'company', 'expects', 'net', 'sales', 'first', 'half', '2008', 'reach', 'previous', 'year', 'level', '']
# Sentence after removing stopwords: ['Ruukki', 'announced', 'signed', 'agreement', 'Aker', 'Solutions', 'Norway', 'supply', '24', 'suction', 'anchors', 'September', '2010', 'Kalajoki', 'unit', 'Finland', '']
# Sentence after removing stopwords: ['AUSTIN', '', 'Texas', '', 'Sept', '6', '', 'Texas', 'Department', 'Of', 'Transportation', 'awards', 'contract', 'Teleste', 'Video', 'Compression', 'Distribution', 'Equipment', '']
# Sentence after removing stopwords: ['The', 'price', 'raw', 'material', 'aluminium', 'went', 'end', '2005', '', 'company', 'considers', 'outlook', '2006', 'favourable', '']
# Sentence after removing stopwords: ['Finnish', 'automation', 'solutions', 'developer', 'Cencorp', 'Corporation', '', 'OMX', 'Helsinki', '', 'CNC1V', '', 'said', 'Friday', '', '27', 'June', '', 'completed', 'employee', 'negotiations', 'regarding', 'reorganisation', 'operations', '']
# Sentence after removing stopwords: ['The', 'company', 'committed', 'expanding', 'Apollo', 'portfolio', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'Nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout', '']
# Sentence after removing stopwords: ['The', 'company', 'moved', 'operating', 'profit', 'EUR10', '9', 'versus', 'operating', 'loss', 'EUR15', '3', 'It', 'also', 'turned', 'EPS', 'EUR0', '08', 'versus', 'loss', 'per', 'share', 'EUR0', '04', '']
# Sentence after removing stopwords: ['The', 'increase', 'capital', 'stock', 'registered', 'Finnish', 'Trade', 'Register', '20', 'November', '2006', '']
# Sentence after removing stopwords: ['Basware', 'Corporation', 'stock', 'exchange', 'release', 'August', '31', '', '2010', '1625', 'Basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'Basware', 'deliver', 'Invoice', 'Automation', 'solution', 'Connectivity', 'Services', 'international', 'industrial', 'group', '']
# Sentence after removing stopwords: ['20', 'October', '2010', '', 'Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', 'HEL', '', 'CTH1V', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'EUR7m', 'first', 'nine', 'months', '2010', 'EUR23', '3', 'period', '2009', '']
# Sentence after removing stopwords: ['In', 'January', '', 'traffic', '', 'measured', 'revenue', 'passenger', 'kilometres', 'RPK', '', 'went', '32', '', 'capacity', '', 'measured', 'available', 'seat', 'kilometres', 'ASK', '', 'rose', '122', '', '']
# Sentence after removing stopwords: ['Lule', 'municipality', 'awarded', 'YIT', '2year', 'contract', '', 'property', 'management', 'one', 'third', 'municipality', 'properties', '', 'total', 'area', '140000', 'sq', 'metres', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'jumped', 'EUR', '219', 'million', 'EUR', '31', 'million', '']
# Sentence after removing stopwords: ['Tekla', 'Structures', 'BIM', 'Building', 'Information', 'Modeling', 'software', 'developed', 'according', 'longterm', 'plan', 'improved', 'user', 'experience', '', 'process', '', 'functionality', '']
# Sentence after removing stopwords: ['Industry', 'Investment', 'interested', 'Glaston', 'solar', 'energy', 'projects', '']
# Sentence after removing stopwords: ['Sales', 'improved', 'SEK', '1553', 'mn', '', 'compared', 'SEK', '1408', 'mn', '']
# Sentence after removing stopwords: ['It', 'leading', 'private', 'road', 'ambulance', 'service', 'company', 'Finland', '']
# Sentence after removing stopwords: ['The', 'decision', 'sell', 'share', 'Lenenergo', 'reached', 'line', 'Fortum', 'strategic', 'plans', 'invest', 'mainly', 'generating', 'assets', 'Russia', '', 'Lenenergo', 'grid', 'company', '', 'press', 'release', 'said', '']
# Sentence after removing stopwords: ['It', 'projected', 'revenue', '', '22', 'billion', '', '23', 'billion', '', 'slightly', 'higher', 'analyst', 'estimates', '', '219', 'billion', '']
# Sentence after removing stopwords: ['These', 'measures', 'expected', 'produce', 'annual', 'cost', 'savings', 'EUR', '15', 'million', 'starting', '2007', '']
# Sentence after removing stopwords: ['', 'I', 'happy', 'outcome', '', '', 'Sneed', 'said', 'hearing', '']
# ...
# Sentence after removing stopwords: ['Net', 'sales', '2006', 'totaled', 'EUR', '302', 'million', 'operating', 'margin', '16', '', '']
# Sentence after removing stopwords: ['The', 'Bank', 'land', 'acquired', 'private', 'banking', 'business', '', 'asset', 'management', '', 'share', 'brokerage', 'business', 'Kaupthing', 'Sweden', 'early', '2009', '']
# Sentence after removing stopwords: ['Quality', 'chargers', 'CHARGZ', 'brand', 'sold', 'selected', 'retail', 'stores', 'sales', 'locations', 'worldwide', '']
# Sentence after removing stopwords: ['industry', 'Asia', '\x88', 'Pakistan', '', 'Malaysia', '', 'Taiwan', 'Philippines', 'Today', '', 'Global', 'Research', '', 'Data', 'Services', 'going', 'publish', 'several', 'market', 'analyses', 'cement', 'markets', 'Asia', '']
# Sentence after removing stopwords: ['Glaston', 'wellknown', 'brands', 'Bavelloni', '', 'preprocessing', 'machines', 'tools', '', 'Tamglass', 'Uniglass', 'safety', 'glass', 'machines', 'Albat', '', 'Wirsam', 'software', 'solutions', '']
# Sentence after removing stopwords: ['A', 'Le', 'Coq', 'market', 'share', '413', 'percent', 'rival', 'beverage', 'group', 'Saku', '321', 'percent', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'June', '7', '', 'Michael', 'G', 'Williams', 'Newbury', 'Park', '', 'Calif', '', 'developed', 'network', 'device', '']
# Sentence after removing stopwords: ['', 'They', 'already', 'allocated', 'money', 'inventory', '']
# Sentence after removing stopwords: ['The', 'value', 'threeyear', 'contract', 'estimated', 'EUR40m', '']
# Sentence after removing stopwords: ['Each', 'option', 'right', 'entitles', 'holder', 'subscribe', 'one', 'new', 'share', 'subscription', 'price', 'EUR0', '045', 'subscription', 'period', 'ends', '31', 'December', '2013', '']
# Sentence after removing stopwords: ['Kaukopartio', 'Oy', 'acquired', 'specialized', 'knowledge', 'Far', 'Eastern', 'operations', '', 'industrial', 'sourcing', 'services', 'core', 'competence', '']
# Sentence after removing stopwords: ['The', 'value', 'orders', 'EUR', '25mn', '']
# Sentence after removing stopwords: ['The', 'owners', 'participated', 'business', 'operations', 'company', 'continue', 'Poyry', 'employment', 'transaction', '']
# Sentence after removing stopwords: ['Nokian', 'Tyres', '', 'tyres', 'considered', 'genuine', 'winter', 'tyres', 'Russia', '']
# Sentence after removing stopwords: ['Mr', 'McDonald', 'started', 'evening', 'set', '', 'featuring', 'hits', 'solo', 'career', 'Doobie', 'Brothers', 'years', 'selection', 'RB', 'cover', 'songs', 'met', 'mixed', 'results', '']
# Sentence after removing stopwords: ['Nokia', 'said', 'outcome', '', 'fair', 'responsible', 'social', 'plan', '', '']
# Sentence after removing stopwords: ['AffectoGenimap', 'builds', 'highly', 'customised', 'IT', 'solutions', 'customers', 'Finland', 'Baltic', 'countries', '']
# Sentence after removing stopwords: ['Votorantim', 'Celulose', 'e', 'Papel', '', 'VCP', '', 'part', 'Votorantim', 'Group', '', 'major', 'Brazilian', 'conglomerate', '']
# Sentence after removing stopwords: ['She', 'succeed', 'Krister', 'Kylas', '', 'decided', 'leave', 'TeliaSonera', '']
# Sentence after removing stopwords: ['The', 'dividend', 'paid', 'April', '15', '', '2008', 'shareholders', 'record', 'date', 'April', '8', '', '2008', 'entered', 'list', 'shareholders', 'kept', 'Finnish', 'Central', 'Securities', 'Depository', 'Ltd', '']
# Sentence after removing stopwords: ['Unbelievably', '', 'company', 'makes', '', 'Fiskars', 'Corporation', '', 'formed', '1649', 'Dutch', 'merchant', 'named', 'Peter', 'Thorwoste', 'given', 'charter', 'establish', 'blast', 'furnace', 'forging', 'operation', 'small', 'Finnish', 'village', 'Fiskars', '']
# Sentence after removing stopwords: ['The', 'number', 'class', 'A', 'shares', 'remains', 'unchanged', '9526089', 'shares', '']
# Sentence after removing stopwords: ['HELSINKI', 'AFX', '', 'Cargotec', 'said', 'bought', '95', 'pct', 'stake', 'Indital', 'Construction', 'Machinery', 'Ltd', '', 'Bangalorebased', 'company', 'makes', 'fork', 'lift', 'trucks', 'mobile', 'cranes', '', 'undisclosed', 'sum', '']
# Sentence after removing stopwords: ['Finnish', 'fibers', 'plastics', 'producer', 'Suominen', 'Corporation', 'OMX', 'Helsinki', '', 'SUY1V', 'reported', 'Wednesday', '22', 'October', 'operating', 'loss', 'EUR0', '8', 'net', 'sales', 'EUR55', '2', 'third', 'quarter', '2008', '']
# Sentence after removing stopwords: ['Swedish', 'telco', 'TeliaSonera', 'teaming', 'Friends', '', 'Swedish', 'organization', 'bullying', '', 'fight', 'bullying', 'children', 'teenagers', 'via', 'electronic', 'channels', '']
# Sentence after removing stopwords: ['Sanoma', 'also', 'Executive', 'Committee', '', 'accordance', 'Company', 'Articles', 'Association', '', 'prepares', 'proposals', 'matters', 'decided', 'noted', 'Board', 'Directors', '']
# Sentence after removing stopwords: ['3G', 'data', 'subscribers', 'also', 'helping', 'maintain', 'growth', 'levels', '', 'since', 'dataonly', 'subscriptions', 'push', 'multiple', 'SIM', 'ownership', '']
# Sentence after removing stopwords: ['', 'Printed', 'fabrics', 'related', 'design', 'expertise', 'always', 'core', 'Marimekko', 'business', 'brand', '']
# Sentence after removing stopwords: ['Feed', 'companies', 'Suomen', 'Rehu', 'Raisio', 'import', 'GMO', 'feed', '']
# Sentence after removing stopwords: ['The', 'engine', 'electrical', 'output', '18321', 'kW', '', 'making', 'largest', 'gas', 'powered', 'generating', 'set', 'world', '']
# Sentence after removing stopwords: ['This', 'lays', 'foundation', 'sustainable', 'business', 'development', 'long', 'term', '']
# Sentence after removing stopwords: ['The', 'Committee', 'proposes', 'following', 'remuneration', '', 'monthly', 'remuneration', 'EUR', '5000', 'Chairman', '', 'EUR', '3500', 'Deputy', 'Chairman', '', 'EUR', '2500', 'Board', 'members', '']
# Sentence after removing stopwords: ['Risto', 'Jalo', '', 'chief', 'executive', 'Dormus', 'Print', 'also', 'owner', 'remainder', 'company', '', 'keep', 'position', 'acquisition', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'Oct', '15', '', 'Aaron', 'Moss', 'Hampshire', '', 'Great', 'Britain', '', 'developed', 'ornamental', 'design', 'handset', '', 'US', 'Patent', '', 'Trademark', 'Office', 'announced', '']
# Sentence after removing stopwords: ['Yvonne', 'Jones', 'owner', 'Chameleon', 'Interiors', '']
# Sentence after removing stopwords: ['Citigroup', '', 'Inc', 'NYSE', '', 'C', '', 'Deutsche', 'Bank', 'NYSE', '', 'DB', 'Pohjola', 'Bank', 'lead', 'managers', 'sale', '']
# Sentence after removing stopwords: ['At', 'beginning', 'subscription', 'period', 'May', '2', '', '2006', 'share', 'subscription', 'price', 'B', 'option', 'right', 'EUR', '1022', 'per', 'share', '']
# Sentence after removing stopwords: ['In', '2005', 'bank', 'posted', 'net', 'profit', 'Lt', '82', 'mn', '']
# Sentence after removing stopwords: ['The', 'company', 'earlier', 'said', 'considering', 'different', 'strategic', 'options', 'struggling', 'lowcost', 'mobile', 'operator', '', 'including', 'divestment', 'holding', '']
# Sentence after removing stopwords: ['The', 'two', 'sellers', 'Finnish', 'National', 'Fund', 'RD', '', 'Sitra', '', 'Oras', 'Invest', 'Oy', '', 'also', 'sold', 'half', 'shareholdings', '', 'leaving', '38', 'pct', '32', 'pct', 'company', 'respectively', '']
# Sentence after removing stopwords: ['According', 'Gallup', 'Food', 'Farm', 'Facts', '', 'beef', 'consumption', 'totaled', '99mn', 'kilos', 'Finland', '2007', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'Alma', 'Media', 'focus', 'quality', 'developing', 'chain', 'operations', '']
# Sentence after removing stopwords: ['mr', 'Bakman', 'sees', 'also', 'expansion', 'options', 'TallinnHelisnki', 'link', '', 'claiming', 'however', '', 'operating', 'link', 'single', 'ship', 'enough', '']
# Sentence after removing stopwords: ['Since', 'registration', 'shares', 'subscribed', 'directed', 'share', 'issue', '', 'new', 'number', 'Panostaja', 'shares', 'voting', 'rights', '41733110', '']
# Sentence after removing stopwords: ['The', 'inaugural', 'speech', 'given', 'Hannu', 'Kyrolainen', '', 'Finland', 'Ambassador', 'Czech', 'Republic', '']
# Sentence after removing stopwords: ['Following', 'issue', '', 'new', 'shares', 'constitute', '10', 'percent', 'firm', 'capital', '']
# Sentence after removing stopwords: ['The', 'decision', 'made', 'whether', 'group', 'agrees', 'import', 'Estonian', 'meat', 'meat', 'products', 'Finland', '', 'paper', 'added', '']
# Sentence after removing stopwords: ['Measures', 'launched', 'immediately', 'due', 'finalized', 'first', 'quarter', '2010', '']
# Sentence after removing stopwords: ['', 'Our', 'approach', 'much', 'use', 'raw', 'materials', 'produced', 'line', 'principles', 'sustainable', 'development', '']
# Sentence after removing stopwords: ['With', 'second', 'phase', 'new', 'Innova', 'building', '', 'Tecnopolis', 'presence', 'Jyvaskyla', 'increase', 'total', 'approximately', '62000', 'floor', 'square', 'meters', '']
# Sentence after removing stopwords: ['Country', '', '', 'Germany', 'Sector', '', 'ConstructionReal', 'Estate', '', 'MachineryEngineering', 'Target', '', 'Caverion', 'GmbH', 'Buyer', '', 'YIT', 'Oyj', 'Deal', 'size', 'USD', '', '903', 'Type', '', 'Corporate', 'acquisition', 'Status', '', 'Agreed']
# Sentence after removing stopwords: ['Pharmaceutical', 'market', 'Netherlands', 'Global', 'Research', '', 'Data', 'Services', 'published', 'recently', 'market', 'analysis', 'pharmaceutical', 'markets', 'Netherlands', '']
# Sentence after removing stopwords: ['It', 'even', 'little', 'bit', 'higher', 'Yara', 'multiples', '', '', 'analyst', 'Helsinki', 'said', '']
# Sentence after removing stopwords: ['Finnish', 'plumbing', 'heating', 'systems', 'supplier', 'Uponor', 'announced', 'companywide', 'cost', 'reduction', 'program', 'August', '2008', '']
# Sentence after removing stopwords: ['Finnish', 'diversified', 'holding', 'company', 'Aspo', 'Oyj', 'said', 'September', '8', '', '2008', 'sell', 'Finnish', 'tape', 'business', 'Kaukomarkkinat', 'unit', 'local', 'Oy', 'Telpak', 'Ab', '']
# Sentence after removing stopwords: ['The', 'Polish', 'business', 'employs', '1000', 'people', '', 'net', 'sales', 'EUR', '70mn', '2007', '']
# Sentence after removing stopwords: ['The', 'reductions', 'implemented', 'immediately', '', 'beginning', 'October', '2009', '']
# Sentence after removing stopwords: ['The', 'company', '120', 'employees', 'annual', 'sales', 'approximately', 'EUR16m', '']
# Sentence after removing stopwords: ['Finnish', 'glass', 'technology', 'group', 'Glaston', 'Corporation', '', 'OMX', 'Helsinki', '', 'GLA1V', '', 'reported', 'Thursday', '', '14', 'August', '', 'operating', 'profit', 'EUR6', '5', 'net', 'sales', 'EUR201', '5', 'period', 'JanuarySeptember', '2008', '']
# Sentence after removing stopwords: ['', 'Nordea', 'definitely', 'big', 'Sampo', 'acquire', '', '', 'said', 'analyst', '', 'But', 'Sampo', 'would', 'appear', 'agenda', 'Nordea', 'ahead', 'privatisation', '']
# Sentence after removing stopwords: ['Bertrand', 'Sciard', 'vice', 'chairman', 'board', 'directors', 'Aldata', 'Solution', 'since', 'April', '2007', '']
# Sentence after removing stopwords: ['The', 'webcast', 'may', 'followed', 'online', 'company', 'website', 'wwwruukkicominvestors', '']
# Sentence after removing stopwords: ['In', 'Sweden', '', 'Gallerix', 'accumulated', 'SEK', 'denominated', 'sales', '1', '', 'EUR', 'denominated', 'sales', '11', '', '']
# Sentence after removing stopwords: ['Cramo', '', 'headquartered', 'Vantaa', '', 'Finland', '', 'rents', 'construction', 'machinery', 'equipment', '', 'well', 'rents', 'sells', 'modular', 'space', '']
# Sentence after removing stopwords: ['The', 'first', 'phase', 'logistics', 'complex', 'envisages', 'completion', '70000', 'sq', 'logistics', 'premises', 'gatehouse', 'building', 'November', '2008', '']
# Sentence after removing stopwords: ['The', 'proposal', 'shareholders', 'elect', 'Mr', 'Hannu', 'Krogerus', 'Board', 'based', 'long', 'unrivalled', 'experience', 'knowledge', 'matters', 'related', 'Elcoteq', '']
# Sentence after removing stopwords: ['', 'We', 'license', 'agreement', 'Nokia', 'Corp', 'part', 'expires', 'April', '9', '', '2007', '']
# Sentence after removing stopwords: ['The', 'platform', 'would', 'continue', 'development', 'framework', 'Symbian', 'MeeGo', '']
# Sentence after removing stopwords: ['The', 'new', 'Kroksberg', 'railway', 'tunnel', 'built', 'new', 'section', 'track', 'Harnosand', 'Veda', '', 'forming', 'part', 'line', 'follows', 'coast', 'Gulf', 'Bothnia', '']
# Sentence after removing stopwords: ['The', 'energy', 'sector', 'accounted', 'approximately', '33', '', 'steel', 'industry', '57', '', 'transportation', 'volume', '']
# Sentence after removing stopwords: ['Currently', 'Alfred', 'A', 'Palmberg', 'putting', 'finishing', 'touches', 'one', 'Finland', 'biggest', 'ever', 'replumbing', 'bathroom', 'refurbishment', 'projects', 'also', 'district', 'Vuosaari', '']
# Sentence after removing stopwords: ['The', 'prices', 'stainless', 'steel', 'also', 'rose', 'Europe', '']
# Sentence after removing stopwords: ['In', 'release', 'Oct', '28', '', 'Peab', 'said', 'two', 'businesses', 'continue', 'conducted', 'brands', 'Cliffton', 'Stockholm', 'Entreprenad', '', 'part', 'Peab', 'Group', '']
# Sentence after removing stopwords: ['We', 'serve', 'broad', 'range', 'customers', '', 'including', 'construction', 'process', 'industries', '', 'shipyards', '', 'public', 'sector', 'households', '']
# Sentence after removing stopwords: ['', 'Tweeple', 'check', 'following', '', 'cautious', 'clicking', 'URLs', 'tinyurls', '', '']
# Sentence after removing stopwords: ['Cargotec', 'sales', 'totalled', 'EUR', '34', 'billion', '2008', 'employs', 'approximately', '10500', 'people', '']
# Sentence after removing stopwords: ['The', 'expanded', 'plant', 'scheduled', 'operational', 'middle', 'October', '2009', '']
# Sentence after removing stopwords: ['The', 'machines', 'cease', 'production', 'end', 'February', '2007', '']
# Sentence after removing stopwords: ['All', 'rights', 'reserved', '']
# Sentence after removing stopwords: ['The', 'company', 'studying', 'feasibility', 'focusing', 'processed', 'meat', 'production', 'Vantaa', 'facilities', 'processing', 'fresh', 'meat', 'Forssa', 'facilities', '']
# Sentence after removing stopwords: ['The', 'opportunity', 'available', 'employees', '', 'however', '']
# Sentence after removing stopwords: ['The', 'broadbased', 'WIG', 'index', 'ended', 'Thursday', 'session', '01', 'pct', '6500334', 'pts', '', 'bluechip', 'WIG20', '113', '368715', 'pts', '']
# Sentence after removing stopwords: ['The', 'bank', 'leasing', 'arm', 'Nordea', 'Liising', 'ended', 'year', 'profit', '44', 'million', 'euros', '']
# Sentence after removing stopwords: ['To', 'number', 'one', 'means', 'creating', 'added', 'value', 'stakeholders', 'everything', '']
# Sentence after removing stopwords: ['The', 'companies', 'divest', 'UPM', 'Fray', 'Bentos', 'pulp', 'mill', 'Forestal', 'Oriental', '', 'company', 'specialising', 'eucalyptus', 'cultivation', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'produces', 'many', 'turkey', 'products', '', 'cold', 'cuts', '']
# Sentence after removing stopwords: ['Mr', 'Kari', 'Stadigh', 'carry', 'Chairman', 'Board', 'Mr', 'Matti', 'Arteva', 'ViceChairman', '']
# Sentence after removing stopwords: ['The', 'Russian', 'government', 'contribute', '20', '', 'necessary', 'funds', '', 'said', '']
# Sentence after removing stopwords: ['Nordstjernan', 'used', 'option', 'buy', 'another', '224', '', 'stake', 'Salcomp', 'shares', 'votes', '']
# Sentence after removing stopwords: ['Mreal', 'Corporation', 'Stock', 'Exchange', 'Announcement', '29', 'September', '2006', '415', 'pm', 'Kyro', 'Corporation', 'Mreal', 'Corporation', '', 'Metsaliitto', 'Group', 'subsidiary', '', 'agreed', 'arrangement', 'gives', 'Mreal', 'option', 'purchase', 'Kyroskoski', 'natural', 'gas', 'powerplant', 'Kyro', '']
# Sentence after removing stopwords: ['Its', 'total', 'annual', 'revenue', 'comes', '160', 'mln', 'zloty', '', '', '569', 'mln42', '3', 'mln', 'euro', '', '']

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive2=pd.DataFrame(sorted(positiveValues2.items(),key=lambda x:x[1],reverse=True))
df_negative2=pd.DataFrame(sorted(negativeValues2.items(),key=lambda x:x[1],reverse=True))
df_neutral2=pd.DataFrame(sorted(neutralValues2.items(),key=lambda x:x[1],reverse=True))

# %%
pd1bi=df_positive2[0][:10]
pd2bi=df_positive2[1][:10]

ned1bi=df_negative2[0][:10]
ned2bi=df_negative2[1][:10]

nud1bi=df_neutral2[0][:10]
nud2bi=df_neutral2[1][:10]

plt.figure(1,figsize=(16,4))

plt.bar(pd1bi,pd2bi, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-BIGRAM ANALYSIS")

plt.savefig("positive-bigram.png")
plt.show()

# %%
df_positive2.head(10)
# Out:
#            0    1
# 0             156
# 1  net sales   59
# 2      2009    58
# 3        mn    55
# 4       said   51
# 5        EUR   41
# 6      euro    41
# 7      said    40
# 8      2008    39
# 9      2010    37

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1bi,ned2bi, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-BIGRAM ANALYSIS")

plt.savefig("negative-bigram.png")
plt.show()

# %%
df_negative2.head(10)
# Out:
#                       0   1
# 0                        59
# 1                   mn   48
# 2                   EUR  33
# 3                 2008   32
# 4                 2009   32
# 5                 2007   29
# 6      Operating profit  28
# 7  corresponding period  27
# 8             net sales  25
# 9              compared  25

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1bi,nud2bi, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-BIGRAM ANALYSIS")

plt.savefig("neutral-bigram.png")
plt.show()

# %%
df_neutral2.head(10)
# Out:
#              0    1
# 0               187
# 1     Finland    75
# 2  The company   70
# 3        said    54
# 4    net sales   51
# 5     million    50
# 6        2008    48
# 7        2007    44
# 8      company   43
# 9        2010    41

# %% [markdown]
# **Creating trigrams**

# %%
positiveValues3=defaultdict(int)
negativeValues3=defaultdict(int)
neutralValues3=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text,3):
    positiveValues3[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text,3):
    negativeValues3[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text,3):
    neutralValues3[word]+=1
# Out:
# Sentence after removing stopwords: ['The', 'concept', 'enables', 'commercially', 'affordable', 'way', 'manufacture', 'highquality', 'TCO', 'coated', 'glass', 'solar', 'industry', '']
# Sentence after removing stopwords: ['Talentum', 'expects', 'net', 'sales', 'core', 'business', 'increase', '2008', '', 'compared', '2007', '']
# Sentence after removing stopwords: ['By', 'cutting', 'number', 'plants', '', 'group', 'trim', 'fixed', 'costs', '']
# Sentence after removing stopwords: ['More', 'staff', 'recruited', 'Japan', 'complement', 'network', 'close', '50', 'service', 'locations', '20', 'countries', 'worldwide', '']
# Sentence after removing stopwords: ['Finnish', 'Swedish', 'construction', 'markets', 'still', 'experiencing', 'estimated', '4', '', 'annual', 'growth', '2008', '']
# Sentence after removing stopwords: ['In', 'addition', 'fireplace', 'exports', '', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['It', 'combines', 'perfect', 'price', 'performance', 'sophisticated', 'management', 'facilities', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '194', 'mn', 'EUR', '245', 'mn', '']
# Sentence after removing stopwords: ['Cash', 'flow', 'business', 'operations', 'totalled', 'EUR', '04', 'mn', 'compared', 'negative', 'EUR', '155', 'mn', 'first', 'half', '2008', '']
# Sentence after removing stopwords: ['', 'The', 'change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', '', '', 'said', 'Julia', 'Prohaska', '', 'director', 'marketing', 'communications', 'Fiskars', '']
# Sentence after removing stopwords: ['A', 'new', 'Kveyt', 'light', 'variety', 'Suomalainen', 'Pekoni', 'marketed', 'Atria', 'brand', 'name', 'available', 'consumers', 'Finland', '']
# Sentence after removing stopwords: ['Finnish', 'OKO', 'bank', 'signed', 'cooperation', 'agreement', 'Raiffeisen', 'concerning', 'Finnish', 'companies', '', 'investments', 'Russia', '']
# Sentence after removing stopwords: ['The', 'production', 'capacity', 'tripled', 'without', 'major', 'additional', 'investments', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Aspo', 'Plc', 'STOCK', 'EXCHANGE', 'RELEASE', 'February', '11', '', '2011', 'at8', '45', 'ESL', 'Shipping', 'Ltd', '', 'part', 'Aspo', 'Group', '', 'signed', 'new', '', 'longterm', 'contract', 'Rautaruukki', 'Corporation', 'marine', 'transport', 'raw', 'materials', 'Baltic', 'Sea', '']
# Sentence after removing stopwords: ['SKF', '6', 'April', '2010', '', 'Alandsbanken', 'given', '', 'buy', '', 'recommendation', 'Swedish', 'industrial', 'company', 'SKF', 'AB', '', 'STO', '', 'SKF', 'B', '', 'share', 'price', 'target', 'SEK150', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'anticipated', 'operating', 'profit', 'improve', 'period', '']
# Sentence after removing stopwords: ['Fiskars', 'strong', 'portfolio', 'international', 'brands', '', 'include', 'Fiskars', '', 'Iittala', '', 'Gerber', '', 'Silva', 'Buster', '']
# Sentence after removing stopwords: ['Ramirent', 'leading', 'company', 'machinery', 'equipment', 'rentals', 'construction', 'industry', '']
# Sentence after removing stopwords: ['Previously', 'company', 'estimated', 'operating', 'profit', 'reach', 'level', '2005', '']
# Sentence after removing stopwords: ['The', 'financial', 'impact', 'estimated', '15', 'MEUR', 'annual', 'improvement', 'division', 'result', '', 'starting', 'fiscal', 'year', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'technology', 'group', 'Aspocomp', 'Group', 'Oyj', '', 'OMX', 'Helsinki', '', 'ACG1V', '', 'issued', 'third', 'quarter', 'report', 'Thursday', '', '13', 'November', '', '', 'posting', 'operating', 'profit', 'EUR0', '4', '', 'compared', 'loss', 'EUR0', '5', 'third', 'quarter', '2007', '']
# Sentence after removing stopwords: ['The', 'agreement', 'provide', 'The', 'Switch', 'double', 'converter', 'capacity', '', 'whilst', 'opening', 'manufacturing', 'locations', 'China', '']
# Sentence after removing stopwords: ['Finnish', 'KCI', 'Konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'Indian', 'steel', 'producer', 'Bhushan', 'Steel', '', 'Strips', 'delivered', '2007', '']
# Sentence after removing stopwords: ['According', 'Bosse', '', 'present', 'cooperation', 'beneficial', 'parties', '', 'however', '']
# Sentence after removing stopwords: ['Proving', 'good', 'cellphone', 'design', 'truly', 'work', 'art', '', 'website', 'Nokia', '6131', 'provides', 'colorful', 'canvas', 'expression', 'mobileinspired', 'sentiments', '']
# Sentence after removing stopwords: ['In', 'China', '', 'Finnish', 'Kone', 'provides', 'elevators', '', 'escalators', '', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'highspeed', 'railway', 'section', 'Beijing', 'Shanghai', '15', 'years', '', 'time', '']
# Sentence after removing stopwords: ['One', 'colleagues', 'summed', 'E7', 'quite', 'aptly', 'remarked', '', '', 'Fantastic', 'hardware', '']
# Sentence after removing stopwords: ['Tiimari', '', 'Finnish', 'retailer', '', 'reported', 'geenrated', 'quarterly', 'revenues', 'totalling', 'EUR', '13', 'mn', '4th', 'quarter', '2009', '', 'EUR', '03', 'mn', 'loss', '2008', '']
# Sentence after removing stopwords: ['The', 'stock', 'rose', 'third', 'day', 'Tuesday', 'bringing', 'threeday', 'rise', 'GBX10', '50', '18', '', '']
# Sentence after removing stopwords: ['Adanac', 'Molybdenum', 'Canada', 'ordered', 'grinding', 'technology', 'molybdenum', 'project', 'British', 'Columbia', '', 'Canada', '', 'Shalkiya', 'Zinc', 'Kazakhstan', 'awarded', 'contract', 'grinding', 'technology', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['At', 'end', 'March', '2007', '', 'group', 'order', 'book', 'EUR', '396', 'mn', '', '42', '', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['The', 'EPS', 'improved', 'EUR0', '38', 'EUR0', '27', '']
# Sentence after removing stopwords: ['Mreal', 'sales', 'expected', 'increased', '4', '', 'yearonyear', 'EUR609m', 'second', 'quarter', '2010', '']
# Sentence after removing stopwords: ['Growth', 'strongest', 'FSecure', 'operator', 'ISPs', '', 'mobile', 'operators', 'cable', 'operators', 'business', '']
# Sentence after removing stopwords: ['Seppala', 'revenue', 'increased', '02', '', 'EUR10', '1', 'In', 'Finland', '', 'revenue', 'went', '24', '', 'EUR6', '8', '', 'sales', 'abroad', 'rose', '62', '', 'EUR3', '3', 'Sales', 'increased', 'Baltic', 'countries', 'well', 'Russia', 'Ukraine', '']
# Sentence after removing stopwords: ['The', 'rebuilds', 'designed', 'improve', 'machines', '', 'performance', 'product', 'quality', '']
# Sentence after removing stopwords: ['The', 'disposal', 'Autotank', 'also', 'strengthen', 'Aspo', 'capital', 'structure', '', '', 'commented', 'Gustav', 'Nyberg', '', 'CEO', 'Aspo', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'R', 'shares', 'rose', '120', 'pct', '1184', 'eur', '', 'UPMKymmene', 'also', 'dragged', 'higher', '', 'rising', '168', 'pct', '1756', 'eur', 'MReal', 'B', 'added', '238', 'pct', '430', 'eur', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['Nevertheless', '', 'market', 'share', 'rose', '4914', 'percent', '4851', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['EuroChem', 'CFO', 'Andrey', 'Ilyin', 'said', '', '', 'This', 'facility', 'marks', 'another', 'important', 'step', 'EuroChem', 'securing', 'longterm', 'financing', 'necessary', 'potash', 'strategic', 'projects', '', '']
# Sentence after removing stopwords: ['Precedex', 'approved', 'IV', 'sedation', 'initially', 'intubated', 'mechanically', 'ventilated', 'patients', 'intensive', 'care', '']
# Sentence after removing stopwords: ['It', 'provides', 'customers', 'industryleading', 'elevators', '', 'escalators', 'innovative', 'solutions', 'maintenance', 'modernization', '']
# Sentence after removing stopwords: ['The', 'Finnish', 'supplier', 'BSSOSS', 'VAS', 'telecom', 'operators', '', 'Tecnotree', '', 'received', 'expansion', 'orders', 'worth', 'total', 'US', '73', 'mn', 'convergent', 'charging', 'next', 'generation', 'messaging', 'solutions', 'Latin', 'America', '', 'company', 'announced', 'without', 'specifying', 'operators', 'placed', 'orders', '']
# Sentence after removing stopwords: ['credit', '20', 'November', '2009', '', 'Finnish', 'glass', 'technology', 'company', 'Glaston', 'Oyj', 'Abp', '', 'HEL', '', 'GLA1V', '', 'said', 'today', 'concluded', 'EUR74m', 'revolving', 'credit', 'facility', 'agreement', 'core', 'banks', '']
# Sentence after removing stopwords: ['Aspocomp', 'repaid', 'interest', 'bearing', 'liability', 'Standard', 'Chartered', 'Bank', 'use', 'rest', 'consideration', 'partially', 'repay', 'interest', 'bearing', 'liabilities', 'Finland', 'improve', 'liquidity', '']
# Sentence after removing stopwords: ['Operating', 'income', 'rose', 'EUR', '6964', 'mn', 'EUR', '6003', 'mn', '2009', '']
# Sentence after removing stopwords: ['Due', 'rapid', 'expansion', '', 'market', 'share', 'Tallink', 'terms', 'passenger', 'carriage', 'Tallinna', 'Sadam', 'Port', 'Tallinn', 'totaled', '55', 'percent', 'November', '457', 'percent', 'November', '2005', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'accounts', '50', '', 'poultry', 'sales', 'Finland', '', 'profitability', 'good', 'level', '']
# Sentence after removing stopwords: ['TELE2', 'Affarsvarlden', 'gave', '', 'buy', '', 'recommendation', 'mobile', 'operator', 'Tele2', 'AB', 'share', 'price', 'target', '142', 'crowns', '', '', '2354', '', '1519', 'euro', '', '']
# Sentence after removing stopwords: ['Operating', 'loss', 'EUR', '179mn', '', 'compared', 'loss', 'EUR', '188mn', 'second', 'quarter', '2009', '']
# Sentence after removing stopwords: ['The', 'sale', '', 'result', 'gain', 'EUR', '60', 'million', 'second', 'quarter', '2010', 'OriolaKD', '', 'supports', 'Finnish', 'company', 'strategy', 'focus', 'pharmaceutical', 'wholesale', 'retail', 'operations', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'totalled', 'EUR', '808', 'mn', '', 'compared', 'loss', 'EUR', '131', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['We', 'warmly', 'welcome', 'Satama', '', '', 'states', 'Jussi', 'Lansio', '', 'chairman', 'Board', '']
# Sentence after removing stopwords: ['This', 'new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties', '']
# Sentence after removing stopwords: ['Finnish', 'business', 'software', 'group', 'AffectoGenimap', 'Oyj', 'said', 'signed', 'agreement', 'acquire', 'shares', 'Swedish', 'sector', 'company', 'Intellibis', 'Ab', '12', 'mln', 'euro', '', '', '158', 'mln', '', 'debtfree', 'basis', '']
# Sentence after removing stopwords: ['Talvivaara', 'also', 'maintains', 'assumption', 'turning', 'cash', 'flow', 'positive', 'year', 'end', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['Dubai', 'Nokia', 'announced', 'launch', '', 'Comes', 'Music', '', '', 'groundbreaking', 'service', 'introduces', 'new', 'way', 'people', 'enjoy', 'music', '']
# Sentence after removing stopwords: ['Previously', '', 'EB', 'delivered', 'custom', 'solution', 'LG', 'Electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators', '']
# Sentence after removing stopwords: ['As', 'part', 'transaction', '', 'Mreal', 'Sappi', 'also', 'signed', 'longterm', 'agreement', 'supply', 'pulp', 'BCTMP', 'smaller', 'services', 'supplies', '']
# Sentence after removing stopwords: ['The', 'company', 'also', 'expects', 'sell', 'products', 'Russian', 'region', '']
# Sentence after removing stopwords: ['Nokia', 'continue', 'invest', 'future', 'development', 'Qt', 'benefit', 'users', '', 'Commercial', 'LGPL', '']
# Sentence after removing stopwords: ['21', 'December', '2010', '', 'Finnish', 'industrial', 'machinery', 'company', 'Wartsila', 'Oyj', 'Abp', 'HEL', '', 'WRT1V', 'said', 'yesterday', 'order', 'design', 'liquefied', 'natural', 'gas', 'LNG', 'powered', 'platform', 'supply', 'vessel', 'PSV', 'Norwegian', 'oil', 'service', 'provider', 'Eidesvik', 'Offshore', 'ASA', 'OSL', '', 'EIOF', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'Finland', '', 'Sept', '18', '', '2009', '', 'GLOBE', 'NEWSWIRE', '', '', 'Ixonos', 'Plc', 'expands', 'company', 'smartphone', 'RD', 'services', 'establishes', 'new', 'nextgeneration', 'smartphone', 'design', 'unit', 'connection', 'Ixonos', '', 'site', 'Jyvaeskylae', '']
# Sentence after removing stopwords: ['HELSINKI', 'AFX', '', 'KCI', 'Konecranes', 'said', 'raised', 'stake', 'MMH', 'Holdings', 'Inc', '', 'owner', 'USbased', 'Morris', 'Materials', 'Handling', '', '909', 'pct', '745', 'pct', '']
# Sentence after removing stopwords: ['Finnish', 'electronics', 'manufacturer', 'PKC', 'Group', 'Oyj', '', 'OMX', 'Helsinki', '', 'PKC1V', '', 'said', 'Wednesday', '', '31', 'December', '', 'completed', 'acquisition', 'MAN', 'Nutzfahrzeuge', 'AG', 'cable', 'harness', 'business', 'MAN', 'Star', 'Trucks', '', 'Buses', 'Spolka', 'zoo', 'Poland', '']
# Sentence after removing stopwords: ['Ramirent', 'Danish', 'subsidiary', 'Ramirent', 'AS', 'today', 'signed', 'agreement', 'acquire', 'business', 'assets', 'machinery', 'rental', 'company', 'Jydsk', 'Materiel', 'Udlejning', 'located', 'West', 'Jutland', '']
# Sentence after removing stopwords: ['This', 'assignment', 'strengthens', 'Poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry', '']
# Sentence after removing stopwords: ['Net', 'sales', 'revenue', 'per', 'passenger', 'expected', 'increase', '']
# Sentence after removing stopwords: ['The', 'Dutch', 'broker', 'noted', 'Nokian', 'Tyres', 'reported', 'good', 'first', 'quarter', '2006', '', 'line', 'consensus', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'margin', 'increased', '112', '', '117', '', '']
# Sentence after removing stopwords: ['In', 'JanuarySeptember', '2007', '', 'Finnlines', '', 'net', 'sales', 'rose', 'EUR', '5054', 'mn', 'EUR', '4735', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'While', 'concerns', 'remain', 'longer', 'term', '', 'size', 'scale', 'may', 'enable', 'Nokia', 'hold', 'newfound', 'margin', 'improvements', 'near', 'term', '', '', 'analyst', 'wrote', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', '', 'HEL', '', 'CTH1V', '', 'said', 'today', 'net', 'loss', 'narrowed', 'EUR', '500000', '', 'USD', '680000', '', 'last', 'quarter', '2010', 'EUR', '53', 'million', 'period', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Finnish', 'consumer', 'packaging', 'manufacturer', 'Huhtamaki', 'Oyj', 'said', 'swung', 'net', 'profit', '841', 'mln', 'euro', '', '1056', 'mln', 'first', 'nine', 'months', '2006', 'net', 'loss', '26', 'mln', 'euro', '', '33', 'mln', 'period', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'high', 'technology', 'provider', 'Vaahto', 'Group', 'reports', 'net', 'sales', 'EUR', '418', 'mn', 'accounting', 'period', 'September', '2007', '', 'February', '2008', '', 'increase', '112', '', 'year', 'earlier', '']
# Sentence after removing stopwords: ['By', 'implementing', 'software', 'Finnish', 'Army', 'aims', 'unify', 'improve', 'operations', 'application', 'areas', '', 'QPR', 'Software', 'stated', '']
# Sentence after removing stopwords: ['At', 'press', 'conference', '', 'Lattelecom', 'board', 'chairman', 'Nils', 'Melngailis', 'explained', 'Blackstone', 'chosen', 'experience', 'IT', 'sector', 'well', 'financial', 'strength', '']
# Sentence after removing stopwords: ['Finnish', 'pharmaceuticals', 'company', 'Orion', 'reports', 'profit', 'taxes', 'EUR', '700', 'mn', 'third', 'quarter', '2010', '', 'EUR', '549', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '06', 'mn', 'EUR', '04', 'mn', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '1034', 'mn', 'EUR', '232', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['The', 'OMX', 'Helsinki', '25', 'index', '092', 'pct', '251867', 'Helsinki', 'CAP', 'portfolio', 'index', '091', 'pct', 'higher', '471119', '']
# Sentence after removing stopwords: ['', 'ADPnews', '', '', 'Nov', '9', '', '2009', '', 'Four', 'companies', 'agreed', 'buy', 'combined', 'SEK', '59', 'billion', '', 'USD', '854mEUR', '5718', '', 'drug', 'stores', 'offered', 'sale', 'part', 'restructuring', 'Swedish', 'statedowned', 'pharmacy', 'monopoly', 'Apoteket', 'AB', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Lietuva', '', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'Kesko', 'Group', '', 'boosted', 'sales', '429', 'percent', '134', 'million', 'euros', '', 'VAT', 'inclusive', '']
# Sentence after removing stopwords: ['According', 'company', 'updated', 'strategy', 'years', '20092012', '', 'Basware', 'targets', 'longterm', 'net', 'sales', 'growth', 'range', '20', '', '40', '', 'operating', 'profit', 'margin', '10', '', '20', '', 'net', 'sales', '']
# Sentence after removing stopwords: ['Iggesunds', 'Bruk', 'Sweden', 'one', 'advanced', '', 'fully', 'integrated', 'pulp', 'paperboard', 'mills', 'world', '']
# Sentence after removing stopwords: ['UPMKymmene', 'working', 'closely', 'shipping', 'agents', 'reduce', 'fuel', 'consumption', 'greenhouse', 'gas', 'emissions', '']
# Sentence after removing stopwords: ['Metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'China', 'Lee', '', 'Man', 'Paper', 'Co', '']
# Sentence after removing stopwords: ['In', 'Q1', '2010', '', 'Bank', 'land', 'net', 'interest', 'income', 'increased', 'EUR', '91', 'mn', 'EUR', '97', 'mn', '']
# Sentence after removing stopwords: ['Separately', '', 'YIT', 'Corporation', 'Austrian', 'firm', 'E', 'AG', 'last', 'week', 'signed', 'agreement', 'sale', 'E', 'building', 'system', 'service', 'business', 'Germany', '', 'Austria', '', 'Poland', '', 'Czech', 'Republic', '', 'Hungary', 'Romania', 'EUR', '55', 'mln', '']
# Sentence after removing stopwords: ['Orders', 'received', 'grew', '55', '', 'yearonyear', 'EUR732m', '']
# Sentence after removing stopwords: ['Forestries', 'also', 'higher', '', 'driven', 'yesterday', 'bullish', 'analyst', 'comment', 'Stora', 'Enso', 'Dagens', 'Industri', '', 'dealers', 'said', '']
# Sentence after removing stopwords: ['The', 'group', 'expand', 'chain', 'include', '45', 'stores', '']
# Sentence after removing stopwords: ['Last', 'year', 'company', 'raised', 'turnover', 'approximately', '7', 'million', 'litas', 'EUR', '2', 'mln', '', '61', 'million', 'litas', '2004', '']
# Sentence after removing stopwords: ['Sales', 'expected', 'increase', 'end', 'year', '2006', '', 'however', '']
# Sentence after removing stopwords: ['Comparable', 'net', 'sales', 'expected', 'increase', '10', '', '2008', '', 'line', 'group', 'target', '']
# Sentence after removing stopwords: ['Kalmar', 'awarded', 'new', '5year', 'contract', 'supply', 'Rough', 'Terrain', 'Container', 'Handler', 'RTCH', '']
# Sentence after removing stopwords: ['The', 'company', 'also', 'featured', 'Ethibel', 'Pioneer', 'Investment', 'Register', 'included', 'Innovest', 'Global', '100', 'list', 'world', 'sustainable', 'corporations', '']
# Sentence after removing stopwords: ['In', 'AsiaPacific', 'region', '', 'Visa', 'Wave', 'available', 'Malaysia', '', 'Taiwan', 'South', 'Korea', 'expanded', 'Japan', 'Southeast', 'Asia', 'year', '', 'Jung', 'added', '']
# Sentence after removing stopwords: ['', 'Following', 'last', 'year', 'good', 'profit', 'development', '', 'entered', 'current', 'year', 'good', 'position', '']
# Sentence after removing stopwords: ['The', 'companies', 'agreed', 'longterm', 'cooperation', 'mechanise', 'harvesting', 'Stora', 'Enso', 'eucalyptus', 'plantations', 'Southern', 'China', '']
# Sentence after removing stopwords: ['Outotec', 'said', 'new', 'orders', 'worth', '4929', 'mln', 'eur', 'quarter', '', 'compared', '2404', 'mln', 'eur', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Sales', 'Department', 'Store', 'Division', 'Hobby', 'Hall', 'increased', '7', '', '', 'sales', 'clothing', 'store', 'subsidiary', 'Seppala', 'decreased', '4', '', '']
# Sentence after removing stopwords: ['Global', 'Banking', 'News', '', '28', 'September', '2010', 'Tieto', 'Corporation', 'Pohjola', 'Bank', '', 'PINK', '', 'POJLF', '', 'cooperate', 'SWIFT', 'services', '']
# Sentence after removing stopwords: ['Poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'Latin', 'America', '']
# Sentence after removing stopwords: ['Tekla', 'implement', 'renewal', 'software', 'versions', 'introduced', 'spring', '2011', '']
# Sentence after removing stopwords: ['Sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'EUR', '393', 'mn', '', 'EUR', '327', 'mn', '']
# Sentence after removing stopwords: ['', 'Operating', 'profit', 'rose', '269', '', 'EUR', '1058', '', '834', '', 'million', '']
# Sentence after removing stopwords: ['Then', '', 'said', 'contract', 'estimated', 'contribute', 'EUR150m', 'net', 'sales', '2010', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '1019', 'mn', 'EUR', '1007', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Mobile', 'phone', 'sales', 'rose', '25', '', '587', 'billion', 'euros', '', 'enterprise', 'solution', 'sales', 'dropped', '39', '', '186', 'million', 'euros', '']
# Sentence after removing stopwords: ['The', 'pilot', 'project', 'proved', 'RIFD', 'technology', 'ideal', 'purposes', '', '', 'comments', 'Olli', 'Saarinen', '', 'Material', 'Handling', 'Supervisor', 'Yara', '']
# Sentence after removing stopwords: ['The', 'robust', 'growth', 'result', 'inclusion', 'clothing', 'chain', 'Lindex', 'Group', 'December', '2007', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '5mn', 'EUR', '28', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['TELECOMWORLDWIRE7', 'April', '2006TJ', 'Group', 'Plc', 'sells', 'stake', 'Morning', 'Digital', 'Design', 'Oy', 'Finnish', 'IT', 'company', 'TJ', 'Group', 'Plc', 'said', 'Friday', '7', 'April', 'signed', 'agreement', 'selling', 'shares', 'Morning', 'Digital', 'Design', 'Oy', 'Edita', 'Oyj', '']
# Sentence after removing stopwords: ['CEO', 'company', 'Tarmo', 'Noop', 'said', 'growth', 'sale', 'premium', 'beers', 'biggest', '']
# Sentence after removing stopwords: ['Finnish', 'Bank', 'land', 'reports', 'operating', 'profit', 'rose', 'EUR', '213', 'mn', 'second', 'quarter', '2009', 'EUR', '61', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['The', 'respondents', 'praised', 'Finnair', 'reliability', '', 'Finnishness', '', 'understanding', 'target', 'group', '']
# Sentence after removing stopwords: ['South', 'African', 'Sappi', 'become', 'largest', 'foreign', 'forest', 'industry', 'company', 'operating', 'Finland', 'result', 'acquisition', 'Finnish', 'Mreal', 'Corporation', 'Graphic', 'Papers', 'Business', 'unit', '']
# Sentence after removing stopwords: ['Progress', 'Group', '', 'QPR', 'representative', 'Saudi', 'Arabia', 'North', 'Africa', '', 'signed', 'framework', 'agreement', 'long', 'term', 'strategic', 'relationship', 'ISE', '']
# Sentence after removing stopwords: ['NASDAQlisted', 'Yahoo', 'Inc', 'introduced', 'new', 'service', 'enables', 'Malaysians', 'take', 'favorite', 'Internet', 'content', 'services', 'mobile', 'phones', '']
# Sentence after removing stopwords: ['On', 'hand', '', 'Montevideo', 'said', 'two', 'mills', 'working', 'area', 'generate', 'jobs', '']
# Sentence after removing stopwords: ['In', 'accordance', 'strategy', '', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'South', 'Africa', 'October', '']
# Sentence after removing stopwords: ['We', 'position', 'pursue', 'novel', 'clinical', 'candidates', 'going', 'forward', '', '']
# Sentence after removing stopwords: ['Shareholders', 'Rakvere', 'Lihakombinaat', 'decided', 'favor', 'buyout', 'minority', 'shares', 'midJuly', '']
# Sentence after removing stopwords: ['Fiskars', '', '360yearold', 'global', 'business', 'best', 'known', 'orangehandled', 'scissors', '', 'expects', 'derive', 'synergies', 'EUR5', 'million', 'year', 'consolidating', 'certain', 'parts', 'housewares', 'division', 'two', 'compete', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'increased', '45', '', 'EUR', '314', 'mn', 'EUR', '300', 'mn', '2004', '']
# Sentence after removing stopwords: ['Microsoft', 'also', 'churned', 'courtship', '', 'agreeing', 'use', 'Navteq', 'mapping', 'service', '', 'offered', 'company', 'Nokia', 'bought', '', '81', 'billion', 'years', 'ago', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '04', 'mn', '', 'operating', 'loss', 'EUR', '08', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['The', 'apartment', 'block', 'welllocated', '', 'easy', 'reach', 'city', 'center', 'close', 'school', 'kindergarten', '']
# Sentence after removing stopwords: ['The', 'policy', 'also', 'aimed', 'making', 'companies', 'profitable', 'competitive', '']
# Sentence after removing stopwords: ['EBIT', 'excluding', 'nonrecurring', 'items', '', 'totalled', 'EUR', '678', 'mn', '', 'EUR', '381', 'mn', '']
# Sentence after removing stopwords: ['By', 'acquiring', 'RCP', '', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company', '']
# Sentence after removing stopwords: ['Lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'Kaluga', 'regional', 'administration', 'last', 'November', '']
# Sentence after removing stopwords: ['Finnish', 'telecoms', 'software', 'developer', 'Tecnomen', 'Oyj', 'said', 'December', '5', '', '2006', '', '33', 'mln', '', '25', 'mln', 'euro', '', 'order', 'supply', 'expansion', 'charging', 'messaging', 'systems', 'mobile', 'fixed', 'networks', 'Brasil', 'Telecom', '']
# Sentence after removing stopwords: ['', 'Very', 'recommendable', '', 'Nokian', 'Z', 'G2', 'according', '', 'ADAC', 'judgement', '', 'latest', 'summer', 'tyre', 'test', 'German', 'automobile', 'association', 'ADAC', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', '27', '', 'EUR', '5798', 'mn', 'EUR', '4572', 'mn', '2006', '']
# Sentence after removing stopwords: ['Finnish', 'IT', 'consultancy', 'Satama', 'Interactive', 'Oyj', 'posted', 'net', 'profit', '14', 'mln', 'euro', '', '20', 'mln', 'first', 'nine', 'months', '2007', '', 'compared', 'net', 'loss', '462000', 'euro', '', '664000', 'period', '2006', '']
# Sentence after removing stopwords: ['Rapala', 'said', 'estimates', 'make', 'savings', '12', 'mln', 'eur', 'year', 'centralising', 'French', 'operations', 'one', 'site', '']
# Sentence after removing stopwords: ['This', 'second', 'successful', 'effort', 'financial', 'investor', 'year', '']
# Sentence after removing stopwords: ['Net', 'sales', 'went', '1', '', 'yearonyear', 'EUR', '29', 'million', '', 'affected', 'business', 'acquisitions', '', 'realized', 'previous', 'financial', 'period', '', 'effect', 'EUR', '51', 'million', 'review', 'period', '']
# Sentence after removing stopwords: ['Its', 'market', 'share', 'widened', '4851', 'percent', '4831', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['And', 'broker', 'repeated', '', 'buy', '', 'rating', '', 'based', 'expectations', 'current', 'restructuring', 'lead', 'clear', 'improvement', 'performance', 'Europe', '2007', '']
# Sentence after removing stopwords: ['In', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'loss', 'narrowed', 'EUR415', '000', 'EUR7', '4', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Dubbed', 'Nokia', 'Money', 'Solutions', '', 'company', 'officials', 'say', 'initiative', 'would', 'seek', 'bridge', 'gap', 'banked', 'unbanked', 'developing', 'countries', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'owns', '43', 'percent', 'Bergvik', 'earns', 'therefore', 'SEK', '15', 'bn', 'value', 'appreciation', '']
# Sentence after removing stopwords: ['Latvenergo', 'ordered', 'significant', 'expansion', 'Tekla', 'Xpower', 'network', 'information', 'system', '']
# Sentence after removing stopwords: ['With', 'acquisition', 'Panostaja', 'Oyj', 'expands', 'business', 'area', 'specialising', 'digital', 'printing', '']
# Sentence after removing stopwords: ['Estonian', 'telecoms', 'company', 'Elisa', 'customer', 'numbers', 'cross', '400000', 'TALLINN', '', 'Oct', '22', '', 'BNS', '', 'The', 'Estonian', 'telecommunications', 'company', 'Elisa', 'approximately', '50000', 'new', 'clients', 'nine', 'months', 'year', '', 'bringing', 'number', '401800', 'end', 'September', '', 'company', 'said', '']
# Sentence after removing stopwords: ['DMASIA16', 'August', '2006Benefon', 'extends', 'manufacturing', 'capability', 'ASMobile', '', '2006', 'Digitalmediaasiacom', '', 'DMA', 'Ltd', '']
# Sentence after removing stopwords: ['OUTOTEC', 'OYJ', 'PRESS', 'RELEASE', 'DECEMBER', '4', '', '2009', '1030', 'AM', 'Outotec', 'establishes', 'new', 'subsidiary', 'Kolkata', 'Outotec', 'established', 'subsidiary', 'India', 'order', 'better', 'serve', 'Indian', 'customers', 'increase', 'business', 'growing', 'Indian', 'market', '']
# Sentence after removing stopwords: ['The', 'total', 'delivery', 'volume', 'paper', 'businesses', '2010', '1155000', 'tonnes', '', '1132000', 'tonnes', '2009', '']
# Sentence after removing stopwords: ['Loss', 'taxes', 'amounted', 'EUR', '12', 'mn', 'compared', 'loss', '26', 'mn', '']
# Sentence after removing stopwords: ['The', 'GeoSolutions', 'technology', 'leverage', 'Benefon', 'GPS', 'solutions', 'providing', 'Location', 'Based', 'Search', 'Technology', '', 'Communities', 'Platform', '', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model', '']
# Sentence after removing stopwords: ['Growth', 'expected', 'continue', '2008', '']
# Sentence after removing stopwords: ['Total', 'operating', 'revenue', 'grew', '276', '', 'yearonyear', 'EUR61m', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Feb', '11', '', '2009', '', 'Finnish', 'management', 'software', 'solutions', 'provider', 'Ixonos', 'Oyj', '', 'HEL', '', 'XNS1V', '', 'said', 'today', 'net', 'profit', 'rose', 'EUR', '35', 'million', '', 'USD', '45', '', '2008', 'EUR', '31', 'million', '2007', '']
# Sentence after removing stopwords: ['Stockmann', 'Swedish', 'sector', 'company', 'AB', 'Lindex', 'entered', 'agreement', 'September', '30', '', '2007', '', 'whereby', 'Stockmann', '', 'whollyowned', 'subsidiary', '', 'make', 'public', 'tender', 'offer', 'Lindex', 'issued', 'shares', '']
# Sentence after removing stopwords: ['However', '', 'bottomline', 'result', 'improved', 'thanks', 'positive', 'financial', 'items', '']
# Sentence after removing stopwords: ['The', 'contract', 'signed', 'August', 'Papua', 'New', 'Guineabased', 'Lihir', 'Gold', 'Ltd', 'ASX', '', 'LGL', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['The', 'company', 'operating', 'income', '', 'EBIT', '', 'totalled', 'EUR', '00', 'mn', '', 'EUR', '03', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Profitability', '', 'EBIT', '', '', '139', '', '', 'compared', '131', '', 'previousyear', 'period', '']
# Sentence after removing stopwords: ['', 'We', 'pleased', 'efforts', 'negotiating', 'teams', 'look', 'forward', 'productive', 'four', 'years', 'ahead', '', '']
# Sentence after removing stopwords: ['Componenta', 'increased', 'stake', 'Turkish', 'steel', 'company', 'Doktas', 'Dokumculuk', 'Ticaret', 'Sanayi', 'AS', '926', 'pct', 'stake', 'March', '2007', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['LONDON', 'AFX', '', 'Shares', 'Rautaruukki', 'Corp', 'upgraded', '', 'hold', '', '', 'sell', '', 'ABN', 'Amro', '', 'price', 'target', 'raised', '2575', 'eur', '145', '', 'said', 'dealers', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Dec', '11', '', '2008', '', 'Finnish', 'construction', 'engineering', 'company', 'Outotec', 'Oyj', '', 'OMX', '', 'OTE1V', '', 'said', 'today', 'EUR', '28', 'million', '', 'USD', '368', '', 'order', 'expand', 'phosphate', 'concentrator', 'Siilinjarvi', 'Norwegian', 'minera']
# Sentence after removing stopwords: ['services', 'supplier', 'Efore', 'Plc', 'streamline', 'operations', 'Finland', 'US', 'Finnish', 'electronic', 'systems', 'services', 'supplier', 'Efore', 'Plc', '', 'OMX', 'Helsinki', '', 'EFO1V', '', 'said', 'Tuesday', '', '3', 'February', '', 'initiated', 'statutory', 'negotiations', 'regarding', 'streamlining', 'operations', 'Finland', '']
# Sentence after removing stopwords: ['However', '', 'total', 'orders', 'received', 'still', 'last', 'year', 'levels', '']
# Sentence after removing stopwords: ['SysOpen', 'Digia', 'signed', 'agreement', 'main', 'shareholders', 'Sentera', 'holding', 'total', '7739', '', 'share', 'capital', 'votes', 'Sentera', '']
# Sentence after removing stopwords: ['According', 'CEO', 'Nordea', 'Bank', 'Estonia', 'Vahur', 'Kraft', '', 'Nordea', 'Finland', 'Stockmann', 'cooperating', 'ten', 'years', '']
# Sentence after removing stopwords: ['The', 'Bristol', 'Port', 'Company', 'sealed', 'one', 'million', 'pound', 'contract', 'Cooper', 'Specialised', 'Handling', 'supply', 'four', '45tonne', '', 'customised', 'reach', 'stackers', 'Konecranes', '']
# Sentence after removing stopwords: ['In', 'autumn', '', 'plans', 'expand', 'service', 'St', 'Petersburg', 'Moscow', 'launch', 'service', 'Yekaterinburg', '', 'Russia', '', 'flying', 'three', 'times', 'week', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafers', 'manufacturer', 'Okmetic', 'Oyj', 'said', 'June', '29', '', '2007', 'signed', 'agreement', 'Nordea', 'Bank', 'Finland', 'Plc', '', 'local', 'subsidiary', 'Swedish', 'commercial', 'bank', 'Nordea', 'Bank', 'AB', '', 'refinance', 'Okmetic', 'syndicated', 'bank', 'facility', 'amounts', '20', 'mln', 'euro', '', '', '269', 'mln', '', '']
# Sentence after removing stopwords: ['We', 'capitalize', 'experience', 'number', 'similar', 'bridge', 'projects', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['Managing', 'Director', 'Kari', 'Inkinen', 'says', 'Sponda', 'leasing', 'operations', 'developed', 'highly', 'favourably', '']
# Sentence after removing stopwords: ['GeoSentric', 'Oyj', 'GeoSolutions', 'Business', 'Unit', 'GyPSii', '', 'mobile', 'digital', 'lifestyle', 'application', 'geomobility', 'social', 'networking', 'platform', '', 'signed', 'agreement', 'Nanjing', 'MyNet', 'make', 'GyPSii', 'mobile', 'social', 'networking', 'platform', 'available', 'customers', 'China', 'Mobile', '']
# Sentence after removing stopwords: ['It', 'also', 'turned', 'earnings', 'per', 'share', '', 'EPS', '', 'EUR', '044', 'versus', 'loss', 'per', 'share', 'EUR', '226', '']
# Sentence after removing stopwords: ['Tallink', 'claims', 'watertight', 'doors', 'Vana', 'Tallinn', 'Regina', 'Baltica', '', 'including', 'electrical', 'systems', '', 'fully', 'working', 'order', '']
# Sentence after removing stopwords: ['The', '5050', 'joint', 'venture', '', 'called', 'Nokia', 'Siemens', 'Networks', '', 'comprised', 'Nokia', 'network', 'business', 'group', 'Siemens', '', 'carrierrelated', 'operations', '', 'creating', 'estimated', 'synergies', '15', 'billion', 'euros', '', '', '19', 'billion', '', '2010', '', 'Nokia', 'said', '']
# Sentence after removing stopwords: ['In', 'banking', '', 'Sampo', 'A', 'unchanged', '1424', 'eur', 'Nordea', 'rose', '042', 'pct', '951', 'eur', '']
# Sentence after removing stopwords: ['Finnish', 'Raisio', '', 'Diagnostics', '', 'launching', 'new', 'DNAbased', 'quick', 'tests', 'ensure', 'safety', 'food', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '830', 'mn', '', 'EUR', '235', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Pearl', 'Plaza', 'LLC', '', 'joint', 'venture', 'SRV', 'Shanghai', 'Industrial', 'Investment', 'Holdings', 'Co', 'Ltd', '', 'concluded', 'investment', 'decision', 'construction', 'first', 'phase', 'shopping', 'center', 'Saint', 'Petersburg', '', 'Russia', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['Alma', 'Media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously', '']
# Sentence after removing stopwords: ['Exports', 'accounted', '654', '', 'net', 'sales', '', 'representing', 'time', 'record', 'company', '']
# Sentence after removing stopwords: ['Construction', 'volumes', 'meanwhile', 'grow', 'rate', '1015', 'percent', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'mobile', 'operator', 'DNA', 'function', 'subcontractor', 'Maingate', 'responsible', 'telecommunications', 'connections', '']
# Sentence after removing stopwords: ['The', 'Group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets', '']
# Sentence after removing stopwords: ['Outotec', 'net', 'profit', 'second', 'quarter', '2007', 'jumped', '168', 'mln', 'euro', '', '', '231', 'mln', '', '46', 'mln', 'euro', '', '', '63', 'mln', '', 'year', 'ago', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'guided', 'EBIT', 'sales', 'growth', '20', 'pct', '10', 'pct', 'respectively', 'year', '']
# Sentence after removing stopwords: ['According', 'Nordic', 'financial', 'group', 'Nordea', 'analyst', 'Sami', 'Sarkamies', '', 'makes', 'Nokia', 'portfolio', 'competitive', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Significance', '', 'Teleste', 'emphasised', 'large', 'size', 'growing', 'economy', '', 'well', 'rapid', 'development', 'TV', 'services', 'distribution', 'industry', '', 'Poland', 'viewed', 'attractive', 'market', '']
# Sentence after removing stopwords: ['The', 'energyefficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'stateoftheart', 'technology', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Retail', 'wholesale', 'group', 'Kesko', 'reported', 'net', 'sales', '6594', 'mln', 'eur', 'February', '', 'increase', '108', 'pct', 'yearonyear', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', 'higher', '048', '037', 'year', 'ahead', 'market', 'consensus', '040', 'eur', '']
# Sentence after removing stopwords: ['Sanoma', 'Magazines', 'Finland', 'net', 'sales', 'grew', 'EUR', '1401', 'mn', 'EUR', '1318', 'mn', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'part', 'Ramirent', 'strategy', 'strengthen', 'position', 'selected', 'locations', '']
# Sentence after removing stopwords: ['It', 'estimates', 'operating', 'profit', 'improve', 'third', 'quarter', '']
# Sentence after removing stopwords: ['Ragutis', '', 'controlled', 'Finnish', 'brewery', 'Olvi', '', 'achieved', '57', 'percent', 'rise', 'beer', 'sales', '226', 'million', 'liters', 'held', '1075', 'percent', 'market', 'share', '']
# Sentence after removing stopwords: ['TomTom', 'given', 'assurances', 'continue', 'sell', 'maps', 'competitors', 'wins', 'EU', 'approval', '']
# Sentence after removing stopwords: ['For', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'profit', 'rose', 'EUR41m', 'EUR30m', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Exports', 'grew', '165', 'percent', '191', 'million', 'liters', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Diluted', 'loss', 'per', 'share', 'stood', 'EUR', '015', 'versus', 'EUR', '026', '']
# Sentence after removing stopwords: ['Nokia', '012', 'pct', '1670', 'eur', 'kicking', 'morning', 'negative', 'territory', '']
# Sentence after removing stopwords: ['The', 'borrower', 'happy', 'roadshow', 'paid', 'hit', 'ratio', 'high', '']
# Sentence after removing stopwords: ['Adjusted', 'changes', 'Group', 'structure', '', 'Division', 'net', 'sales', 'increased', '17', '', '']
# Sentence after removing stopwords: ['Cision', 'says', 'sale', 'return', 'UK', 'operation', 'profitability', '']
# Sentence after removing stopwords: ['Finnish', 'Okmetic', 'manufactures', 'processes', 'silicon', 'wafers', 'semiconductor', 'sensor', 'industries', 'Norwegian', 'solar', 'wafer', 'company', 'NorSun', 'signed', 'contract', 'Okmetic', 'supply', 'NorSun', 'mono', 'silicon', 'crystals', 'use', 'solar', 'cell', 'manufacturing', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafer', 'technology', 'company', 'Okmetic', 'Oyj', 'OMX', 'Helsinki', '', 'OKM1V', 'reported', 'Thursday', '30', 'October', 'operating', 'profit', 'EUR7', '4', 'JanuarySeptember', '2008', '', 'EUR6', '1', 'corresponding', 'period', '2007', '']
# Sentence after removing stopwords: ['Also', '', 'bringing', '', 'right', 'kind', 'people', '', 'upgrade', 'human', 'resources', '']
# Sentence after removing stopwords: ['About', 'Elcoteq', 'Elcoteq', 'SE', 'leading', 'electronics', 'manufacturing', 'services', '', 'EMS', '', 'company', 'communications', 'technology', 'field', '']
# Sentence after removing stopwords: ['Mr', 'Priit', 'Kasak', '', 'Balti', 'Metsamasina', 'owner', '', 'said', 'Rakverebased', 'company', 'wishes', 'increase', 'Valmet', 'market', 'share', '27', '', 'third', 'couple', 'years', '']
# Sentence after removing stopwords: ['Finland', 'Nokian', 'Tyres', 'Kazakhstan', 'Ordabasy', 'Corporation', 'signed', 'agreement', 'build', 'plant', 'Astana', 'produce', 'car', 'tires', '', 'Ordabasy', 'chairman', 'Dinmukhamet', 'Idrisov', 'said', 'press', 'conference', '']
# Sentence after removing stopwords: ['The', 'company', 'expects', 'net', 'sales', 'first', 'half', '2008', 'reach', 'previous', 'year', 'level', '']
# Sentence after removing stopwords: ['Ruukki', 'announced', 'signed', 'agreement', 'Aker', 'Solutions', 'Norway', 'supply', '24', 'suction', 'anchors', 'September', '2010', 'Kalajoki', 'unit', 'Finland', '']
# Sentence after removing stopwords: ['AUSTIN', '', 'Texas', '', 'Sept', '6', '', 'Texas', 'Department', 'Of', 'Transportation', 'awards', 'contract', 'Teleste', 'Video', 'Compression', 'Distribution', 'Equipment', '']
# Sentence after removing stopwords: ['The', 'price', 'raw', 'material', 'aluminium', 'went', 'end', '2005', '', 'company', 'considers', 'outlook', '2006', 'favourable', '']
# Sentence after removing stopwords: ['Finnish', 'automation', 'solutions', 'developer', 'Cencorp', 'Corporation', '', 'OMX', 'Helsinki', '', 'CNC1V', '', 'said', 'Friday', '', '27', 'June', '', 'completed', 'employee', 'negotiations', 'regarding', 'reorganisation', 'operations', '']
# Sentence after removing stopwords: ['The', 'company', 'committed', 'expanding', 'Apollo', 'portfolio', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'Nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout', '']
# Sentence after removing stopwords: ['The', 'company', 'moved', 'operating', 'profit', 'EUR10', '9', 'versus', 'operating', 'loss', 'EUR15', '3', 'It', 'also', 'turned', 'EPS', 'EUR0', '08', 'versus', 'loss', 'per', 'share', 'EUR0', '04', '']
# Sentence after removing stopwords: ['The', 'increase', 'capital', 'stock', 'registered', 'Finnish', 'Trade', 'Register', '20', 'November', '2006', '']
# Sentence after removing stopwords: ['Basware', 'Corporation', 'stock', 'exchange', 'release', 'August', '31', '', '2010', '1625', 'Basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'Basware', 'deliver', 'Invoice', 'Automation', 'solution', 'Connectivity', 'Services', 'international', 'industrial', 'group', '']
# Sentence after removing stopwords: ['20', 'October', '2010', '', 'Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', 'HEL', '', 'CTH1V', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'EUR7m', 'first', 'nine', 'months', '2010', 'EUR23', '3', 'period', '2009', '']
# Sentence after removing stopwords: ['In', 'January', '', 'traffic', '', 'measured', 'revenue', 'passenger', 'kilometres', 'RPK', '', 'went', '32', '', 'capacity', '', 'measured', 'available', 'seat', 'kilometres', 'ASK', '', 'rose', '122', '', '']
# Sentence after removing stopwords: ['Lule', 'municipality', 'awarded', 'YIT', '2year', 'contract', '', 'property', 'management', 'one', 'third', 'municipality', 'properties', '', 'total', 'area', '140000', 'sq', 'metres', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'jumped', 'EUR', '219', 'million', 'EUR', '31', 'million', '']
# Sentence after removing stopwords: ['Tekla', 'Structures', 'BIM', 'Building', 'Information', 'Modeling', 'software', 'developed', 'according', 'longterm', 'plan', 'improved', 'user', 'experience', '', 'process', '', 'functionality', '']
# Sentence after removing stopwords: ['Industry', 'Investment', 'interested', 'Glaston', 'solar', 'energy', 'projects', '']
# Sentence after removing stopwords: ['Sales', 'improved', 'SEK', '1553', 'mn', '', 'compared', 'SEK', '1408', 'mn', '']
# Sentence after removing stopwords: ['It', 'leading', 'private', 'road', 'ambulance', 'service', 'company', 'Finland', '']
# Sentence after removing stopwords: ['The', 'decision', 'sell', 'share', 'Lenenergo', 'reached', 'line', 'Fortum', 'strategic', 'plans', 'invest', 'mainly', 'generating', 'assets', 'Russia', '', 'Lenenergo', 'grid', 'company', '', 'press', 'release', 'said', '']
# Sentence after removing stopwords: ['It', 'projected', 'revenue', '', '22', 'billion', '', '23', 'billion', '', 'slightly', 'higher', 'analyst', 'estimates', '', '219', 'billion', '']
# Sentence after removing stopwords: ['These', 'measures', 'expected', 'produce', 'annual', 'cost', 'savings', 'EUR', '15', 'million', 'starting', '2007', '']
# Sentence after removing stopwords: ['', 'I', 'happy', 'outcome', '', '', 'Sneed', 'said', 'hearing', '']
# ...
# Sentence after removing stopwords: ['Net', 'sales', '2006', 'totaled', 'EUR', '302', 'million', 'operating', 'margin', '16', '', '']
# Sentence after removing stopwords: ['The', 'Bank', 'land', 'acquired', 'private', 'banking', 'business', '', 'asset', 'management', '', 'share', 'brokerage', 'business', 'Kaupthing', 'Sweden', 'early', '2009', '']
# Sentence after removing stopwords: ['Quality', 'chargers', 'CHARGZ', 'brand', 'sold', 'selected', 'retail', 'stores', 'sales', 'locations', 'worldwide', '']
# Sentence after removing stopwords: ['industry', 'Asia', '\x88', 'Pakistan', '', 'Malaysia', '', 'Taiwan', 'Philippines', 'Today', '', 'Global', 'Research', '', 'Data', 'Services', 'going', 'publish', 'several', 'market', 'analyses', 'cement', 'markets', 'Asia', '']
# Sentence after removing stopwords: ['Glaston', 'wellknown', 'brands', 'Bavelloni', '', 'preprocessing', 'machines', 'tools', '', 'Tamglass', 'Uniglass', 'safety', 'glass', 'machines', 'Albat', '', 'Wirsam', 'software', 'solutions', '']
# Sentence after removing stopwords: ['A', 'Le', 'Coq', 'market', 'share', '413', 'percent', 'rival', 'beverage', 'group', 'Saku', '321', 'percent', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'June', '7', '', 'Michael', 'G', 'Williams', 'Newbury', 'Park', '', 'Calif', '', 'developed', 'network', 'device', '']
# Sentence after removing stopwords: ['', 'They', 'already', 'allocated', 'money', 'inventory', '']
# Sentence after removing stopwords: ['The', 'value', 'threeyear', 'contract', 'estimated', 'EUR40m', '']
# Sentence after removing stopwords: ['Each', 'option', 'right', 'entitles', 'holder', 'subscribe', 'one', 'new', 'share', 'subscription', 'price', 'EUR0', '045', 'subscription', 'period', 'ends', '31', 'December', '2013', '']
# Sentence after removing stopwords: ['Kaukopartio', 'Oy', 'acquired', 'specialized', 'knowledge', 'Far', 'Eastern', 'operations', '', 'industrial', 'sourcing', 'services', 'core', 'competence', '']
# Sentence after removing stopwords: ['The', 'value', 'orders', 'EUR', '25mn', '']
# Sentence after removing stopwords: ['The', 'owners', 'participated', 'business', 'operations', 'company', 'continue', 'Poyry', 'employment', 'transaction', '']
# Sentence after removing stopwords: ['Nokian', 'Tyres', '', 'tyres', 'considered', 'genuine', 'winter', 'tyres', 'Russia', '']
# Sentence after removing stopwords: ['Mr', 'McDonald', 'started', 'evening', 'set', '', 'featuring', 'hits', 'solo', 'career', 'Doobie', 'Brothers', 'years', 'selection', 'RB', 'cover', 'songs', 'met', 'mixed', 'results', '']
# Sentence after removing stopwords: ['Nokia', 'said', 'outcome', '', 'fair', 'responsible', 'social', 'plan', '', '']
# Sentence after removing stopwords: ['AffectoGenimap', 'builds', 'highly', 'customised', 'IT', 'solutions', 'customers', 'Finland', 'Baltic', 'countries', '']
# Sentence after removing stopwords: ['Votorantim', 'Celulose', 'e', 'Papel', '', 'VCP', '', 'part', 'Votorantim', 'Group', '', 'major', 'Brazilian', 'conglomerate', '']
# Sentence after removing stopwords: ['She', 'succeed', 'Krister', 'Kylas', '', 'decided', 'leave', 'TeliaSonera', '']
# Sentence after removing stopwords: ['The', 'dividend', 'paid', 'April', '15', '', '2008', 'shareholders', 'record', 'date', 'April', '8', '', '2008', 'entered', 'list', 'shareholders', 'kept', 'Finnish', 'Central', 'Securities', 'Depository', 'Ltd', '']
# Sentence after removing stopwords: ['Unbelievably', '', 'company', 'makes', '', 'Fiskars', 'Corporation', '', 'formed', '1649', 'Dutch', 'merchant', 'named', 'Peter', 'Thorwoste', 'given', 'charter', 'establish', 'blast', 'furnace', 'forging', 'operation', 'small', 'Finnish', 'village', 'Fiskars', '']
# Sentence after removing stopwords: ['The', 'number', 'class', 'A', 'shares', 'remains', 'unchanged', '9526089', 'shares', '']
# Sentence after removing stopwords: ['HELSINKI', 'AFX', '', 'Cargotec', 'said', 'bought', '95', 'pct', 'stake', 'Indital', 'Construction', 'Machinery', 'Ltd', '', 'Bangalorebased', 'company', 'makes', 'fork', 'lift', 'trucks', 'mobile', 'cranes', '', 'undisclosed', 'sum', '']
# Sentence after removing stopwords: ['Finnish', 'fibers', 'plastics', 'producer', 'Suominen', 'Corporation', 'OMX', 'Helsinki', '', 'SUY1V', 'reported', 'Wednesday', '22', 'October', 'operating', 'loss', 'EUR0', '8', 'net', 'sales', 'EUR55', '2', 'third', 'quarter', '2008', '']
# Sentence after removing stopwords: ['Swedish', 'telco', 'TeliaSonera', 'teaming', 'Friends', '', 'Swedish', 'organization', 'bullying', '', 'fight', 'bullying', 'children', 'teenagers', 'via', 'electronic', 'channels', '']
# Sentence after removing stopwords: ['Sanoma', 'also', 'Executive', 'Committee', '', 'accordance', 'Company', 'Articles', 'Association', '', 'prepares', 'proposals', 'matters', 'decided', 'noted', 'Board', 'Directors', '']
# Sentence after removing stopwords: ['3G', 'data', 'subscribers', 'also', 'helping', 'maintain', 'growth', 'levels', '', 'since', 'dataonly', 'subscriptions', 'push', 'multiple', 'SIM', 'ownership', '']
# Sentence after removing stopwords: ['', 'Printed', 'fabrics', 'related', 'design', 'expertise', 'always', 'core', 'Marimekko', 'business', 'brand', '']
# Sentence after removing stopwords: ['Feed', 'companies', 'Suomen', 'Rehu', 'Raisio', 'import', 'GMO', 'feed', '']
# Sentence after removing stopwords: ['The', 'engine', 'electrical', 'output', '18321', 'kW', '', 'making', 'largest', 'gas', 'powered', 'generating', 'set', 'world', '']
# Sentence after removing stopwords: ['This', 'lays', 'foundation', 'sustainable', 'business', 'development', 'long', 'term', '']
# Sentence after removing stopwords: ['The', 'Committee', 'proposes', 'following', 'remuneration', '', 'monthly', 'remuneration', 'EUR', '5000', 'Chairman', '', 'EUR', '3500', 'Deputy', 'Chairman', '', 'EUR', '2500', 'Board', 'members', '']
# Sentence after removing stopwords: ['Risto', 'Jalo', '', 'chief', 'executive', 'Dormus', 'Print', 'also', 'owner', 'remainder', 'company', '', 'keep', 'position', 'acquisition', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'Oct', '15', '', 'Aaron', 'Moss', 'Hampshire', '', 'Great', 'Britain', '', 'developed', 'ornamental', 'design', 'handset', '', 'US', 'Patent', '', 'Trademark', 'Office', 'announced', '']
# Sentence after removing stopwords: ['Yvonne', 'Jones', 'owner', 'Chameleon', 'Interiors', '']
# Sentence after removing stopwords: ['Citigroup', '', 'Inc', 'NYSE', '', 'C', '', 'Deutsche', 'Bank', 'NYSE', '', 'DB', 'Pohjola', 'Bank', 'lead', 'managers', 'sale', '']
# Sentence after removing stopwords: ['At', 'beginning', 'subscription', 'period', 'May', '2', '', '2006', 'share', 'subscription', 'price', 'B', 'option', 'right', 'EUR', '1022', 'per', 'share', '']
# Sentence after removing stopwords: ['In', '2005', 'bank', 'posted', 'net', 'profit', 'Lt', '82', 'mn', '']
# Sentence after removing stopwords: ['The', 'company', 'earlier', 'said', 'considering', 'different', 'strategic', 'options', 'struggling', 'lowcost', 'mobile', 'operator', '', 'including', 'divestment', 'holding', '']
# Sentence after removing stopwords: ['The', 'two', 'sellers', 'Finnish', 'National', 'Fund', 'RD', '', 'Sitra', '', 'Oras', 'Invest', 'Oy', '', 'also', 'sold', 'half', 'shareholdings', '', 'leaving', '38', 'pct', '32', 'pct', 'company', 'respectively', '']
# Sentence after removing stopwords: ['According', 'Gallup', 'Food', 'Farm', 'Facts', '', 'beef', 'consumption', 'totaled', '99mn', 'kilos', 'Finland', '2007', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'Alma', 'Media', 'focus', 'quality', 'developing', 'chain', 'operations', '']
# Sentence after removing stopwords: ['mr', 'Bakman', 'sees', 'also', 'expansion', 'options', 'TallinnHelisnki', 'link', '', 'claiming', 'however', '', 'operating', 'link', 'single', 'ship', 'enough', '']
# Sentence after removing stopwords: ['Since', 'registration', 'shares', 'subscribed', 'directed', 'share', 'issue', '', 'new', 'number', 'Panostaja', 'shares', 'voting', 'rights', '41733110', '']
# Sentence after removing stopwords: ['The', 'inaugural', 'speech', 'given', 'Hannu', 'Kyrolainen', '', 'Finland', 'Ambassador', 'Czech', 'Republic', '']
# Sentence after removing stopwords: ['Following', 'issue', '', 'new', 'shares', 'constitute', '10', 'percent', 'firm', 'capital', '']
# Sentence after removing stopwords: ['The', 'decision', 'made', 'whether', 'group', 'agrees', 'import', 'Estonian', 'meat', 'meat', 'products', 'Finland', '', 'paper', 'added', '']
# Sentence after removing stopwords: ['Measures', 'launched', 'immediately', 'due', 'finalized', 'first', 'quarter', '2010', '']
# Sentence after removing stopwords: ['', 'Our', 'approach', 'much', 'use', 'raw', 'materials', 'produced', 'line', 'principles', 'sustainable', 'development', '']
# Sentence after removing stopwords: ['With', 'second', 'phase', 'new', 'Innova', 'building', '', 'Tecnopolis', 'presence', 'Jyvaskyla', 'increase', 'total', 'approximately', '62000', 'floor', 'square', 'meters', '']
# Sentence after removing stopwords: ['Country', '', '', 'Germany', 'Sector', '', 'ConstructionReal', 'Estate', '', 'MachineryEngineering', 'Target', '', 'Caverion', 'GmbH', 'Buyer', '', 'YIT', 'Oyj', 'Deal', 'size', 'USD', '', '903', 'Type', '', 'Corporate', 'acquisition', 'Status', '', 'Agreed']
# Sentence after removing stopwords: ['Pharmaceutical', 'market', 'Netherlands', 'Global', 'Research', '', 'Data', 'Services', 'published', 'recently', 'market', 'analysis', 'pharmaceutical', 'markets', 'Netherlands', '']
# Sentence after removing stopwords: ['It', 'even', 'little', 'bit', 'higher', 'Yara', 'multiples', '', '', 'analyst', 'Helsinki', 'said', '']
# Sentence after removing stopwords: ['Finnish', 'plumbing', 'heating', 'systems', 'supplier', 'Uponor', 'announced', 'companywide', 'cost', 'reduction', 'program', 'August', '2008', '']
# Sentence after removing stopwords: ['Finnish', 'diversified', 'holding', 'company', 'Aspo', 'Oyj', 'said', 'September', '8', '', '2008', 'sell', 'Finnish', 'tape', 'business', 'Kaukomarkkinat', 'unit', 'local', 'Oy', 'Telpak', 'Ab', '']
# Sentence after removing stopwords: ['The', 'Polish', 'business', 'employs', '1000', 'people', '', 'net', 'sales', 'EUR', '70mn', '2007', '']
# Sentence after removing stopwords: ['The', 'reductions', 'implemented', 'immediately', '', 'beginning', 'October', '2009', '']
# Sentence after removing stopwords: ['The', 'company', '120', 'employees', 'annual', 'sales', 'approximately', 'EUR16m', '']
# Sentence after removing stopwords: ['Finnish', 'glass', 'technology', 'group', 'Glaston', 'Corporation', '', 'OMX', 'Helsinki', '', 'GLA1V', '', 'reported', 'Thursday', '', '14', 'August', '', 'operating', 'profit', 'EUR6', '5', 'net', 'sales', 'EUR201', '5', 'period', 'JanuarySeptember', '2008', '']
# Sentence after removing stopwords: ['', 'Nordea', 'definitely', 'big', 'Sampo', 'acquire', '', '', 'said', 'analyst', '', 'But', 'Sampo', 'would', 'appear', 'agenda', 'Nordea', 'ahead', 'privatisation', '']
# Sentence after removing stopwords: ['Bertrand', 'Sciard', 'vice', 'chairman', 'board', 'directors', 'Aldata', 'Solution', 'since', 'April', '2007', '']
# Sentence after removing stopwords: ['The', 'webcast', 'may', 'followed', 'online', 'company', 'website', 'wwwruukkicominvestors', '']
# Sentence after removing stopwords: ['In', 'Sweden', '', 'Gallerix', 'accumulated', 'SEK', 'denominated', 'sales', '1', '', 'EUR', 'denominated', 'sales', '11', '', '']
# Sentence after removing stopwords: ['Cramo', '', 'headquartered', 'Vantaa', '', 'Finland', '', 'rents', 'construction', 'machinery', 'equipment', '', 'well', 'rents', 'sells', 'modular', 'space', '']
# Sentence after removing stopwords: ['The', 'first', 'phase', 'logistics', 'complex', 'envisages', 'completion', '70000', 'sq', 'logistics', 'premises', 'gatehouse', 'building', 'November', '2008', '']
# Sentence after removing stopwords: ['The', 'proposal', 'shareholders', 'elect', 'Mr', 'Hannu', 'Krogerus', 'Board', 'based', 'long', 'unrivalled', 'experience', 'knowledge', 'matters', 'related', 'Elcoteq', '']
# Sentence after removing stopwords: ['', 'We', 'license', 'agreement', 'Nokia', 'Corp', 'part', 'expires', 'April', '9', '', '2007', '']
# Sentence after removing stopwords: ['The', 'platform', 'would', 'continue', 'development', 'framework', 'Symbian', 'MeeGo', '']
# Sentence after removing stopwords: ['The', 'new', 'Kroksberg', 'railway', 'tunnel', 'built', 'new', 'section', 'track', 'Harnosand', 'Veda', '', 'forming', 'part', 'line', 'follows', 'coast', 'Gulf', 'Bothnia', '']
# Sentence after removing stopwords: ['The', 'energy', 'sector', 'accounted', 'approximately', '33', '', 'steel', 'industry', '57', '', 'transportation', 'volume', '']
# Sentence after removing stopwords: ['Currently', 'Alfred', 'A', 'Palmberg', 'putting', 'finishing', 'touches', 'one', 'Finland', 'biggest', 'ever', 'replumbing', 'bathroom', 'refurbishment', 'projects', 'also', 'district', 'Vuosaari', '']
# Sentence after removing stopwords: ['The', 'prices', 'stainless', 'steel', 'also', 'rose', 'Europe', '']
# Sentence after removing stopwords: ['In', 'release', 'Oct', '28', '', 'Peab', 'said', 'two', 'businesses', 'continue', 'conducted', 'brands', 'Cliffton', 'Stockholm', 'Entreprenad', '', 'part', 'Peab', 'Group', '']
# Sentence after removing stopwords: ['We', 'serve', 'broad', 'range', 'customers', '', 'including', 'construction', 'process', 'industries', '', 'shipyards', '', 'public', 'sector', 'households', '']
# Sentence after removing stopwords: ['', 'Tweeple', 'check', 'following', '', 'cautious', 'clicking', 'URLs', 'tinyurls', '', '']
# Sentence after removing stopwords: ['Cargotec', 'sales', 'totalled', 'EUR', '34', 'billion', '2008', 'employs', 'approximately', '10500', 'people', '']
# Sentence after removing stopwords: ['The', 'expanded', 'plant', 'scheduled', 'operational', 'middle', 'October', '2009', '']
# Sentence after removing stopwords: ['The', 'machines', 'cease', 'production', 'end', 'February', '2007', '']
# Sentence after removing stopwords: ['All', 'rights', 'reserved', '']
# Sentence after removing stopwords: ['The', 'company', 'studying', 'feasibility', 'focusing', 'processed', 'meat', 'production', 'Vantaa', 'facilities', 'processing', 'fresh', 'meat', 'Forssa', 'facilities', '']
# Sentence after removing stopwords: ['The', 'opportunity', 'available', 'employees', '', 'however', '']
# Sentence after removing stopwords: ['The', 'broadbased', 'WIG', 'index', 'ended', 'Thursday', 'session', '01', 'pct', '6500334', 'pts', '', 'bluechip', 'WIG20', '113', '368715', 'pts', '']
# Sentence after removing stopwords: ['The', 'bank', 'leasing', 'arm', 'Nordea', 'Liising', 'ended', 'year', 'profit', '44', 'million', 'euros', '']
# Sentence after removing stopwords: ['To', 'number', 'one', 'means', 'creating', 'added', 'value', 'stakeholders', 'everything', '']
# Sentence after removing stopwords: ['The', 'companies', 'divest', 'UPM', 'Fray', 'Bentos', 'pulp', 'mill', 'Forestal', 'Oriental', '', 'company', 'specialising', 'eucalyptus', 'cultivation', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'produces', 'many', 'turkey', 'products', '', 'cold', 'cuts', '']
# Sentence after removing stopwords: ['Mr', 'Kari', 'Stadigh', 'carry', 'Chairman', 'Board', 'Mr', 'Matti', 'Arteva', 'ViceChairman', '']
# Sentence after removing stopwords: ['The', 'Russian', 'government', 'contribute', '20', '', 'necessary', 'funds', '', 'said', '']
# Sentence after removing stopwords: ['Nordstjernan', 'used', 'option', 'buy', 'another', '224', '', 'stake', 'Salcomp', 'shares', 'votes', '']
# Sentence after removing stopwords: ['Mreal', 'Corporation', 'Stock', 'Exchange', 'Announcement', '29', 'September', '2006', '415', 'pm', 'Kyro', 'Corporation', 'Mreal', 'Corporation', '', 'Metsaliitto', 'Group', 'subsidiary', '', 'agreed', 'arrangement', 'gives', 'Mreal', 'option', 'purchase', 'Kyroskoski', 'natural', 'gas', 'powerplant', 'Kyro', '']
# Sentence after removing stopwords: ['Its', 'total', 'annual', 'revenue', 'comes', '160', 'mln', 'zloty', '', '', '569', 'mln42', '3', 'mln', 'euro', '', '']

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive3=pd.DataFrame(sorted(positiveValues3.items(),key=lambda x:x[1],reverse=True))
df_negative3=pd.DataFrame(sorted(negativeValues3.items(),key=lambda x:x[1],reverse=True))
df_neutral3=pd.DataFrame(sorted(neutralValues3.items(),key=lambda x:x[1],reverse=True))

# %%
pd1tri=df_positive3[0][:10]
pd2tri=df_positive3[1][:10]

ned1tri=df_negative3[0][:10]
ned2tri=df_negative3[1][:10]

nud1tri=df_neutral3[0][:10]
nud2tri=df_neutral3[1][:10]

plt.figure(1,figsize=(16,4))

plt.bar(pd1tri,pd2tri, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-TRIGRAM ANALYSIS")

plt.savefig("positive-trigram.png")
plt.show()

# %%
df_positive3.head(10)
# Out:
#                          0   1
# 0                mln euro   35
# 1                   euro    21
# 2  mn corresponding period  20
# 3            year earlier   17
# 4               said today  16
# 5          profit rose EUR  15
# 6                     HEL   15
# 7                  mn  EUR  15
# 8             period 2006   14
# 9        first nine months  14

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1tri,ned2tri, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-TRIGRAM ANALYSIS")

plt.savefig("negative-trigram.png")
plt.show()

# %%
df_negative3.head(10)
# Out:
#                          0   1
# 0                  mn  EUR  19
# 1                mln euro   16
# 2  mn corresponding period  15
# 3      compared profit EUR  12
# 4             mn  compared  11
# 5            year earlier   11
# 6               per share   10
# 7                   euro    10
# 8               share  EPS   9
# 9                     EPS    9

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1tri,nud2tri, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-TRIGRAM ANALYSIS")

plt.savefig("neutral-trigram.png")
plt.show()

# %%
df_neutral3.head(10)
# Out:
#                      0   1
# 0             Finland   32
# 1            mln euro   20
# 2         company said  15
# 3                 HEL   15
# 4        company said   14
# 5        OMX Helsinki   14
# 6               euro    13
# 7             Oyj  HEL  12
# 8     operating profit  11
# 9  NASDAQ OMX Helsinki  11

# %% [markdown]
# **Using CountVectorizer()**
#
# -can also b used to check the most common bigrams
